# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/GloVe/BiLSTM-CRF%20GLOVE%20(Hidden).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-fhdv4dnw
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-fhdv4dnw
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=aaa6828234e5a670bbf81e357f17a9fcfefca30b848ee49e43a9af5d6b017f12
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cyk8tfhy/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Requirement already satisfied: sklearn_crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# TensorFlow 1.x selected.

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2
# Using TensorFlow backend.

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_path = "/content/drive/My Drive/glove.6B.50d.txt"
#root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
HIDDEN =[10,20,50,100]
DROPOUT =0.10
CELLS =200
BATCH_SIZE= 32
EPOCHS=20
fold_count = 1

for HID in HIDDEN:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(HIDDEN)*3))
    
    #split data
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(HID):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=CELLS, return_sequences=True,
                                recurrent_dropout=DROPOUT, dropout=DROPOUT))(model_2)
      model_2 = TimeDistributed(Dense(HID, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer="adam", loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

  #---------Fit Model-----------------
    model = create_model(HID)
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "Hidden": HID ,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/12
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2974: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 269s 29ms/step - loss: 39.3904 - crf_viterbi_accuracy: 0.8715 - val_loss: 39.3840 - val_crf_viterbi_accuracy: 0.9186
# Epoch 2/20
# 9360/9360 [==============================] - 264s 28ms/step - loss: 39.1046 - crf_viterbi_accuracy: 0.9339 - val_loss: 39.3182 - val_crf_viterbi_accuracy: 0.9395
# Epoch 3/20
# 9360/9360 [==============================] - 266s 28ms/step - loss: 39.0595 - crf_viterbi_accuracy: 0.9443 - val_loss: 39.2866 - val_crf_viterbi_accuracy: 0.9483
# Epoch 4/20
# 9360/9360 [==============================] - 262s 28ms/step - loss: 39.0288 - crf_viterbi_accuracy: 0.9529 - val_loss: 39.2685 - val_crf_viterbi_accuracy: 0.9518
# Epoch 5/20
# 9360/9360 [==============================] - 264s 28ms/step - loss: 39.0091 - crf_viterbi_accuracy: 0.9582 - val_loss: 39.2553 - val_crf_viterbi_accuracy: 0.9540
# Epoch 6/20
# 9360/9360 [==============================] - 262s 28ms/step - loss: 38.9938 - crf_viterbi_accuracy: 0.9622 - val_loss: 39.2409 - val_crf_viterbi_accuracy: 0.9594
# Epoch 7/20
# 9360/9360 [==============================] - 266s 28ms/step - loss: 38.9799 - crf_viterbi_accuracy: 0.9660 - val_loss: 39.2280 - val_crf_viterbi_accuracy: 0.9622
# Epoch 8/20
# 9360/9360 [==============================] - 264s 28ms/step - loss: 38.9710 - crf_viterbi_accuracy: 0.9691 - val_loss: 39.2261 - val_crf_viterbi_accuracy: 0.9629
# Epoch 9/20
# 9360/9360 [==============================] - 264s 28ms/step - loss: 38.9624 - crf_viterbi_accuracy: 0.9708 - val_loss: 39.2220 - val_crf_viterbi_accuracy: 0.9650
# Epoch 10/20
# 9360/9360 [==============================] - 260s 28ms/step - loss: 38.9547 - crf_viterbi_accuracy: 0.9739 - val_loss: 39.2174 - val_crf_viterbi_accuracy: 0.9661
# Epoch 11/20
# 9360/9360 [==============================] - 261s 28ms/step - loss: 38.9485 - crf_viterbi_accuracy: 0.9757 - val_loss: 39.2161 - val_crf_viterbi_accuracy: 0.9671
# Epoch 12/20
# 9360/9360 [==============================] - 265s 28ms/step - loss: 38.9430 - crf_viterbi_accuracy: 0.9772 - val_loss: 39.2133 - val_crf_viterbi_accuracy: 0.9668
# Epoch 13/20
# 9360/9360 [==============================] - 269s 29ms/step - loss: 38.9380 - crf_viterbi_accuracy: 0.9786 - val_loss: 39.2152 - val_crf_viterbi_accuracy: 0.9673
# Epoch 14/20
# 9360/9360 [==============================] - 268s 29ms/step - loss: 38.9345 - crf_viterbi_accuracy: 0.9796 - val_loss: 39.2144 - val_crf_viterbi_accuracy: 0.9665
# FOLD Number: 2/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 272s 29ms/step - loss: 39.3674 - crf_viterbi_accuracy: 0.8692 - val_loss: 39.3613 - val_crf_viterbi_accuracy: 0.9290
# Epoch 2/20
# 9361/9361 [==============================] - 271s 29ms/step - loss: 39.0932 - crf_viterbi_accuracy: 0.9350 - val_loss: 39.3016 - val_crf_viterbi_accuracy: 0.9456
# Epoch 3/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.0436 - crf_viterbi_accuracy: 0.9494 - val_loss: 39.2690 - val_crf_viterbi_accuracy: 0.9544
# Epoch 4/20
# 9361/9361 [==============================] - 271s 29ms/step - loss: 39.0138 - crf_viterbi_accuracy: 0.9567 - val_loss: 39.2516 - val_crf_viterbi_accuracy: 0.9598
# Epoch 5/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 38.9947 - crf_viterbi_accuracy: 0.9618 - val_loss: 39.2405 - val_crf_viterbi_accuracy: 0.9622
# Epoch 6/20
# 9361/9361 [==============================] - 272s 29ms/step - loss: 38.9796 - crf_viterbi_accuracy: 0.9658 - val_loss: 39.2377 - val_crf_viterbi_accuracy: 0.9627
# Epoch 7/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 38.9686 - crf_viterbi_accuracy: 0.9691 - val_loss: 39.2246 - val_crf_viterbi_accuracy: 0.9647
# Epoch 8/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 38.9587 - crf_viterbi_accuracy: 0.9722 - val_loss: 39.2279 - val_crf_viterbi_accuracy: 0.9592
# Epoch 9/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 38.9503 - crf_viterbi_accuracy: 0.9751 - val_loss: 39.2144 - val_crf_viterbi_accuracy: 0.9694
# Epoch 10/20
# 9361/9361 [==============================] - 272s 29ms/step - loss: 38.9428 - crf_viterbi_accuracy: 0.9765 - val_loss: 39.2192 - val_crf_viterbi_accuracy: 0.9670
# Epoch 11/20
# 9361/9361 [==============================] - 270s 29ms/step - loss: 38.9376 - crf_viterbi_accuracy: 0.9790 - val_loss: 39.2185 - val_crf_viterbi_accuracy: 0.9676
# FOLD Number: 3/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 39.5397 - crf_viterbi_accuracy: 0.8901 - val_loss: 38.8934 - val_crf_viterbi_accuracy: 0.9324
# Epoch 2/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.3071 - crf_viterbi_accuracy: 0.9392 - val_loss: 38.8478 - val_crf_viterbi_accuracy: 0.9452
# Epoch 3/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.2628 - crf_viterbi_accuracy: 0.9508 - val_loss: 38.8167 - val_crf_viterbi_accuracy: 0.9520
# Epoch 4/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.2386 - crf_viterbi_accuracy: 0.9577 - val_loss: 38.7956 - val_crf_viterbi_accuracy: 0.9590
# Epoch 5/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.2179 - crf_viterbi_accuracy: 0.9634 - val_loss: 38.7831 - val_crf_viterbi_accuracy: 0.9625
# Epoch 6/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.2027 - crf_viterbi_accuracy: 0.9668 - val_loss: 38.7797 - val_crf_viterbi_accuracy: 0.9626
# Epoch 7/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.1932 - crf_viterbi_accuracy: 0.9696 - val_loss: 38.7722 - val_crf_viterbi_accuracy: 0.9655
# Epoch 8/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1845 - crf_viterbi_accuracy: 0.9732 - val_loss: 38.7661 - val_crf_viterbi_accuracy: 0.9683
# Epoch 9/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1757 - crf_viterbi_accuracy: 0.9752 - val_loss: 38.7653 - val_crf_viterbi_accuracy: 0.9665
# Epoch 10/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1693 - crf_viterbi_accuracy: 0.9775 - val_loss: 38.7636 - val_crf_viterbi_accuracy: 0.9666
# Epoch 11/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1631 - crf_viterbi_accuracy: 0.9792 - val_loss: 38.7628 - val_crf_viterbi_accuracy: 0.9684
# Epoch 12/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1581 - crf_viterbi_accuracy: 0.9811 - val_loss: 38.7604 - val_crf_viterbi_accuracy: 0.9687
# Epoch 13/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.1533 - crf_viterbi_accuracy: 0.9834 - val_loss: 38.7648 - val_crf_viterbi_accuracy: 0.9672
# Epoch 14/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.1499 - crf_viterbi_accuracy: 0.9851 - val_loss: 38.7636 - val_crf_viterbi_accuracy: 0.9682
# FOLD Number: 4/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 39.3131 - crf_viterbi_accuracy: 0.8918 - val_loss: 39.3312 - val_crf_viterbi_accuracy: 0.9342
# Epoch 2/20
# 9360/9360 [==============================] - 275s 29ms/step - loss: 39.0707 - crf_viterbi_accuracy: 0.9403 - val_loss: 39.2784 - val_crf_viterbi_accuracy: 0.9478
# Epoch 3/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 39.0276 - crf_viterbi_accuracy: 0.9532 - val_loss: 39.2581 - val_crf_viterbi_accuracy: 0.9530
# Epoch 4/20
# 9360/9360 [==============================] - 272s 29ms/step - loss: 39.0032 - crf_viterbi_accuracy: 0.9588 - val_loss: 39.2434 - val_crf_viterbi_accuracy: 0.9575
# Epoch 5/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 38.9857 - crf_viterbi_accuracy: 0.9635 - val_loss: 39.2328 - val_crf_viterbi_accuracy: 0.9607
# Epoch 6/20
# 9360/9360 [==============================] - 276s 29ms/step - loss: 38.9734 - crf_viterbi_accuracy: 0.9674 - val_loss: 39.2273 - val_crf_viterbi_accuracy: 0.9629
# Epoch 7/20
# 9360/9360 [==============================] - 275s 29ms/step - loss: 38.9625 - crf_viterbi_accuracy: 0.9706 - val_loss: 39.2198 - val_crf_viterbi_accuracy: 0.9647
# Epoch 8/20
# 9360/9360 [==============================] - 275s 29ms/step - loss: 38.9548 - crf_viterbi_accuracy: 0.9732 - val_loss: 39.2164 - val_crf_viterbi_accuracy: 0.9655
# Epoch 9/20
# 9360/9360 [==============================] - 275s 29ms/step - loss: 38.9477 - crf_viterbi_accuracy: 0.9752 - val_loss: 39.2125 - val_crf_viterbi_accuracy: 0.9674
# Epoch 10/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 38.9407 - crf_viterbi_accuracy: 0.9779 - val_loss: 39.2133 - val_crf_viterbi_accuracy: 0.9675
# Epoch 11/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 38.9369 - crf_viterbi_accuracy: 0.9788 - val_loss: 39.2129 - val_crf_viterbi_accuracy: 0.9677
# FOLD Number: 5/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 39.2823 - crf_viterbi_accuracy: 0.8965 - val_loss: 39.3296 - val_crf_viterbi_accuracy: 0.9371
# Epoch 2/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 39.0679 - crf_viterbi_accuracy: 0.9428 - val_loss: 39.2816 - val_crf_viterbi_accuracy: 0.9520
# Epoch 3/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 39.0268 - crf_viterbi_accuracy: 0.9543 - val_loss: 39.2570 - val_crf_viterbi_accuracy: 0.9581
# Epoch 4/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 39.0025 - crf_viterbi_accuracy: 0.9608 - val_loss: 39.2437 - val_crf_viterbi_accuracy: 0.9615
# Epoch 5/20
# 9361/9361 [==============================] - 276s 30ms/step - loss: 38.9854 - crf_viterbi_accuracy: 0.9645 - val_loss: 39.2350 - val_crf_viterbi_accuracy: 0.9629
# Epoch 6/20
# 9361/9361 [==============================] - 276s 30ms/step - loss: 38.9713 - crf_viterbi_accuracy: 0.9683 - val_loss: 39.2281 - val_crf_viterbi_accuracy: 0.9655
# Epoch 7/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9620 - crf_viterbi_accuracy: 0.9710 - val_loss: 39.2223 - val_crf_viterbi_accuracy: 0.9675
# Epoch 8/20
# 9361/9361 [==============================] - 276s 30ms/step - loss: 38.9522 - crf_viterbi_accuracy: 0.9735 - val_loss: 39.2233 - val_crf_viterbi_accuracy: 0.9673
# Epoch 9/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9448 - crf_viterbi_accuracy: 0.9761 - val_loss: 39.2204 - val_crf_viterbi_accuracy: 0.9666
# Epoch 10/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 38.9393 - crf_viterbi_accuracy: 0.9777 - val_loss: 39.2176 - val_crf_viterbi_accuracy: 0.9679
# Epoch 11/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 38.9334 - crf_viterbi_accuracy: 0.9799 - val_loss: 39.2161 - val_crf_viterbi_accuracy: 0.9688
# Epoch 12/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9286 - crf_viterbi_accuracy: 0.9818 - val_loss: 39.2196 - val_crf_viterbi_accuracy: 0.9683
# Epoch 13/20
# 9361/9361 [==============================] - 278s 30ms/step - loss: 38.9254 - crf_viterbi_accuracy: 0.9831 - val_loss: 39.2144 - val_crf_viterbi_accuracy: 0.9717
# Epoch 14/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9215 - crf_viterbi_accuracy: 0.9845 - val_loss: 39.2160 - val_crf_viterbi_accuracy: 0.9713
# Epoch 15/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9177 - crf_viterbi_accuracy: 0.9864 - val_loss: 39.2208 - val_crf_viterbi_accuracy: 0.9679
# FOLD Number: 6/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.5144 - crf_viterbi_accuracy: 0.8990 - val_loss: 38.8803 - val_crf_viterbi_accuracy: 0.9349
# Epoch 2/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.2926 - crf_viterbi_accuracy: 0.9432 - val_loss: 38.8314 - val_crf_viterbi_accuracy: 0.9504
# Epoch 3/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 39.2530 - crf_viterbi_accuracy: 0.9542 - val_loss: 38.8081 - val_crf_viterbi_accuracy: 0.9564
# Epoch 4/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.2268 - crf_viterbi_accuracy: 0.9602 - val_loss: 38.7938 - val_crf_viterbi_accuracy: 0.9591
# Epoch 5/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 39.2104 - crf_viterbi_accuracy: 0.9647 - val_loss: 38.7814 - val_crf_viterbi_accuracy: 0.9617
# Epoch 6/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1973 - crf_viterbi_accuracy: 0.9685 - val_loss: 38.7754 - val_crf_viterbi_accuracy: 0.9638
# Epoch 7/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1865 - crf_viterbi_accuracy: 0.9716 - val_loss: 38.7667 - val_crf_viterbi_accuracy: 0.9666
# Epoch 8/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1787 - crf_viterbi_accuracy: 0.9738 - val_loss: 38.7680 - val_crf_viterbi_accuracy: 0.9662
# Epoch 9/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1710 - crf_viterbi_accuracy: 0.9769 - val_loss: 38.7655 - val_crf_viterbi_accuracy: 0.9676
# Epoch 10/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1645 - crf_viterbi_accuracy: 0.9790 - val_loss: 38.7649 - val_crf_viterbi_accuracy: 0.9669
# Epoch 11/20
# 9361/9361 [==============================] - 272s 29ms/step - loss: 39.1588 - crf_viterbi_accuracy: 0.9808 - val_loss: 38.7645 - val_crf_viterbi_accuracy: 0.9677
# Epoch 12/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1550 - crf_viterbi_accuracy: 0.9825 - val_loss: 38.7602 - val_crf_viterbi_accuracy: 0.9708
# Epoch 13/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1511 - crf_viterbi_accuracy: 0.9836 - val_loss: 38.7696 - val_crf_viterbi_accuracy: 0.9671
# Epoch 14/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1485 - crf_viterbi_accuracy: 0.9850 - val_loss: 38.7634 - val_crf_viterbi_accuracy: 0.9686
# FOLD Number: 7/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 39.2738 - crf_viterbi_accuracy: 0.8966 - val_loss: 39.3349 - val_crf_viterbi_accuracy: 0.9357
# Epoch 2/20
# 9360/9360 [==============================] - 272s 29ms/step - loss: 39.0696 - crf_viterbi_accuracy: 0.9432 - val_loss: 39.2806 - val_crf_viterbi_accuracy: 0.9503
# Epoch 3/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 39.0262 - crf_viterbi_accuracy: 0.9550 - val_loss: 39.2623 - val_crf_viterbi_accuracy: 0.9536
# Epoch 4/20
# 9360/9360 [==============================] - 272s 29ms/step - loss: 39.0007 - crf_viterbi_accuracy: 0.9616 - val_loss: 39.2384 - val_crf_viterbi_accuracy: 0.9615
# Epoch 5/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 38.9821 - crf_viterbi_accuracy: 0.9662 - val_loss: 39.2285 - val_crf_viterbi_accuracy: 0.9628
# Epoch 6/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 38.9687 - crf_viterbi_accuracy: 0.9695 - val_loss: 39.2254 - val_crf_viterbi_accuracy: 0.9643
# Epoch 7/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 38.9592 - crf_viterbi_accuracy: 0.9724 - val_loss: 39.2183 - val_crf_viterbi_accuracy: 0.9664
# Epoch 8/20
# 9360/9360 [==============================] - 275s 29ms/step - loss: 38.9505 - crf_viterbi_accuracy: 0.9750 - val_loss: 39.2185 - val_crf_viterbi_accuracy: 0.9641
# Epoch 9/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 38.9434 - crf_viterbi_accuracy: 0.9772 - val_loss: 39.2193 - val_crf_viterbi_accuracy: 0.9678
# FOLD Number: 8/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 39.2485 - crf_viterbi_accuracy: 0.9010 - val_loss: 39.3169 - val_crf_viterbi_accuracy: 0.9413
# Epoch 2/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.0546 - crf_viterbi_accuracy: 0.9449 - val_loss: 39.2767 - val_crf_viterbi_accuracy: 0.9522
# Epoch 3/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.0154 - crf_viterbi_accuracy: 0.9562 - val_loss: 39.2592 - val_crf_viterbi_accuracy: 0.9562
# Epoch 4/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 38.9928 - crf_viterbi_accuracy: 0.9616 - val_loss: 39.2370 - val_crf_viterbi_accuracy: 0.9622
# Epoch 5/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 38.9768 - crf_viterbi_accuracy: 0.9659 - val_loss: 39.2305 - val_crf_viterbi_accuracy: 0.9628
# Epoch 6/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 38.9650 - crf_viterbi_accuracy: 0.9690 - val_loss: 39.2257 - val_crf_viterbi_accuracy: 0.9654
# Epoch 7/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 38.9551 - crf_viterbi_accuracy: 0.9719 - val_loss: 39.2171 - val_crf_viterbi_accuracy: 0.9677
# Epoch 8/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 38.9453 - crf_viterbi_accuracy: 0.9752 - val_loss: 39.2247 - val_crf_viterbi_accuracy: 0.9620
# Epoch 9/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 38.9401 - crf_viterbi_accuracy: 0.9769 - val_loss: 39.2131 - val_crf_viterbi_accuracy: 0.9695
# Epoch 10/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 38.9337 - crf_viterbi_accuracy: 0.9785 - val_loss: 39.2200 - val_crf_viterbi_accuracy: 0.9677
# Epoch 11/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 38.9282 - crf_viterbi_accuracy: 0.9811 - val_loss: 39.2183 - val_crf_viterbi_accuracy: 0.9694
# FOLD Number: 9/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 39.4796 - crf_viterbi_accuracy: 0.9002 - val_loss: 38.8785 - val_crf_viterbi_accuracy: 0.9354
# Epoch 2/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.2883 - crf_viterbi_accuracy: 0.9447 - val_loss: 38.8321 - val_crf_viterbi_accuracy: 0.9501
# Epoch 3/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.2477 - crf_viterbi_accuracy: 0.9557 - val_loss: 38.8088 - val_crf_viterbi_accuracy: 0.9544
# Epoch 4/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.2236 - crf_viterbi_accuracy: 0.9617 - val_loss: 38.7909 - val_crf_viterbi_accuracy: 0.9601
# Epoch 5/20
# 9361/9361 [==============================] - 272s 29ms/step - loss: 39.2073 - crf_viterbi_accuracy: 0.9657 - val_loss: 38.7809 - val_crf_viterbi_accuracy: 0.9619
# Epoch 6/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.1963 - crf_viterbi_accuracy: 0.9683 - val_loss: 38.7785 - val_crf_viterbi_accuracy: 0.9632
# Epoch 7/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.1854 - crf_viterbi_accuracy: 0.9712 - val_loss: 38.7705 - val_crf_viterbi_accuracy: 0.9659
# Epoch 8/20
# 9361/9361 [==============================] - 272s 29ms/step - loss: 39.1773 - crf_viterbi_accuracy: 0.9741 - val_loss: 38.7657 - val_crf_viterbi_accuracy: 0.9675
# Epoch 9/20
# 9361/9361 [==============================] - 272s 29ms/step - loss: 39.1693 - crf_viterbi_accuracy: 0.9764 - val_loss: 38.7646 - val_crf_viterbi_accuracy: 0.9682
# Epoch 10/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 39.1629 - crf_viterbi_accuracy: 0.9788 - val_loss: 38.7633 - val_crf_viterbi_accuracy: 0.9685
# Epoch 11/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 39.1587 - crf_viterbi_accuracy: 0.9799 - val_loss: 38.7686 - val_crf_viterbi_accuracy: 0.9666
# Epoch 12/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1532 - crf_viterbi_accuracy: 0.9830 - val_loss: 38.7647 - val_crf_viterbi_accuracy: 0.9688
# FOLD Number: 10/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 284s 30ms/step - loss: 39.2256 - crf_viterbi_accuracy: 0.9070 - val_loss: 39.3206 - val_crf_viterbi_accuracy: 0.9345
# Epoch 2/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 39.0518 - crf_viterbi_accuracy: 0.9475 - val_loss: 39.2739 - val_crf_viterbi_accuracy: 0.9514
# Epoch 3/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 39.0142 - crf_viterbi_accuracy: 0.9579 - val_loss: 39.2457 - val_crf_viterbi_accuracy: 0.9591
# Epoch 4/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 38.9925 - crf_viterbi_accuracy: 0.9632 - val_loss: 39.2357 - val_crf_viterbi_accuracy: 0.9608
# Epoch 5/20
# 9360/9360 [==============================] - 276s 29ms/step - loss: 38.9755 - crf_viterbi_accuracy: 0.9676 - val_loss: 39.2258 - val_crf_viterbi_accuracy: 0.9633
# Epoch 6/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 38.9641 - crf_viterbi_accuracy: 0.9701 - val_loss: 39.2297 - val_crf_viterbi_accuracy: 0.9562
# Epoch 7/20
# 9360/9360 [==============================] - 273s 29ms/step - loss: 38.9544 - crf_viterbi_accuracy: 0.9735 - val_loss: 39.2126 - val_crf_viterbi_accuracy: 0.9679
# Epoch 8/20
# 9360/9360 [==============================] - 272s 29ms/step - loss: 38.9453 - crf_viterbi_accuracy: 0.9766 - val_loss: 39.2131 - val_crf_viterbi_accuracy: 0.9678
# Epoch 9/20
# 9360/9360 [==============================] - 272s 29ms/step - loss: 38.9394 - crf_viterbi_accuracy: 0.9784 - val_loss: 39.2090 - val_crf_viterbi_accuracy: 0.9688
# Epoch 10/20
# 9360/9360 [==============================] - 272s 29ms/step - loss: 38.9334 - crf_viterbi_accuracy: 0.9803 - val_loss: 39.2135 - val_crf_viterbi_accuracy: 0.9637
# Epoch 11/20
# 9360/9360 [==============================] - 272s 29ms/step - loss: 38.9289 - crf_viterbi_accuracy: 0.9816 - val_loss: 39.2088 - val_crf_viterbi_accuracy: 0.9698
# Epoch 12/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 38.9247 - crf_viterbi_accuracy: 0.9831 - val_loss: 39.2094 - val_crf_viterbi_accuracy: 0.9699
# Epoch 13/20
# 9360/9360 [==============================] - 278s 30ms/step - loss: 38.9190 - crf_viterbi_accuracy: 0.9854 - val_loss: 39.2137 - val_crf_viterbi_accuracy: 0.9684
# FOLD Number: 11/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 289s 31ms/step - loss: 39.2255 - crf_viterbi_accuracy: 0.9054 - val_loss: 39.3149 - val_crf_viterbi_accuracy: 0.9434
# Epoch 2/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 39.0512 - crf_viterbi_accuracy: 0.9471 - val_loss: 39.2709 - val_crf_viterbi_accuracy: 0.9542
# Epoch 3/20
# 9361/9361 [==============================] - 278s 30ms/step - loss: 39.0127 - crf_viterbi_accuracy: 0.9572 - val_loss: 39.2469 - val_crf_viterbi_accuracy: 0.9599
# Epoch 4/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9891 - crf_viterbi_accuracy: 0.9636 - val_loss: 39.2411 - val_crf_viterbi_accuracy: 0.9615
# Epoch 5/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9737 - crf_viterbi_accuracy: 0.9672 - val_loss: 39.2291 - val_crf_viterbi_accuracy: 0.9648
# Epoch 6/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 38.9623 - crf_viterbi_accuracy: 0.9708 - val_loss: 39.2227 - val_crf_viterbi_accuracy: 0.9673
# Epoch 7/20
# 9361/9361 [==============================] - 278s 30ms/step - loss: 38.9512 - crf_viterbi_accuracy: 0.9736 - val_loss: 39.2174 - val_crf_viterbi_accuracy: 0.9691
# Epoch 8/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 38.9431 - crf_viterbi_accuracy: 0.9757 - val_loss: 39.2158 - val_crf_viterbi_accuracy: 0.9696
# Epoch 9/20
# 9361/9361 [==============================] - 276s 30ms/step - loss: 38.9369 - crf_viterbi_accuracy: 0.9781 - val_loss: 39.2174 - val_crf_viterbi_accuracy: 0.9680
# Epoch 10/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 38.9320 - crf_viterbi_accuracy: 0.9799 - val_loss: 39.2139 - val_crf_viterbi_accuracy: 0.9710
# Epoch 11/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 38.9263 - crf_viterbi_accuracy: 0.9822 - val_loss: 39.2166 - val_crf_viterbi_accuracy: 0.9716
# Epoch 12/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 38.9218 - crf_viterbi_accuracy: 0.9840 - val_loss: 39.2156 - val_crf_viterbi_accuracy: 0.9714
# FOLD Number: 12/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 285s 30ms/step - loss: 39.4428 - crf_viterbi_accuracy: 0.9090 - val_loss: 38.8616 - val_crf_viterbi_accuracy: 0.9416
# Epoch 2/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.2763 - crf_viterbi_accuracy: 0.9478 - val_loss: 38.8187 - val_crf_viterbi_accuracy: 0.9540
# Epoch 3/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.2394 - crf_viterbi_accuracy: 0.9580 - val_loss: 38.7971 - val_crf_viterbi_accuracy: 0.9572
# Epoch 4/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.2169 - crf_viterbi_accuracy: 0.9635 - val_loss: 38.7860 - val_crf_viterbi_accuracy: 0.9603
# Epoch 5/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.2015 - crf_viterbi_accuracy: 0.9675 - val_loss: 38.7744 - val_crf_viterbi_accuracy: 0.9635
# Epoch 6/20
# 9361/9361 [==============================] - 273s 29ms/step - loss: 39.1890 - crf_viterbi_accuracy: 0.9709 - val_loss: 38.7691 - val_crf_viterbi_accuracy: 0.9670
# Epoch 7/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1785 - crf_viterbi_accuracy: 0.9739 - val_loss: 38.7658 - val_crf_viterbi_accuracy: 0.9660
# Epoch 8/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1706 - crf_viterbi_accuracy: 0.9763 - val_loss: 38.7675 - val_crf_viterbi_accuracy: 0.9649
# Epoch 9/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1650 - crf_viterbi_accuracy: 0.9780 - val_loss: 38.7610 - val_crf_viterbi_accuracy: 0.9678
# Epoch 10/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.1584 - crf_viterbi_accuracy: 0.9801 - val_loss: 38.7650 - val_crf_viterbi_accuracy: 0.9684
# Epoch 11/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 39.1534 - crf_viterbi_accuracy: 0.9824 - val_loss: 38.7636 - val_crf_viterbi_accuracy: 0.9693
# CPU times: user 16h 16min 30s, sys: 1h 20min 5s, total: 17h 36min 36s
# Wall time: 11h 13min 7s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("Hidden").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#         train_loss  train_acc   val_loss   val_acc     epochs
# Hidden
# 100      38.998081   0.983920  39.064300  0.969711  12.000000
# 50       39.008258   0.980433  39.067453  0.968657  10.666667
# 20       39.001008   0.983410  39.065706  0.968087  13.333333
# 10       39.007336   0.981244  39.065493  0.967430  13.000000

# %%
from google.colab import files
df_results.to_csv('Hidden_grid_Glove.csv')
files.download('Hidden_grid_Glove.csv')
