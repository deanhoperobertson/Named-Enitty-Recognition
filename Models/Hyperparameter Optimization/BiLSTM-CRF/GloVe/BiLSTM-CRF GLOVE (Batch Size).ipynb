# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/GloVe/BiLSTM-CRF%20GLOVE%20(Batch%20Size).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-5mgovoj9
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-5mgovoj9
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=0c7d372f6a5e6718f61929458fbba3ad94a731aec15ef42a06c2d0cb985514ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2qm6yt81/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Requirement already satisfied: sklearn_crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_path = "/content/drive/My Drive/glove.6B.50d.txt"
#root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
BATCHES= [256,128,64,32]
EPOCHS=20
fold_count = 1


for BATCH_SIZE in BATCHES:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(BATCHES)*3))
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(opt='adam'):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=100, return_sequences=True,
                                recurrent_dropout=0.1, dropout=0.1))(model_2)
      model_2 = TimeDistributed(Dense(20, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer=opt, loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

    #---------Fit Model-----------------
    model = create_model()
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "batch size": BATCH_SIZE,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 27s 3ms/step - loss: 39.8927 - crf_viterbi_accuracy: 0.8030 - val_loss: 39.7911 - val_crf_viterbi_accuracy: 0.8355
# Epoch 2/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.4294 - crf_viterbi_accuracy: 0.8607 - val_loss: 39.5325 - val_crf_viterbi_accuracy: 0.8838
# Epoch 3/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.2345 - crf_viterbi_accuracy: 0.8996 - val_loss: 39.4149 - val_crf_viterbi_accuracy: 0.9086
# Epoch 4/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.1605 - crf_viterbi_accuracy: 0.9158 - val_loss: 39.3723 - val_crf_viterbi_accuracy: 0.9213
# Epoch 5/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.1280 - crf_viterbi_accuracy: 0.9253 - val_loss: 39.3484 - val_crf_viterbi_accuracy: 0.9265
# Epoch 6/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.1039 - crf_viterbi_accuracy: 0.9314 - val_loss: 39.3284 - val_crf_viterbi_accuracy: 0.9340
# Epoch 7/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0860 - crf_viterbi_accuracy: 0.9372 - val_loss: 39.3133 - val_crf_viterbi_accuracy: 0.9380
# Epoch 8/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0716 - crf_viterbi_accuracy: 0.9406 - val_loss: 39.3022 - val_crf_viterbi_accuracy: 0.9408
# Epoch 9/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0583 - crf_viterbi_accuracy: 0.9454 - val_loss: 39.2904 - val_crf_viterbi_accuracy: 0.9444
# Epoch 10/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0479 - crf_viterbi_accuracy: 0.9484 - val_loss: 39.2826 - val_crf_viterbi_accuracy: 0.9462
# Epoch 11/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0384 - crf_viterbi_accuracy: 0.9510 - val_loss: 39.2745 - val_crf_viterbi_accuracy: 0.9483
# Epoch 12/20
# 9360/9360 [==============================] - 25s 3ms/step - loss: 39.0289 - crf_viterbi_accuracy: 0.9534 - val_loss: 39.2660 - val_crf_viterbi_accuracy: 0.9509
# Epoch 13/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0219 - crf_viterbi_accuracy: 0.9556 - val_loss: 39.2619 - val_crf_viterbi_accuracy: 0.9524
# Epoch 14/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0145 - crf_viterbi_accuracy: 0.9576 - val_loss: 39.2566 - val_crf_viterbi_accuracy: 0.9536
# Epoch 15/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0085 - crf_viterbi_accuracy: 0.9594 - val_loss: 39.2527 - val_crf_viterbi_accuracy: 0.9548
# Epoch 16/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 39.0023 - crf_viterbi_accuracy: 0.9614 - val_loss: 39.2521 - val_crf_viterbi_accuracy: 0.9549
# Epoch 17/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 38.9975 - crf_viterbi_accuracy: 0.9622 - val_loss: 39.2452 - val_crf_viterbi_accuracy: 0.9570
# Epoch 18/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 38.9939 - crf_viterbi_accuracy: 0.9631 - val_loss: 39.2410 - val_crf_viterbi_accuracy: 0.9583
# Epoch 19/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 38.9891 - crf_viterbi_accuracy: 0.9644 - val_loss: 39.2375 - val_crf_viterbi_accuracy: 0.9587
# Epoch 20/20
# 9360/9360 [==============================] - 24s 3ms/step - loss: 38.9851 - crf_viterbi_accuracy: 0.9659 - val_loss: 39.2357 - val_crf_viterbi_accuracy: 0.9593
# FOLD Number: 2/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 27s 3ms/step - loss: 39.9681 - crf_viterbi_accuracy: 0.7628 - val_loss: 39.8069 - val_crf_viterbi_accuracy: 0.8316
# Epoch 2/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.4856 - crf_viterbi_accuracy: 0.8489 - val_loss: 39.5873 - val_crf_viterbi_accuracy: 0.8775
# Epoch 3/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.2807 - crf_viterbi_accuracy: 0.8923 - val_loss: 39.4313 - val_crf_viterbi_accuracy: 0.9102
# Epoch 4/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.1741 - crf_viterbi_accuracy: 0.9147 - val_loss: 39.3737 - val_crf_viterbi_accuracy: 0.9248
# Epoch 5/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.1332 - crf_viterbi_accuracy: 0.9245 - val_loss: 39.3475 - val_crf_viterbi_accuracy: 0.9309
# Epoch 6/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.1078 - crf_viterbi_accuracy: 0.9312 - val_loss: 39.3314 - val_crf_viterbi_accuracy: 0.9355
# Epoch 7/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0892 - crf_viterbi_accuracy: 0.9373 - val_loss: 39.3140 - val_crf_viterbi_accuracy: 0.9415
# Epoch 8/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0731 - crf_viterbi_accuracy: 0.9419 - val_loss: 39.3020 - val_crf_viterbi_accuracy: 0.9450
# Epoch 9/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0608 - crf_viterbi_accuracy: 0.9450 - val_loss: 39.2913 - val_crf_viterbi_accuracy: 0.9477
# Epoch 10/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0489 - crf_viterbi_accuracy: 0.9479 - val_loss: 39.2840 - val_crf_viterbi_accuracy: 0.9501
# Epoch 11/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0397 - crf_viterbi_accuracy: 0.9508 - val_loss: 39.2767 - val_crf_viterbi_accuracy: 0.9526
# Epoch 12/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0316 - crf_viterbi_accuracy: 0.9534 - val_loss: 39.2719 - val_crf_viterbi_accuracy: 0.9526
# Epoch 13/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0232 - crf_viterbi_accuracy: 0.9557 - val_loss: 39.2645 - val_crf_viterbi_accuracy: 0.9560
# Epoch 14/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0165 - crf_viterbi_accuracy: 0.9576 - val_loss: 39.2600 - val_crf_viterbi_accuracy: 0.9567
# Epoch 15/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0087 - crf_viterbi_accuracy: 0.9597 - val_loss: 39.2558 - val_crf_viterbi_accuracy: 0.9580
# Epoch 16/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0030 - crf_viterbi_accuracy: 0.9614 - val_loss: 39.2519 - val_crf_viterbi_accuracy: 0.9588
# Epoch 17/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9984 - crf_viterbi_accuracy: 0.9621 - val_loss: 39.2494 - val_crf_viterbi_accuracy: 0.9586
# Epoch 18/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9938 - crf_viterbi_accuracy: 0.9631 - val_loss: 39.2458 - val_crf_viterbi_accuracy: 0.9602
# Epoch 19/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 38.9892 - crf_viterbi_accuracy: 0.9650 - val_loss: 39.2438 - val_crf_viterbi_accuracy: 0.9605
# Epoch 20/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 38.9857 - crf_viterbi_accuracy: 0.9659 - val_loss: 39.2400 - val_crf_viterbi_accuracy: 0.9616
# FOLD Number: 3/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 28s 3ms/step - loss: 40.2786 - crf_viterbi_accuracy: 0.7734 - val_loss: 39.3842 - val_crf_viterbi_accuracy: 0.8311
# Epoch 2/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.6869 - crf_viterbi_accuracy: 0.8591 - val_loss: 39.0903 - val_crf_viterbi_accuracy: 0.8820
# Epoch 3/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.4758 - crf_viterbi_accuracy: 0.8991 - val_loss: 38.9792 - val_crf_viterbi_accuracy: 0.9048
# Epoch 4/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.3991 - crf_viterbi_accuracy: 0.9159 - val_loss: 38.9335 - val_crf_viterbi_accuracy: 0.9200
# Epoch 5/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.3618 - crf_viterbi_accuracy: 0.9248 - val_loss: 38.9067 - val_crf_viterbi_accuracy: 0.9271
# Epoch 6/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.3389 - crf_viterbi_accuracy: 0.9303 - val_loss: 38.8875 - val_crf_viterbi_accuracy: 0.9330
# Epoch 7/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.3184 - crf_viterbi_accuracy: 0.9367 - val_loss: 38.8717 - val_crf_viterbi_accuracy: 0.9376
# Epoch 8/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.3034 - crf_viterbi_accuracy: 0.9409 - val_loss: 38.8576 - val_crf_viterbi_accuracy: 0.9418
# Epoch 9/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2897 - crf_viterbi_accuracy: 0.9445 - val_loss: 38.8472 - val_crf_viterbi_accuracy: 0.9450
# Epoch 10/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2795 - crf_viterbi_accuracy: 0.9476 - val_loss: 38.8406 - val_crf_viterbi_accuracy: 0.9455
# Epoch 11/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2692 - crf_viterbi_accuracy: 0.9510 - val_loss: 38.8312 - val_crf_viterbi_accuracy: 0.9497
# Epoch 12/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.2602 - crf_viterbi_accuracy: 0.9528 - val_loss: 38.8230 - val_crf_viterbi_accuracy: 0.9516
# Epoch 13/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2514 - crf_viterbi_accuracy: 0.9550 - val_loss: 38.8181 - val_crf_viterbi_accuracy: 0.9528
# Epoch 14/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.2455 - crf_viterbi_accuracy: 0.9570 - val_loss: 38.8125 - val_crf_viterbi_accuracy: 0.9545
# Epoch 15/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2390 - crf_viterbi_accuracy: 0.9588 - val_loss: 38.8102 - val_crf_viterbi_accuracy: 0.9542
# Epoch 16/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.2353 - crf_viterbi_accuracy: 0.9595 - val_loss: 38.8030 - val_crf_viterbi_accuracy: 0.9566
# Epoch 17/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2279 - crf_viterbi_accuracy: 0.9617 - val_loss: 38.8004 - val_crf_viterbi_accuracy: 0.9573
# Epoch 18/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2237 - crf_viterbi_accuracy: 0.9630 - val_loss: 38.7963 - val_crf_viterbi_accuracy: 0.9587
# Epoch 19/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2192 - crf_viterbi_accuracy: 0.9643 - val_loss: 38.7940 - val_crf_viterbi_accuracy: 0.9590
# Epoch 20/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2151 - crf_viterbi_accuracy: 0.9654 - val_loss: 38.7904 - val_crf_viterbi_accuracy: 0.9603
# FOLD Number: 4/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 54s 6ms/step - loss: 39.8768 - crf_viterbi_accuracy: 0.7680 - val_loss: 39.5757 - val_crf_viterbi_accuracy: 0.8877
# Epoch 2/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.2443 - crf_viterbi_accuracy: 0.9048 - val_loss: 39.4137 - val_crf_viterbi_accuracy: 0.9157
# Epoch 3/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.1506 - crf_viterbi_accuracy: 0.9235 - val_loss: 39.3589 - val_crf_viterbi_accuracy: 0.9299
# Epoch 4/20
# 9360/9360 [==============================] - 48s 5ms/step - loss: 39.1092 - crf_viterbi_accuracy: 0.9341 - val_loss: 39.3290 - val_crf_viterbi_accuracy: 0.9375
# Epoch 5/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0810 - crf_viterbi_accuracy: 0.9418 - val_loss: 39.3079 - val_crf_viterbi_accuracy: 0.9426
# Epoch 6/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0602 - crf_viterbi_accuracy: 0.9473 - val_loss: 39.2900 - val_crf_viterbi_accuracy: 0.9484
# Epoch 7/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0459 - crf_viterbi_accuracy: 0.9509 - val_loss: 39.2810 - val_crf_viterbi_accuracy: 0.9498
# Epoch 8/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0336 - crf_viterbi_accuracy: 0.9544 - val_loss: 39.2699 - val_crf_viterbi_accuracy: 0.9529
# Epoch 9/20
# 9360/9360 [==============================] - 48s 5ms/step - loss: 39.0221 - crf_viterbi_accuracy: 0.9573 - val_loss: 39.2640 - val_crf_viterbi_accuracy: 0.9531
# Epoch 10/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0140 - crf_viterbi_accuracy: 0.9588 - val_loss: 39.2558 - val_crf_viterbi_accuracy: 0.9557
# Epoch 11/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0065 - crf_viterbi_accuracy: 0.9609 - val_loss: 39.2500 - val_crf_viterbi_accuracy: 0.9569
# Epoch 12/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 38.9993 - crf_viterbi_accuracy: 0.9630 - val_loss: 39.2517 - val_crf_viterbi_accuracy: 0.9557
# Epoch 13/20
# 9360/9360 [==============================] - 51s 5ms/step - loss: 38.9937 - crf_viterbi_accuracy: 0.9639 - val_loss: 39.2432 - val_crf_viterbi_accuracy: 0.9576
# Epoch 14/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 38.9885 - crf_viterbi_accuracy: 0.9651 - val_loss: 39.2372 - val_crf_viterbi_accuracy: 0.9597
# Epoch 15/20
# 9360/9360 [==============================] - 48s 5ms/step - loss: 38.9816 - crf_viterbi_accuracy: 0.9673 - val_loss: 39.2334 - val_crf_viterbi_accuracy: 0.9607
# Epoch 16/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 38.9786 - crf_viterbi_accuracy: 0.9675 - val_loss: 39.2348 - val_crf_viterbi_accuracy: 0.9609
# Epoch 17/20
# 9360/9360 [==============================] - 48s 5ms/step - loss: 38.9758 - crf_viterbi_accuracy: 0.9681 - val_loss: 39.2316 - val_crf_viterbi_accuracy: 0.9612
# Epoch 18/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 38.9718 - crf_viterbi_accuracy: 0.9693 - val_loss: 39.2291 - val_crf_viterbi_accuracy: 0.9626
# Epoch 19/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 38.9660 - crf_viterbi_accuracy: 0.9711 - val_loss: 39.2270 - val_crf_viterbi_accuracy: 0.9629
# Epoch 20/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 38.9633 - crf_viterbi_accuracy: 0.9718 - val_loss: 39.2250 - val_crf_viterbi_accuracy: 0.9632
# FOLD Number: 5/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 54s 6ms/step - loss: 39.7427 - crf_viterbi_accuracy: 0.7876 - val_loss: 39.5363 - val_crf_viterbi_accuracy: 0.8890
# Epoch 2/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2136 - crf_viterbi_accuracy: 0.9053 - val_loss: 39.3849 - val_crf_viterbi_accuracy: 0.9221
# Epoch 3/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.1322 - crf_viterbi_accuracy: 0.9262 - val_loss: 39.3448 - val_crf_viterbi_accuracy: 0.9340
# Epoch 4/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0991 - crf_viterbi_accuracy: 0.9344 - val_loss: 39.3243 - val_crf_viterbi_accuracy: 0.9397
# Epoch 5/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0732 - crf_viterbi_accuracy: 0.9414 - val_loss: 39.3032 - val_crf_viterbi_accuracy: 0.9463
# Epoch 6/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0547 - crf_viterbi_accuracy: 0.9469 - val_loss: 39.2942 - val_crf_viterbi_accuracy: 0.9477
# Epoch 7/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0410 - crf_viterbi_accuracy: 0.9508 - val_loss: 39.2774 - val_crf_viterbi_accuracy: 0.9536
# Epoch 8/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0282 - crf_viterbi_accuracy: 0.9546 - val_loss: 39.2704 - val_crf_viterbi_accuracy: 0.9549
# Epoch 9/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0179 - crf_viterbi_accuracy: 0.9573 - val_loss: 39.2637 - val_crf_viterbi_accuracy: 0.9562
# Epoch 10/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0085 - crf_viterbi_accuracy: 0.9597 - val_loss: 39.2555 - val_crf_viterbi_accuracy: 0.9584
# Epoch 11/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.0018 - crf_viterbi_accuracy: 0.9613 - val_loss: 39.2519 - val_crf_viterbi_accuracy: 0.9589
# Epoch 12/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 38.9950 - crf_viterbi_accuracy: 0.9632 - val_loss: 39.2484 - val_crf_viterbi_accuracy: 0.9595
# Epoch 13/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 38.9891 - crf_viterbi_accuracy: 0.9641 - val_loss: 39.2425 - val_crf_viterbi_accuracy: 0.9617
# Epoch 14/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 38.9836 - crf_viterbi_accuracy: 0.9654 - val_loss: 39.2387 - val_crf_viterbi_accuracy: 0.9620
# Epoch 15/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 38.9790 - crf_viterbi_accuracy: 0.9668 - val_loss: 39.2390 - val_crf_viterbi_accuracy: 0.9613
# Epoch 16/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 38.9746 - crf_viterbi_accuracy: 0.9679 - val_loss: 39.2381 - val_crf_viterbi_accuracy: 0.9618
# Epoch 17/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 38.9720 - crf_viterbi_accuracy: 0.9683 - val_loss: 39.2311 - val_crf_viterbi_accuracy: 0.9637
# Epoch 18/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 38.9664 - crf_viterbi_accuracy: 0.9703 - val_loss: 39.2281 - val_crf_viterbi_accuracy: 0.9655
# Epoch 19/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 38.9618 - crf_viterbi_accuracy: 0.9714 - val_loss: 39.2272 - val_crf_viterbi_accuracy: 0.9661
# Epoch 20/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 38.9596 - crf_viterbi_accuracy: 0.9721 - val_loss: 39.2261 - val_crf_viterbi_accuracy: 0.9658
# FOLD Number: 6/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 55s 6ms/step - loss: 39.9007 - crf_viterbi_accuracy: 0.8202 - val_loss: 39.0650 - val_crf_viterbi_accuracy: 0.8941
# Epoch 2/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.4351 - crf_viterbi_accuracy: 0.9089 - val_loss: 38.9360 - val_crf_viterbi_accuracy: 0.9223
# Epoch 3/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.3589 - crf_viterbi_accuracy: 0.9268 - val_loss: 38.9004 - val_crf_viterbi_accuracy: 0.9311
# Epoch 4/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.3231 - crf_viterbi_accuracy: 0.9365 - val_loss: 38.8682 - val_crf_viterbi_accuracy: 0.9410
# Epoch 5/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.2988 - crf_viterbi_accuracy: 0.9429 - val_loss: 38.8495 - val_crf_viterbi_accuracy: 0.9455
# Epoch 6/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.2809 - crf_viterbi_accuracy: 0.9479 - val_loss: 38.8363 - val_crf_viterbi_accuracy: 0.9486
# Epoch 7/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2659 - crf_viterbi_accuracy: 0.9521 - val_loss: 38.8326 - val_crf_viterbi_accuracy: 0.9508
# Epoch 8/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2567 - crf_viterbi_accuracy: 0.9545 - val_loss: 38.8149 - val_crf_viterbi_accuracy: 0.9545
# Epoch 9/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2454 - crf_viterbi_accuracy: 0.9569 - val_loss: 38.8083 - val_crf_viterbi_accuracy: 0.9569
# Epoch 10/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2358 - crf_viterbi_accuracy: 0.9597 - val_loss: 38.8003 - val_crf_viterbi_accuracy: 0.9582
# Epoch 11/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.2283 - crf_viterbi_accuracy: 0.9613 - val_loss: 38.7989 - val_crf_viterbi_accuracy: 0.9581
# Epoch 12/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2217 - crf_viterbi_accuracy: 0.9632 - val_loss: 38.7915 - val_crf_viterbi_accuracy: 0.9598
# Epoch 13/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2146 - crf_viterbi_accuracy: 0.9647 - val_loss: 38.7890 - val_crf_viterbi_accuracy: 0.9606
# Epoch 14/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2102 - crf_viterbi_accuracy: 0.9659 - val_loss: 38.7816 - val_crf_viterbi_accuracy: 0.9626
# Epoch 15/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2054 - crf_viterbi_accuracy: 0.9671 - val_loss: 38.7836 - val_crf_viterbi_accuracy: 0.9619
# Epoch 16/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2009 - crf_viterbi_accuracy: 0.9685 - val_loss: 38.7799 - val_crf_viterbi_accuracy: 0.9623
# Epoch 17/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.1967 - crf_viterbi_accuracy: 0.9699 - val_loss: 38.7749 - val_crf_viterbi_accuracy: 0.9649
# Epoch 18/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.1924 - crf_viterbi_accuracy: 0.9710 - val_loss: 38.7726 - val_crf_viterbi_accuracy: 0.9651
# Epoch 19/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.1889 - crf_viterbi_accuracy: 0.9720 - val_loss: 38.7692 - val_crf_viterbi_accuracy: 0.9659
# Epoch 20/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.1855 - crf_viterbi_accuracy: 0.9729 - val_loss: 38.7702 - val_crf_viterbi_accuracy: 0.9655
# FOLD Number: 7/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 104s 11ms/step - loss: 39.4831 - crf_viterbi_accuracy: 0.8584 - val_loss: 39.4048 - val_crf_viterbi_accuracy: 0.9170
# Epoch 2/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 39.1320 - crf_viterbi_accuracy: 0.9258 - val_loss: 39.3429 - val_crf_viterbi_accuracy: 0.9292
# Epoch 3/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 39.0786 - crf_viterbi_accuracy: 0.9403 - val_loss: 39.2996 - val_crf_viterbi_accuracy: 0.9429
# Epoch 4/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 39.0472 - crf_viterbi_accuracy: 0.9495 - val_loss: 39.2764 - val_crf_viterbi_accuracy: 0.9500
# Epoch 5/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 39.0274 - crf_viterbi_accuracy: 0.9546 - val_loss: 39.2649 - val_crf_viterbi_accuracy: 0.9521
# Epoch 6/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 39.0123 - crf_viterbi_accuracy: 0.9593 - val_loss: 39.2508 - val_crf_viterbi_accuracy: 0.9568
# Epoch 7/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9989 - crf_viterbi_accuracy: 0.9621 - val_loss: 39.2452 - val_crf_viterbi_accuracy: 0.9580
# Epoch 8/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9912 - crf_viterbi_accuracy: 0.9641 - val_loss: 39.2385 - val_crf_viterbi_accuracy: 0.9591
# Epoch 9/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9817 - crf_viterbi_accuracy: 0.9665 - val_loss: 39.2313 - val_crf_viterbi_accuracy: 0.9606
# Epoch 10/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9752 - crf_viterbi_accuracy: 0.9676 - val_loss: 39.2307 - val_crf_viterbi_accuracy: 0.9619
# Epoch 11/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9682 - crf_viterbi_accuracy: 0.9702 - val_loss: 39.2289 - val_crf_viterbi_accuracy: 0.9624
# Epoch 12/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9631 - crf_viterbi_accuracy: 0.9713 - val_loss: 39.2231 - val_crf_viterbi_accuracy: 0.9644
# Epoch 13/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9589 - crf_viterbi_accuracy: 0.9719 - val_loss: 39.2209 - val_crf_viterbi_accuracy: 0.9646
# Epoch 14/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9543 - crf_viterbi_accuracy: 0.9739 - val_loss: 39.2175 - val_crf_viterbi_accuracy: 0.9644
# Epoch 15/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9499 - crf_viterbi_accuracy: 0.9752 - val_loss: 39.2138 - val_crf_viterbi_accuracy: 0.9669
# Epoch 16/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9462 - crf_viterbi_accuracy: 0.9758 - val_loss: 39.2154 - val_crf_viterbi_accuracy: 0.9649
# Epoch 17/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9430 - crf_viterbi_accuracy: 0.9769 - val_loss: 39.2126 - val_crf_viterbi_accuracy: 0.9664
# Epoch 18/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9407 - crf_viterbi_accuracy: 0.9771 - val_loss: 39.2119 - val_crf_viterbi_accuracy: 0.9678
# Epoch 19/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9374 - crf_viterbi_accuracy: 0.9790 - val_loss: 39.2125 - val_crf_viterbi_accuracy: 0.9669
# Epoch 20/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 38.9349 - crf_viterbi_accuracy: 0.9797 - val_loss: 39.2139 - val_crf_viterbi_accuracy: 0.9676
# FOLD Number: 8/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 104s 11ms/step - loss: 39.5358 - crf_viterbi_accuracy: 0.8389 - val_loss: 39.4099 - val_crf_viterbi_accuracy: 0.9169
# Epoch 2/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1345 - crf_viterbi_accuracy: 0.9239 - val_loss: 39.3299 - val_crf_viterbi_accuracy: 0.9360
# Epoch 3/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.0766 - crf_viterbi_accuracy: 0.9395 - val_loss: 39.2986 - val_crf_viterbi_accuracy: 0.9444
# Epoch 4/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.0458 - crf_viterbi_accuracy: 0.9486 - val_loss: 39.2763 - val_crf_viterbi_accuracy: 0.9525
# Epoch 5/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.0255 - crf_viterbi_accuracy: 0.9540 - val_loss: 39.2632 - val_crf_viterbi_accuracy: 0.9559
# Epoch 6/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.0095 - crf_viterbi_accuracy: 0.9586 - val_loss: 39.2568 - val_crf_viterbi_accuracy: 0.9572
# Epoch 7/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 38.9990 - crf_viterbi_accuracy: 0.9609 - val_loss: 39.2470 - val_crf_viterbi_accuracy: 0.9594
# Epoch 8/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 38.9896 - crf_viterbi_accuracy: 0.9632 - val_loss: 39.2401 - val_crf_viterbi_accuracy: 0.9629
# Epoch 9/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9799 - crf_viterbi_accuracy: 0.9657 - val_loss: 39.2340 - val_crf_viterbi_accuracy: 0.9635
# Epoch 10/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9740 - crf_viterbi_accuracy: 0.9678 - val_loss: 39.2296 - val_crf_viterbi_accuracy: 0.9639
# Epoch 11/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 38.9673 - crf_viterbi_accuracy: 0.9689 - val_loss: 39.2271 - val_crf_viterbi_accuracy: 0.9655
# Epoch 12/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9631 - crf_viterbi_accuracy: 0.9703 - val_loss: 39.2205 - val_crf_viterbi_accuracy: 0.9670
# Epoch 13/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9562 - crf_viterbi_accuracy: 0.9721 - val_loss: 39.2214 - val_crf_viterbi_accuracy: 0.9658
# Epoch 14/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9525 - crf_viterbi_accuracy: 0.9738 - val_loss: 39.2218 - val_crf_viterbi_accuracy: 0.9649
# FOLD Number: 9/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 104s 11ms/step - loss: 39.8030 - crf_viterbi_accuracy: 0.8312 - val_loss: 38.9777 - val_crf_viterbi_accuracy: 0.9084
# Epoch 2/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.3741 - crf_viterbi_accuracy: 0.9222 - val_loss: 38.9027 - val_crf_viterbi_accuracy: 0.9283
# Epoch 3/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.3188 - crf_viterbi_accuracy: 0.9358 - val_loss: 38.8619 - val_crf_viterbi_accuracy: 0.9405
# Epoch 4/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.2849 - crf_viterbi_accuracy: 0.9455 - val_loss: 38.8352 - val_crf_viterbi_accuracy: 0.9494
# Epoch 5/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2639 - crf_viterbi_accuracy: 0.9518 - val_loss: 38.8202 - val_crf_viterbi_accuracy: 0.9529
# Epoch 6/20
# 9361/9361 [==============================] - 98s 10ms/step - loss: 39.2460 - crf_viterbi_accuracy: 0.9566 - val_loss: 38.8058 - val_crf_viterbi_accuracy: 0.9564
# Epoch 7/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.2330 - crf_viterbi_accuracy: 0.9595 - val_loss: 38.8024 - val_crf_viterbi_accuracy: 0.9567
# Epoch 8/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2215 - crf_viterbi_accuracy: 0.9628 - val_loss: 38.7943 - val_crf_viterbi_accuracy: 0.9584
# Epoch 9/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2138 - crf_viterbi_accuracy: 0.9651 - val_loss: 38.7851 - val_crf_viterbi_accuracy: 0.9617
# Epoch 10/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2063 - crf_viterbi_accuracy: 0.9665 - val_loss: 38.7796 - val_crf_viterbi_accuracy: 0.9628
# Epoch 11/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1998 - crf_viterbi_accuracy: 0.9686 - val_loss: 38.7792 - val_crf_viterbi_accuracy: 0.9623
# Epoch 12/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1940 - crf_viterbi_accuracy: 0.9699 - val_loss: 38.7730 - val_crf_viterbi_accuracy: 0.9646
# Epoch 13/20
# 9361/9361 [==============================] - 98s 10ms/step - loss: 39.1890 - crf_viterbi_accuracy: 0.9711 - val_loss: 38.7706 - val_crf_viterbi_accuracy: 0.9655
# Epoch 14/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1844 - crf_viterbi_accuracy: 0.9726 - val_loss: 38.7710 - val_crf_viterbi_accuracy: 0.9645
# Epoch 15/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.1801 - crf_viterbi_accuracy: 0.9739 - val_loss: 38.7667 - val_crf_viterbi_accuracy: 0.9667
# Epoch 16/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.1763 - crf_viterbi_accuracy: 0.9751 - val_loss: 38.7666 - val_crf_viterbi_accuracy: 0.9657
# Epoch 17/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.1724 - crf_viterbi_accuracy: 0.9764 - val_loss: 38.7686 - val_crf_viterbi_accuracy: 0.9638
# Epoch 18/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1696 - crf_viterbi_accuracy: 0.9769 - val_loss: 38.7623 - val_crf_viterbi_accuracy: 0.9679
# Epoch 19/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1666 - crf_viterbi_accuracy: 0.9783 - val_loss: 38.7634 - val_crf_viterbi_accuracy: 0.9661
# Epoch 20/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1637 - crf_viterbi_accuracy: 0.9788 - val_loss: 38.7634 - val_crf_viterbi_accuracy: 0.9683
# FOLD Number: 10/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 198s 21ms/step - loss: 39.3311 - crf_viterbi_accuracy: 0.8834 - val_loss: 39.3623 - val_crf_viterbi_accuracy: 0.9301
# Epoch 2/20
# 9360/9360 [==============================] - 192s 20ms/step - loss: 39.0861 - crf_viterbi_accuracy: 0.9397 - val_loss: 39.2963 - val_crf_viterbi_accuracy: 0.9463
# Epoch 3/20
# 9360/9360 [==============================] - 193s 21ms/step - loss: 39.0425 - crf_viterbi_accuracy: 0.9521 - val_loss: 39.2731 - val_crf_viterbi_accuracy: 0.9520
# Epoch 4/20
# 9360/9360 [==============================] - 192s 21ms/step - loss: 39.0190 - crf_viterbi_accuracy: 0.9573 - val_loss: 39.2569 - val_crf_viterbi_accuracy: 0.9549
# Epoch 5/20
# 9360/9360 [==============================] - 193s 21ms/step - loss: 38.9999 - crf_viterbi_accuracy: 0.9612 - val_loss: 39.2409 - val_crf_viterbi_accuracy: 0.9597
# Epoch 6/20
# 9360/9360 [==============================] - 194s 21ms/step - loss: 38.9872 - crf_viterbi_accuracy: 0.9647 - val_loss: 39.2328 - val_crf_viterbi_accuracy: 0.9623
# Epoch 7/20
# 9360/9360 [==============================] - 193s 21ms/step - loss: 38.9764 - crf_viterbi_accuracy: 0.9680 - val_loss: 39.2265 - val_crf_viterbi_accuracy: 0.9622
# Epoch 8/20
# 9360/9360 [==============================] - 194s 21ms/step - loss: 38.9689 - crf_viterbi_accuracy: 0.9697 - val_loss: 39.2234 - val_crf_viterbi_accuracy: 0.9645
# Epoch 9/20
# 9360/9360 [==============================] - 194s 21ms/step - loss: 38.9606 - crf_viterbi_accuracy: 0.9717 - val_loss: 39.2178 - val_crf_viterbi_accuracy: 0.9647
# Epoch 10/20
# 9360/9360 [==============================] - 193s 21ms/step - loss: 38.9556 - crf_viterbi_accuracy: 0.9732 - val_loss: 39.2159 - val_crf_viterbi_accuracy: 0.9657
# Epoch 11/20
# 9360/9360 [==============================] - 192s 21ms/step - loss: 38.9495 - crf_viterbi_accuracy: 0.9748 - val_loss: 39.2163 - val_crf_viterbi_accuracy: 0.9650
# Epoch 12/20
# 9360/9360 [==============================] - 193s 21ms/step - loss: 38.9445 - crf_viterbi_accuracy: 0.9764 - val_loss: 39.2141 - val_crf_viterbi_accuracy: 0.9665
# Epoch 13/20
# 9360/9360 [==============================] - 192s 20ms/step - loss: 38.9401 - crf_viterbi_accuracy: 0.9778 - val_loss: 39.2173 - val_crf_viterbi_accuracy: 0.9655
# Epoch 14/20
# 9360/9360 [==============================] - 192s 21ms/step - loss: 38.9368 - crf_viterbi_accuracy: 0.9789 - val_loss: 39.2109 - val_crf_viterbi_accuracy: 0.9672
# Epoch 15/20
# 9360/9360 [==============================] - 192s 21ms/step - loss: 38.9340 - crf_viterbi_accuracy: 0.9806 - val_loss: 39.2113 - val_crf_viterbi_accuracy: 0.9676
# Epoch 16/20
# 9360/9360 [==============================] - 190s 20ms/step - loss: 38.9312 - crf_viterbi_accuracy: 0.9815 - val_loss: 39.2085 - val_crf_viterbi_accuracy: 0.9680
# Epoch 17/20
# 9360/9360 [==============================] - 191s 20ms/step - loss: 38.9291 - crf_viterbi_accuracy: 0.9818 - val_loss: 39.2084 - val_crf_viterbi_accuracy: 0.9698
# Epoch 18/20
# 9360/9360 [==============================] - 191s 20ms/step - loss: 38.9261 - crf_viterbi_accuracy: 0.9834 - val_loss: 39.2090 - val_crf_viterbi_accuracy: 0.9692
# Epoch 19/20
# 9360/9360 [==============================] - 191s 20ms/step - loss: 38.9234 - crf_viterbi_accuracy: 0.9837 - val_loss: 39.2106 - val_crf_viterbi_accuracy: 0.9688
# FOLD Number: 11/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.3140 - crf_viterbi_accuracy: 0.8914 - val_loss: 39.3496 - val_crf_viterbi_accuracy: 0.9353
# Epoch 2/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 39.0839 - crf_viterbi_accuracy: 0.9407 - val_loss: 39.2940 - val_crf_viterbi_accuracy: 0.9504
# Epoch 3/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 39.0414 - crf_viterbi_accuracy: 0.9513 - val_loss: 39.2699 - val_crf_viterbi_accuracy: 0.9556
# Epoch 4/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.0155 - crf_viterbi_accuracy: 0.9578 - val_loss: 39.2562 - val_crf_viterbi_accuracy: 0.9580
# Epoch 5/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 38.9984 - crf_viterbi_accuracy: 0.9614 - val_loss: 39.2455 - val_crf_viterbi_accuracy: 0.9612
# Epoch 6/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 38.9855 - crf_viterbi_accuracy: 0.9648 - val_loss: 39.2386 - val_crf_viterbi_accuracy: 0.9634
# Epoch 7/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 38.9758 - crf_viterbi_accuracy: 0.9670 - val_loss: 39.2301 - val_crf_viterbi_accuracy: 0.9643
# Epoch 8/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 38.9665 - crf_viterbi_accuracy: 0.9692 - val_loss: 39.2315 - val_crf_viterbi_accuracy: 0.9602
# Epoch 9/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 38.9593 - crf_viterbi_accuracy: 0.9710 - val_loss: 39.2232 - val_crf_viterbi_accuracy: 0.9670
# Epoch 10/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 38.9532 - crf_viterbi_accuracy: 0.9729 - val_loss: 39.2196 - val_crf_viterbi_accuracy: 0.9676
# Epoch 11/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 38.9487 - crf_viterbi_accuracy: 0.9742 - val_loss: 39.2175 - val_crf_viterbi_accuracy: 0.9678
# Epoch 12/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 38.9442 - crf_viterbi_accuracy: 0.9756 - val_loss: 39.2185 - val_crf_viterbi_accuracy: 0.9678
# Epoch 13/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 38.9401 - crf_viterbi_accuracy: 0.9770 - val_loss: 39.2153 - val_crf_viterbi_accuracy: 0.9684
# Epoch 14/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 38.9351 - crf_viterbi_accuracy: 0.9788 - val_loss: 39.2141 - val_crf_viterbi_accuracy: 0.9700
# Epoch 15/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 38.9325 - crf_viterbi_accuracy: 0.9797 - val_loss: 39.2158 - val_crf_viterbi_accuracy: 0.9706
# Epoch 16/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 38.9296 - crf_viterbi_accuracy: 0.9810 - val_loss: 39.2179 - val_crf_viterbi_accuracy: 0.9702
# FOLD Number: 12/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.5616 - crf_viterbi_accuracy: 0.8832 - val_loss: 38.9033 - val_crf_viterbi_accuracy: 0.9303
# Epoch 2/20
# 9361/9361 [==============================] - 189s 20ms/step - loss: 39.3112 - crf_viterbi_accuracy: 0.9397 - val_loss: 38.8441 - val_crf_viterbi_accuracy: 0.9472
# Epoch 3/20
# 9361/9361 [==============================] - 189s 20ms/step - loss: 39.2681 - crf_viterbi_accuracy: 0.9511 - val_loss: 38.8188 - val_crf_viterbi_accuracy: 0.9520
# Epoch 4/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.2440 - crf_viterbi_accuracy: 0.9572 - val_loss: 38.8084 - val_crf_viterbi_accuracy: 0.9546
# Epoch 5/20
# 9361/9361 [==============================] - 189s 20ms/step - loss: 39.2262 - crf_viterbi_accuracy: 0.9607 - val_loss: 38.7892 - val_crf_viterbi_accuracy: 0.9609
# Epoch 6/20
# 9361/9361 [==============================] - 189s 20ms/step - loss: 39.2125 - crf_viterbi_accuracy: 0.9649 - val_loss: 38.7828 - val_crf_viterbi_accuracy: 0.9618
# Epoch 7/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.2017 - crf_viterbi_accuracy: 0.9681 - val_loss: 38.7749 - val_crf_viterbi_accuracy: 0.9648
# Epoch 8/20
# 9361/9361 [==============================] - 188s 20ms/step - loss: 39.1940 - crf_viterbi_accuracy: 0.9697 - val_loss: 38.7699 - val_crf_viterbi_accuracy: 0.9659
# Epoch 9/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.1865 - crf_viterbi_accuracy: 0.9718 - val_loss: 38.7690 - val_crf_viterbi_accuracy: 0.9649
# Epoch 10/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.1805 - crf_viterbi_accuracy: 0.9740 - val_loss: 38.7616 - val_crf_viterbi_accuracy: 0.9675
# Epoch 11/20
# 9361/9361 [==============================] - 192s 20ms/step - loss: 39.1752 - crf_viterbi_accuracy: 0.9747 - val_loss: 38.7680 - val_crf_viterbi_accuracy: 0.9618
# Epoch 12/20
# 9361/9361 [==============================] - 189s 20ms/step - loss: 39.1712 - crf_viterbi_accuracy: 0.9758 - val_loss: 38.7650 - val_crf_viterbi_accuracy: 0.9657
# CPU times: user 7h 43min 23s, sys: 31min 54s, total: 8h 15min 17s
# Wall time: 5h 12min 40s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("batch size").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#             train_loss  train_acc   val_loss   val_acc     epochs
# batch size
# 32           39.008085   0.980166  39.064504  0.968244  15.666667
# 64           39.017004   0.977407  39.066374  0.966980  18.000000
# 128          39.036103   0.972278  39.073782  0.964849  20.000000
# 256          39.061950   0.965734  39.088697  0.960394  20.000000

# %%
from google.colab import files
df_results.to_csv('batch size_grid_glove.csv')
files.download('batch size_grid_glove.csv')
