# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/GloVe/BiLSTM-CRF%20GLOVE%20(Optimizer).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-mwqk1oai
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-mwqk1oai
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=eb044dc82c4117822c567b15ad03ac26340fdcb8e851df59ca38f7b524c84170
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aayi0gwz/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Requirement already satisfied: sklearn_crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# TensorFlow 1.x selected.

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2
# Using TensorFlow backend.

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_path = "/content/drive/My Drive/glove.6B.50d.txt"
#root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
OPTIMIZERS =["nadam", "adam", "sgd"]
BATCH_SIZE= 32
EPOCHS=20
fold_count = 1

for OPT in OPTIMIZERS:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(OPTIMIZERS)*3))
    
    #split data
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(opt):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=100, return_sequences=True,
                                recurrent_dropout=0.1, dropout=0.1))(model_2)
      model_2 = TimeDistributed(Dense(20, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer=opt, loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

  #---------Fit Model-----------------
    model = create_model(OPT)
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "Optimizer": OPT,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/9
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2974: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 207s 22ms/step - loss: 39.2040 - crf_viterbi_accuracy: 0.9123 - val_loss: 39.2957 - val_crf_viterbi_accuracy: 0.9441
# Epoch 2/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 39.0332 - crf_viterbi_accuracy: 0.9519 - val_loss: 39.2582 - val_crf_viterbi_accuracy: 0.9533
# Epoch 3/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 38.9984 - crf_viterbi_accuracy: 0.9613 - val_loss: 39.2374 - val_crf_viterbi_accuracy: 0.9585
# Epoch 4/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 38.9787 - crf_viterbi_accuracy: 0.9662 - val_loss: 39.2267 - val_crf_viterbi_accuracy: 0.9618
# Epoch 5/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9652 - crf_viterbi_accuracy: 0.9693 - val_loss: 39.2223 - val_crf_viterbi_accuracy: 0.9597
# Epoch 6/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 38.9555 - crf_viterbi_accuracy: 0.9721 - val_loss: 39.2167 - val_crf_viterbi_accuracy: 0.9625
# Epoch 7/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 38.9466 - crf_viterbi_accuracy: 0.9749 - val_loss: 39.2109 - val_crf_viterbi_accuracy: 0.9674
# Epoch 8/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9405 - crf_viterbi_accuracy: 0.9772 - val_loss: 39.2103 - val_crf_viterbi_accuracy: 0.9659
# Epoch 9/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9338 - crf_viterbi_accuracy: 0.9789 - val_loss: 39.2072 - val_crf_viterbi_accuracy: 0.9690
# Epoch 10/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 38.9300 - crf_viterbi_accuracy: 0.9809 - val_loss: 39.2059 - val_crf_viterbi_accuracy: 0.9688
# Epoch 11/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9263 - crf_viterbi_accuracy: 0.9820 - val_loss: 39.2135 - val_crf_viterbi_accuracy: 0.9661
# Epoch 12/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9234 - crf_viterbi_accuracy: 0.9830 - val_loss: 39.2124 - val_crf_viterbi_accuracy: 0.9697
# FOLD Number: 2/9
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.2199 - crf_viterbi_accuracy: 0.9084 - val_loss: 39.3083 - val_crf_viterbi_accuracy: 0.9428
# Epoch 2/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.0367 - crf_viterbi_accuracy: 0.9504 - val_loss: 39.2550 - val_crf_viterbi_accuracy: 0.9564
# Epoch 3/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.0006 - crf_viterbi_accuracy: 0.9594 - val_loss: 39.2429 - val_crf_viterbi_accuracy: 0.9591
# Epoch 4/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 38.9799 - crf_viterbi_accuracy: 0.9643 - val_loss: 39.2302 - val_crf_viterbi_accuracy: 0.9630
# Epoch 5/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 38.9651 - crf_viterbi_accuracy: 0.9686 - val_loss: 39.2236 - val_crf_viterbi_accuracy: 0.9660
# Epoch 6/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 38.9547 - crf_viterbi_accuracy: 0.9720 - val_loss: 39.2255 - val_crf_viterbi_accuracy: 0.9619
# Epoch 7/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 38.9469 - crf_viterbi_accuracy: 0.9741 - val_loss: 39.2207 - val_crf_viterbi_accuracy: 0.9652
# Epoch 8/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 38.9395 - crf_viterbi_accuracy: 0.9772 - val_loss: 39.2329 - val_crf_viterbi_accuracy: 0.9566
# Epoch 9/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 38.9352 - crf_viterbi_accuracy: 0.9779 - val_loss: 39.2149 - val_crf_viterbi_accuracy: 0.9678
# Epoch 10/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 38.9309 - crf_viterbi_accuracy: 0.9797 - val_loss: 39.2156 - val_crf_viterbi_accuracy: 0.9668
# Epoch 11/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 38.9268 - crf_viterbi_accuracy: 0.9813 - val_loss: 39.2169 - val_crf_viterbi_accuracy: 0.9662
# FOLD Number: 3/9
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.4859 - crf_viterbi_accuracy: 0.8874 - val_loss: 38.8614 - val_crf_viterbi_accuracy: 0.9419
# Epoch 2/20
# 9361/9361 [==============================] - 201s 22ms/step - loss: 39.2770 - crf_viterbi_accuracy: 0.9481 - val_loss: 38.8217 - val_crf_viterbi_accuracy: 0.9514
# Epoch 3/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 39.2357 - crf_viterbi_accuracy: 0.9582 - val_loss: 38.7942 - val_crf_viterbi_accuracy: 0.9570
# Epoch 4/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 39.2137 - crf_viterbi_accuracy: 0.9636 - val_loss: 38.7818 - val_crf_viterbi_accuracy: 0.9607
# Epoch 5/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.1979 - crf_viterbi_accuracy: 0.9677 - val_loss: 38.7717 - val_crf_viterbi_accuracy: 0.9637
# Epoch 6/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.1864 - crf_viterbi_accuracy: 0.9711 - val_loss: 38.7629 - val_crf_viterbi_accuracy: 0.9669
# Epoch 7/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.1770 - crf_viterbi_accuracy: 0.9736 - val_loss: 38.7633 - val_crf_viterbi_accuracy: 0.9664
# Epoch 8/20
# 9361/9361 [==============================] - 196s 21ms/step - loss: 39.1698 - crf_viterbi_accuracy: 0.9761 - val_loss: 38.7604 - val_crf_viterbi_accuracy: 0.9673
# Epoch 9/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.1649 - crf_viterbi_accuracy: 0.9774 - val_loss: 38.7613 - val_crf_viterbi_accuracy: 0.9687
# Epoch 10/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.1612 - crf_viterbi_accuracy: 0.9795 - val_loss: 38.7582 - val_crf_viterbi_accuracy: 0.9708
# Epoch 11/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.1563 - crf_viterbi_accuracy: 0.9810 - val_loss: 38.7605 - val_crf_viterbi_accuracy: 0.9686
# Epoch 12/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.1534 - crf_viterbi_accuracy: 0.9819 - val_loss: 38.7656 - val_crf_viterbi_accuracy: 0.9668
# FOLD Number: 4/9
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 39.3471 - crf_viterbi_accuracy: 0.8805 - val_loss: 39.3591 - val_crf_viterbi_accuracy: 0.9276
# Epoch 2/20
# 9360/9360 [==============================] - 197s 21ms/step - loss: 39.0820 - crf_viterbi_accuracy: 0.9401 - val_loss: 39.2916 - val_crf_viterbi_accuracy: 0.9476
# Epoch 3/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 39.0384 - crf_viterbi_accuracy: 0.9519 - val_loss: 39.2678 - val_crf_viterbi_accuracy: 0.9519
# Epoch 4/20
# 9360/9360 [==============================] - 196s 21ms/step - loss: 39.0135 - crf_viterbi_accuracy: 0.9590 - val_loss: 39.2489 - val_crf_viterbi_accuracy: 0.9578
# Epoch 5/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9969 - crf_viterbi_accuracy: 0.9621 - val_loss: 39.2352 - val_crf_viterbi_accuracy: 0.9602
# Epoch 6/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9842 - crf_viterbi_accuracy: 0.9666 - val_loss: 39.2292 - val_crf_viterbi_accuracy: 0.9609
# Epoch 7/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9739 - crf_viterbi_accuracy: 0.9685 - val_loss: 39.2236 - val_crf_viterbi_accuracy: 0.9633
# Epoch 8/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9656 - crf_viterbi_accuracy: 0.9706 - val_loss: 39.2227 - val_crf_viterbi_accuracy: 0.9611
# Epoch 9/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 38.9596 - crf_viterbi_accuracy: 0.9724 - val_loss: 39.2145 - val_crf_viterbi_accuracy: 0.9655
# Epoch 10/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9533 - crf_viterbi_accuracy: 0.9744 - val_loss: 39.2147 - val_crf_viterbi_accuracy: 0.9666
# Epoch 11/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9476 - crf_viterbi_accuracy: 0.9758 - val_loss: 39.2127 - val_crf_viterbi_accuracy: 0.9656
# Epoch 12/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9442 - crf_viterbi_accuracy: 0.9768 - val_loss: 39.2086 - val_crf_viterbi_accuracy: 0.9674
# Epoch 13/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9395 - crf_viterbi_accuracy: 0.9778 - val_loss: 39.2072 - val_crf_viterbi_accuracy: 0.9684
# Epoch 14/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9355 - crf_viterbi_accuracy: 0.9795 - val_loss: 39.2075 - val_crf_viterbi_accuracy: 0.9685
# Epoch 15/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9336 - crf_viterbi_accuracy: 0.9799 - val_loss: 39.2064 - val_crf_viterbi_accuracy: 0.9675
# Epoch 16/20
# 9360/9360 [==============================] - 201s 22ms/step - loss: 38.9303 - crf_viterbi_accuracy: 0.9814 - val_loss: 39.2090 - val_crf_viterbi_accuracy: 0.9678
# Epoch 17/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 38.9274 - crf_viterbi_accuracy: 0.9825 - val_loss: 39.2042 - val_crf_viterbi_accuracy: 0.9702
# Epoch 18/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9257 - crf_viterbi_accuracy: 0.9828 - val_loss: 39.2077 - val_crf_viterbi_accuracy: 0.9706
# Epoch 19/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9230 - crf_viterbi_accuracy: 0.9841 - val_loss: 39.2066 - val_crf_viterbi_accuracy: 0.9696
# FOLD Number: 5/9
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 210s 22ms/step - loss: 39.3266 - crf_viterbi_accuracy: 0.8796 - val_loss: 39.3489 - val_crf_viterbi_accuracy: 0.9275
# Epoch 2/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.0847 - crf_viterbi_accuracy: 0.9358 - val_loss: 39.2925 - val_crf_viterbi_accuracy: 0.9456
# Epoch 3/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 39.0397 - crf_viterbi_accuracy: 0.9483 - val_loss: 39.2668 - val_crf_viterbi_accuracy: 0.9537
# Epoch 4/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.0128 - crf_viterbi_accuracy: 0.9568 - val_loss: 39.2519 - val_crf_viterbi_accuracy: 0.9582
# Epoch 5/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 38.9949 - crf_viterbi_accuracy: 0.9615 - val_loss: 39.2371 - val_crf_viterbi_accuracy: 0.9627
# Epoch 6/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 38.9821 - crf_viterbi_accuracy: 0.9646 - val_loss: 39.2346 - val_crf_viterbi_accuracy: 0.9622
# Epoch 7/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 38.9710 - crf_viterbi_accuracy: 0.9682 - val_loss: 39.2262 - val_crf_viterbi_accuracy: 0.9645
# Epoch 8/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 38.9641 - crf_viterbi_accuracy: 0.9696 - val_loss: 39.2208 - val_crf_viterbi_accuracy: 0.9658
# Epoch 9/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 38.9559 - crf_viterbi_accuracy: 0.9723 - val_loss: 39.2177 - val_crf_viterbi_accuracy: 0.9668
# Epoch 10/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 38.9510 - crf_viterbi_accuracy: 0.9733 - val_loss: 39.2147 - val_crf_viterbi_accuracy: 0.9683
# Epoch 11/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 38.9463 - crf_viterbi_accuracy: 0.9748 - val_loss: 39.2116 - val_crf_viterbi_accuracy: 0.9694
# Epoch 12/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 38.9411 - crf_viterbi_accuracy: 0.9766 - val_loss: 39.2151 - val_crf_viterbi_accuracy: 0.9660
# Epoch 13/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 38.9385 - crf_viterbi_accuracy: 0.9776 - val_loss: 39.2155 - val_crf_viterbi_accuracy: 0.9688
# FOLD Number: 6/9
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.5455 - crf_viterbi_accuracy: 0.8908 - val_loss: 38.8907 - val_crf_viterbi_accuracy: 0.9314
# Epoch 2/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.3027 - crf_viterbi_accuracy: 0.9405 - val_loss: 38.8379 - val_crf_viterbi_accuracy: 0.9471
# Epoch 3/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.2624 - crf_viterbi_accuracy: 0.9512 - val_loss: 38.8158 - val_crf_viterbi_accuracy: 0.9537
# Epoch 4/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 39.2395 - crf_viterbi_accuracy: 0.9581 - val_loss: 38.7975 - val_crf_viterbi_accuracy: 0.9582
# Epoch 5/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.2228 - crf_viterbi_accuracy: 0.9621 - val_loss: 38.7859 - val_crf_viterbi_accuracy: 0.9613
# Epoch 6/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.2110 - crf_viterbi_accuracy: 0.9649 - val_loss: 38.7803 - val_crf_viterbi_accuracy: 0.9626
# Epoch 7/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.2001 - crf_viterbi_accuracy: 0.9678 - val_loss: 38.7783 - val_crf_viterbi_accuracy: 0.9632
# Epoch 8/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.1935 - crf_viterbi_accuracy: 0.9689 - val_loss: 38.7675 - val_crf_viterbi_accuracy: 0.9663
# Epoch 9/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.1857 - crf_viterbi_accuracy: 0.9718 - val_loss: 38.7662 - val_crf_viterbi_accuracy: 0.9658
# Epoch 10/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 39.1806 - crf_viterbi_accuracy: 0.9728 - val_loss: 38.7592 - val_crf_viterbi_accuracy: 0.9694
# Epoch 11/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 39.1755 - crf_viterbi_accuracy: 0.9750 - val_loss: 38.7615 - val_crf_viterbi_accuracy: 0.9681
# Epoch 12/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.1699 - crf_viterbi_accuracy: 0.9765 - val_loss: 38.7593 - val_crf_viterbi_accuracy: 0.9686
# FOLD Number: 7/9
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 39.8893 - crf_viterbi_accuracy: 0.8077 - val_loss: 39.9286 - val_crf_viterbi_accuracy: 0.8084
# Epoch 2/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 39.6532 - crf_viterbi_accuracy: 0.8322 - val_loss: 39.8238 - val_crf_viterbi_accuracy: 0.8088
# Epoch 3/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 39.5658 - crf_viterbi_accuracy: 0.8346 - val_loss: 39.7481 - val_crf_viterbi_accuracy: 0.8143
# Epoch 4/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 39.4936 - crf_viterbi_accuracy: 0.8425 - val_loss: 39.6852 - val_crf_viterbi_accuracy: 0.8276
# Epoch 5/20
# 9360/9360 [==============================] - 201s 22ms/step - loss: 39.4362 - crf_viterbi_accuracy: 0.8559 - val_loss: 39.6329 - val_crf_viterbi_accuracy: 0.8455
# Epoch 6/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 39.3882 - crf_viterbi_accuracy: 0.8700 - val_loss: 39.5901 - val_crf_viterbi_accuracy: 0.8656
# Epoch 7/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 39.3477 - crf_viterbi_accuracy: 0.8804 - val_loss: 39.5545 - val_crf_viterbi_accuracy: 0.8807
# Epoch 8/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 39.3165 - crf_viterbi_accuracy: 0.8864 - val_loss: 39.5267 - val_crf_viterbi_accuracy: 0.8887
# Epoch 9/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 39.2882 - crf_viterbi_accuracy: 0.8920 - val_loss: 39.5034 - val_crf_viterbi_accuracy: 0.8949
# Epoch 10/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 39.2684 - crf_viterbi_accuracy: 0.8950 - val_loss: 39.4850 - val_crf_viterbi_accuracy: 0.8983
# Epoch 11/20
# 9360/9360 [==============================] - 201s 22ms/step - loss: 39.2517 - crf_viterbi_accuracy: 0.8980 - val_loss: 39.4701 - val_crf_viterbi_accuracy: 0.9015
# Epoch 12/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 39.2352 - crf_viterbi_accuracy: 0.9009 - val_loss: 39.4570 - val_crf_viterbi_accuracy: 0.9040
# Epoch 13/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 39.2235 - crf_viterbi_accuracy: 0.9032 - val_loss: 39.4460 - val_crf_viterbi_accuracy: 0.9060
# Epoch 14/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 39.2124 - crf_viterbi_accuracy: 0.9045 - val_loss: 39.4367 - val_crf_viterbi_accuracy: 0.9083
# Epoch 15/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 39.2040 - crf_viterbi_accuracy: 0.9060 - val_loss: 39.4287 - val_crf_viterbi_accuracy: 0.9104
# Epoch 16/20
# 9360/9360 [==============================] - 204s 22ms/step - loss: 39.1960 - crf_viterbi_accuracy: 0.9079 - val_loss: 39.4209 - val_crf_viterbi_accuracy: 0.9113
# Epoch 17/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 39.1887 - crf_viterbi_accuracy: 0.9090 - val_loss: 39.4141 - val_crf_viterbi_accuracy: 0.9133
# Epoch 18/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 39.1818 - crf_viterbi_accuracy: 0.9102 - val_loss: 39.4084 - val_crf_viterbi_accuracy: 0.9142
# Epoch 19/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 39.1752 - crf_viterbi_accuracy: 0.9108 - val_loss: 39.4024 - val_crf_viterbi_accuracy: 0.9161
# Epoch 20/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 39.1718 - crf_viterbi_accuracy: 0.9118 - val_loss: 39.3973 - val_crf_viterbi_accuracy: 0.9176
# FOLD Number: 8/9
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 209s 22ms/step - loss: 39.9319 - crf_viterbi_accuracy: 0.7819 - val_loss: 39.8925 - val_crf_viterbi_accuracy: 0.8131
# Epoch 2/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.6204 - crf_viterbi_accuracy: 0.8316 - val_loss: 39.7894 - val_crf_viterbi_accuracy: 0.8174
# Epoch 3/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.5360 - crf_viterbi_accuracy: 0.8387 - val_loss: 39.7158 - val_crf_viterbi_accuracy: 0.8288
# Epoch 4/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.4680 - crf_viterbi_accuracy: 0.8492 - val_loss: 39.6533 - val_crf_viterbi_accuracy: 0.8459
# Epoch 5/20
# 9361/9361 [==============================] - 201s 22ms/step - loss: 39.4116 - crf_viterbi_accuracy: 0.8599 - val_loss: 39.6030 - val_crf_viterbi_accuracy: 0.8598
# Epoch 6/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.3656 - crf_viterbi_accuracy: 0.8728 - val_loss: 39.5626 - val_crf_viterbi_accuracy: 0.8739
# Epoch 7/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.3289 - crf_viterbi_accuracy: 0.8815 - val_loss: 39.5298 - val_crf_viterbi_accuracy: 0.8859
# Epoch 8/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.2983 - crf_viterbi_accuracy: 0.8891 - val_loss: 39.5043 - val_crf_viterbi_accuracy: 0.8936
# Epoch 9/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.2742 - crf_viterbi_accuracy: 0.8926 - val_loss: 39.4834 - val_crf_viterbi_accuracy: 0.8985
# Epoch 10/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.2566 - crf_viterbi_accuracy: 0.8954 - val_loss: 39.4668 - val_crf_viterbi_accuracy: 0.9019
# Epoch 11/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.2407 - crf_viterbi_accuracy: 0.8980 - val_loss: 39.4534 - val_crf_viterbi_accuracy: 0.9049
# Epoch 12/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.2265 - crf_viterbi_accuracy: 0.9013 - val_loss: 39.4416 - val_crf_viterbi_accuracy: 0.9070
# Epoch 13/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.2150 - crf_viterbi_accuracy: 0.9030 - val_loss: 39.4326 - val_crf_viterbi_accuracy: 0.9087
# Epoch 14/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.2059 - crf_viterbi_accuracy: 0.9035 - val_loss: 39.4240 - val_crf_viterbi_accuracy: 0.9105
# Epoch 15/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.1980 - crf_viterbi_accuracy: 0.9059 - val_loss: 39.4172 - val_crf_viterbi_accuracy: 0.9111
# Epoch 16/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.1909 - crf_viterbi_accuracy: 0.9070 - val_loss: 39.4104 - val_crf_viterbi_accuracy: 0.9133
# Epoch 17/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.1844 - crf_viterbi_accuracy: 0.9083 - val_loss: 39.4047 - val_crf_viterbi_accuracy: 0.9144
# Epoch 18/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.1768 - crf_viterbi_accuracy: 0.9097 - val_loss: 39.3993 - val_crf_viterbi_accuracy: 0.9154
# Epoch 19/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.1721 - crf_viterbi_accuracy: 0.9109 - val_loss: 39.3947 - val_crf_viterbi_accuracy: 0.9170
# Epoch 20/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 39.1663 - crf_viterbi_accuracy: 0.9122 - val_loss: 39.3899 - val_crf_viterbi_accuracy: 0.9182
# FOLD Number: 9/9
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 212s 23ms/step - loss: 40.1092 - crf_viterbi_accuracy: 0.7802 - val_loss: 39.4228 - val_crf_viterbi_accuracy: 0.8112
# Epoch 2/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.8330 - crf_viterbi_accuracy: 0.8323 - val_loss: 39.3119 - val_crf_viterbi_accuracy: 0.8130
# Epoch 3/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.7420 - crf_viterbi_accuracy: 0.8371 - val_loss: 39.2353 - val_crf_viterbi_accuracy: 0.8228
# Epoch 4/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 39.6717 - crf_viterbi_accuracy: 0.8507 - val_loss: 39.1752 - val_crf_viterbi_accuracy: 0.8437
# Epoch 5/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.6148 - crf_viterbi_accuracy: 0.8677 - val_loss: 39.1278 - val_crf_viterbi_accuracy: 0.8682
# Epoch 6/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.5715 - crf_viterbi_accuracy: 0.8801 - val_loss: 39.0915 - val_crf_viterbi_accuracy: 0.8815
# Epoch 7/20
# 9361/9361 [==============================] - 201s 22ms/step - loss: 39.5387 - crf_viterbi_accuracy: 0.8872 - val_loss: 39.0631 - val_crf_viterbi_accuracy: 0.8903
# Epoch 8/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.5116 - crf_viterbi_accuracy: 0.8916 - val_loss: 39.0413 - val_crf_viterbi_accuracy: 0.8945
# Epoch 9/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.4906 - crf_viterbi_accuracy: 0.8955 - val_loss: 39.0232 - val_crf_viterbi_accuracy: 0.8989
# Epoch 10/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.4734 - crf_viterbi_accuracy: 0.8981 - val_loss: 39.0090 - val_crf_viterbi_accuracy: 0.9026
# Epoch 11/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.4609 - crf_viterbi_accuracy: 0.8993 - val_loss: 38.9969 - val_crf_viterbi_accuracy: 0.9055
# Epoch 12/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.4461 - crf_viterbi_accuracy: 0.9037 - val_loss: 38.9862 - val_crf_viterbi_accuracy: 0.9081
# Epoch 13/20
# 9361/9361 [==============================] - 201s 22ms/step - loss: 39.4371 - crf_viterbi_accuracy: 0.9040 - val_loss: 38.9772 - val_crf_viterbi_accuracy: 0.9093
# Epoch 14/20
# 9361/9361 [==============================] - 201s 22ms/step - loss: 39.4273 - crf_viterbi_accuracy: 0.9056 - val_loss: 38.9691 - val_crf_viterbi_accuracy: 0.9113
# Epoch 15/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.4215 - crf_viterbi_accuracy: 0.9066 - val_loss: 38.9622 - val_crf_viterbi_accuracy: 0.9126
# Epoch 16/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.4125 - crf_viterbi_accuracy: 0.9089 - val_loss: 38.9560 - val_crf_viterbi_accuracy: 0.9146
# Epoch 17/20
# 9361/9361 [==============================] - 201s 22ms/step - loss: 39.4066 - crf_viterbi_accuracy: 0.9094 - val_loss: 38.9501 - val_crf_viterbi_accuracy: 0.9155
# Epoch 18/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.3998 - crf_viterbi_accuracy: 0.9108 - val_loss: 38.9446 - val_crf_viterbi_accuracy: 0.9170
# Epoch 19/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.3941 - crf_viterbi_accuracy: 0.9129 - val_loss: 38.9398 - val_crf_viterbi_accuracy: 0.9186
# Epoch 20/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.3883 - crf_viterbi_accuracy: 0.9141 - val_loss: 38.9349 - val_crf_viterbi_accuracy: 0.9185
# CPU times: user 11h 25min 32s, sys: 46min 42s, total: 12h 12min 15s
# Wall time: 7h 47min 10s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("Optimizer").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#            train_loss  train_acc   val_loss   val_acc     epochs
# Optimizer
# adam        39.010473   0.979375  39.060488  0.969013  14.666667
# nadam       39.001216   0.982095  39.064965  0.967550  11.666667
# sgd         39.242145   0.912685  39.240691  0.918120  20.000000

# %%
from google.colab import files
df_results.to_csv('Optimizer_grid_Glove.csv')
files.download('Optimizer_grid_Glove.csv')
