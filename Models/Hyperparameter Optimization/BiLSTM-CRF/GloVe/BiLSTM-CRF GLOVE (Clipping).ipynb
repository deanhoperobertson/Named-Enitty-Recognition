# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/GloVe/BiLSTM-CRF%20GLOVE%20(Clipping).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# !pip install keras==2.2.4
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-m8_f8xuq
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-m8_f8xuq
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=9e1ef430d7f74a642a11592c141e0fb65347e8fb6a07f2591cadcdd7e99a2f88
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l84gdj79/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Requirement already satisfied: sklearn_crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_path = "/content/drive/My Drive/glove.6B.50d.txt"
#root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
CLIPS = [0,1,2,5]
HIDDEN = 100
DROPOUT =0.10
CELLS =200
BATCH_SIZE= 32
EPOCHS=20
fold_count = 1

for CLIP in CLIPS:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(CLIPS)*3))
    
    #split data
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(OPT):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=CELLS, return_sequences=True,
                                recurrent_dropout=DROPOUT, dropout=DROPOUT))(model_2)
      model_2 = TimeDistributed(Dense(HIDDEN, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer=OPT, loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

  #---------Fit Model-----------------
    opt=optimizers.Adam(clipvalue=CLIP)

    model = create_model(opt)
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "Clipping": CLIP ,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/12
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2974: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 212s 23ms/step - loss: 39.2535 - crf_viterbi_accuracy: 0.9023 - val_loss: 39.3446 - val_crf_viterbi_accuracy: 0.9307
# Epoch 2/20
# 9360/9360 [==============================] - 204s 22ms/step - loss: 39.0629 - crf_viterbi_accuracy: 0.9465 - val_loss: 39.2809 - val_crf_viterbi_accuracy: 0.9503
# Epoch 3/20
# 9360/9360 [==============================] - 206s 22ms/step - loss: 39.0218 - crf_viterbi_accuracy: 0.9569 - val_loss: 39.2537 - val_crf_viterbi_accuracy: 0.9576
# Epoch 4/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 38.9967 - crf_viterbi_accuracy: 0.9637 - val_loss: 39.2402 - val_crf_viterbi_accuracy: 0.9608
# Epoch 5/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9793 - crf_viterbi_accuracy: 0.9677 - val_loss: 39.2282 - val_crf_viterbi_accuracy: 0.9622
# Epoch 6/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9666 - crf_viterbi_accuracy: 0.9707 - val_loss: 39.2239 - val_crf_viterbi_accuracy: 0.9643
# Epoch 7/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9554 - crf_viterbi_accuracy: 0.9739 - val_loss: 39.2158 - val_crf_viterbi_accuracy: 0.9675
# Epoch 8/20
# 9360/9360 [==============================] - 201s 22ms/step - loss: 38.9471 - crf_viterbi_accuracy: 0.9765 - val_loss: 39.2137 - val_crf_viterbi_accuracy: 0.9674
# Epoch 9/20
# 9360/9360 [==============================] - 201s 22ms/step - loss: 38.9405 - crf_viterbi_accuracy: 0.9784 - val_loss: 39.2126 - val_crf_viterbi_accuracy: 0.9680
# Epoch 10/20
# 9360/9360 [==============================] - 208s 22ms/step - loss: 38.9351 - crf_viterbi_accuracy: 0.9801 - val_loss: 39.2160 - val_crf_viterbi_accuracy: 0.9676
# Epoch 11/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 38.9290 - crf_viterbi_accuracy: 0.9822 - val_loss: 39.2158 - val_crf_viterbi_accuracy: 0.9698
# FOLD Number: 2/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 39.2410 - crf_viterbi_accuracy: 0.9020 - val_loss: 39.3254 - val_crf_viterbi_accuracy: 0.9363
# Epoch 2/20
# 9361/9361 [==============================] - 208s 22ms/step - loss: 39.0570 - crf_viterbi_accuracy: 0.9451 - val_loss: 39.2845 - val_crf_viterbi_accuracy: 0.9499
# Epoch 3/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.0178 - crf_viterbi_accuracy: 0.9559 - val_loss: 39.2521 - val_crf_viterbi_accuracy: 0.9582
# Epoch 4/20
# 9361/9361 [==============================] - 201s 22ms/step - loss: 38.9944 - crf_viterbi_accuracy: 0.9627 - val_loss: 39.2415 - val_crf_viterbi_accuracy: 0.9588
# Epoch 5/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 38.9769 - crf_viterbi_accuracy: 0.9664 - val_loss: 39.2285 - val_crf_viterbi_accuracy: 0.9642
# Epoch 6/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 38.9646 - crf_viterbi_accuracy: 0.9700 - val_loss: 39.2302 - val_crf_viterbi_accuracy: 0.9599
# Epoch 7/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 38.9550 - crf_viterbi_accuracy: 0.9723 - val_loss: 39.2209 - val_crf_viterbi_accuracy: 0.9643
# Epoch 8/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 38.9460 - crf_viterbi_accuracy: 0.9744 - val_loss: 39.2179 - val_crf_viterbi_accuracy: 0.9692
# Epoch 9/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 38.9388 - crf_viterbi_accuracy: 0.9770 - val_loss: 39.2233 - val_crf_viterbi_accuracy: 0.9666
# Epoch 10/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 38.9327 - crf_viterbi_accuracy: 0.9795 - val_loss: 39.2166 - val_crf_viterbi_accuracy: 0.9704
# Epoch 11/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 38.9290 - crf_viterbi_accuracy: 0.9809 - val_loss: 39.2183 - val_crf_viterbi_accuracy: 0.9688
# Epoch 12/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 38.9243 - crf_viterbi_accuracy: 0.9830 - val_loss: 39.2462 - val_crf_viterbi_accuracy: 0.9652
# FOLD Number: 3/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.4644 - crf_viterbi_accuracy: 0.9052 - val_loss: 38.8804 - val_crf_viterbi_accuracy: 0.9346
# Epoch 2/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.2853 - crf_viterbi_accuracy: 0.9462 - val_loss: 38.8311 - val_crf_viterbi_accuracy: 0.9506
# Epoch 3/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.2444 - crf_viterbi_accuracy: 0.9576 - val_loss: 38.8031 - val_crf_viterbi_accuracy: 0.9578
# Epoch 4/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.2208 - crf_viterbi_accuracy: 0.9629 - val_loss: 38.7844 - val_crf_viterbi_accuracy: 0.9633
# Epoch 5/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.2052 - crf_viterbi_accuracy: 0.9670 - val_loss: 38.7765 - val_crf_viterbi_accuracy: 0.9652
# Epoch 6/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.1918 - crf_viterbi_accuracy: 0.9703 - val_loss: 38.7754 - val_crf_viterbi_accuracy: 0.9644
# Epoch 7/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.1812 - crf_viterbi_accuracy: 0.9732 - val_loss: 38.7702 - val_crf_viterbi_accuracy: 0.9666
# Epoch 8/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.1720 - crf_viterbi_accuracy: 0.9761 - val_loss: 38.7677 - val_crf_viterbi_accuracy: 0.9673
# Epoch 9/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 39.1667 - crf_viterbi_accuracy: 0.9781 - val_loss: 38.7616 - val_crf_viterbi_accuracy: 0.9703
# Epoch 10/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 39.1602 - crf_viterbi_accuracy: 0.9804 - val_loss: 38.7681 - val_crf_viterbi_accuracy: 0.9677
# Epoch 11/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.1552 - crf_viterbi_accuracy: 0.9825 - val_loss: 38.7631 - val_crf_viterbi_accuracy: 0.9716
# FOLD Number: 4/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 39.2657 - crf_viterbi_accuracy: 0.8952 - val_loss: 39.3263 - val_crf_viterbi_accuracy: 0.9367
# Epoch 2/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 39.0617 - crf_viterbi_accuracy: 0.9459 - val_loss: 39.2820 - val_crf_viterbi_accuracy: 0.9464
# Epoch 3/20
# 9360/9360 [==============================] - 206s 22ms/step - loss: 39.0206 - crf_viterbi_accuracy: 0.9572 - val_loss: 39.2494 - val_crf_viterbi_accuracy: 0.9574
# Epoch 4/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 38.9954 - crf_viterbi_accuracy: 0.9638 - val_loss: 39.2360 - val_crf_viterbi_accuracy: 0.9605
# Epoch 5/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 38.9774 - crf_viterbi_accuracy: 0.9679 - val_loss: 39.2341 - val_crf_viterbi_accuracy: 0.9586
# Epoch 6/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 38.9662 - crf_viterbi_accuracy: 0.9707 - val_loss: 39.2207 - val_crf_viterbi_accuracy: 0.9652
# Epoch 7/20
# 9360/9360 [==============================] - 207s 22ms/step - loss: 38.9560 - crf_viterbi_accuracy: 0.9733 - val_loss: 39.2156 - val_crf_viterbi_accuracy: 0.9677
# Epoch 8/20
# 9360/9360 [==============================] - 205s 22ms/step - loss: 38.9454 - crf_viterbi_accuracy: 0.9770 - val_loss: 39.2156 - val_crf_viterbi_accuracy: 0.9675
# Epoch 9/20
# 9360/9360 [==============================] - 209s 22ms/step - loss: 38.9407 - crf_viterbi_accuracy: 0.9778 - val_loss: 39.2122 - val_crf_viterbi_accuracy: 0.9674
# Epoch 10/20
# 9360/9360 [==============================] - 207s 22ms/step - loss: 38.9356 - crf_viterbi_accuracy: 0.9796 - val_loss: 39.2137 - val_crf_viterbi_accuracy: 0.9672
# Epoch 11/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 38.9296 - crf_viterbi_accuracy: 0.9818 - val_loss: 39.2149 - val_crf_viterbi_accuracy: 0.9691
# FOLD Number: 5/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 209s 22ms/step - loss: 39.2653 - crf_viterbi_accuracy: 0.8990 - val_loss: 39.3277 - val_crf_viterbi_accuracy: 0.9409
# Epoch 2/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.0616 - crf_viterbi_accuracy: 0.9455 - val_loss: 39.2782 - val_crf_viterbi_accuracy: 0.9527
# Epoch 3/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.0199 - crf_viterbi_accuracy: 0.9561 - val_loss: 39.2596 - val_crf_viterbi_accuracy: 0.9585
# Epoch 4/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 38.9959 - crf_viterbi_accuracy: 0.9623 - val_loss: 39.2409 - val_crf_viterbi_accuracy: 0.9628
# Epoch 5/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 38.9788 - crf_viterbi_accuracy: 0.9665 - val_loss: 39.2343 - val_crf_viterbi_accuracy: 0.9642
# Epoch 6/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 38.9648 - crf_viterbi_accuracy: 0.9699 - val_loss: 39.2300 - val_crf_viterbi_accuracy: 0.9647
# Epoch 7/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 38.9544 - crf_viterbi_accuracy: 0.9732 - val_loss: 39.2240 - val_crf_viterbi_accuracy: 0.9658
# Epoch 8/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 38.9469 - crf_viterbi_accuracy: 0.9754 - val_loss: 39.2215 - val_crf_viterbi_accuracy: 0.9662
# Epoch 9/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 38.9398 - crf_viterbi_accuracy: 0.9775 - val_loss: 39.2182 - val_crf_viterbi_accuracy: 0.9683
# Epoch 10/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 38.9341 - crf_viterbi_accuracy: 0.9791 - val_loss: 39.2178 - val_crf_viterbi_accuracy: 0.9707
# Epoch 11/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 38.9303 - crf_viterbi_accuracy: 0.9809 - val_loss: 39.2159 - val_crf_viterbi_accuracy: 0.9713
# Epoch 12/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 38.9250 - crf_viterbi_accuracy: 0.9830 - val_loss: 39.2209 - val_crf_viterbi_accuracy: 0.9706
# Epoch 13/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 38.9207 - crf_viterbi_accuracy: 0.9849 - val_loss: 39.2210 - val_crf_viterbi_accuracy: 0.9702
# FOLD Number: 6/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 211s 23ms/step - loss: 39.4573 - crf_viterbi_accuracy: 0.9043 - val_loss: 38.8715 - val_crf_viterbi_accuracy: 0.9350
# Epoch 2/20
# 9361/9361 [==============================] - 209s 22ms/step - loss: 39.2773 - crf_viterbi_accuracy: 0.9471 - val_loss: 38.8168 - val_crf_viterbi_accuracy: 0.9528
# Epoch 3/20
# 9361/9361 [==============================] - 209s 22ms/step - loss: 39.2391 - crf_viterbi_accuracy: 0.9569 - val_loss: 38.8050 - val_crf_viterbi_accuracy: 0.9537
# Epoch 4/20
# 9361/9361 [==============================] - 210s 22ms/step - loss: 39.2160 - crf_viterbi_accuracy: 0.9633 - val_loss: 38.7822 - val_crf_viterbi_accuracy: 0.9631
# Epoch 5/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.2008 - crf_viterbi_accuracy: 0.9676 - val_loss: 38.7725 - val_crf_viterbi_accuracy: 0.9654
# Epoch 6/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.1885 - crf_viterbi_accuracy: 0.9710 - val_loss: 38.7679 - val_crf_viterbi_accuracy: 0.9655
# Epoch 7/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.1805 - crf_viterbi_accuracy: 0.9733 - val_loss: 38.7646 - val_crf_viterbi_accuracy: 0.9670
# Epoch 8/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.1712 - crf_viterbi_accuracy: 0.9757 - val_loss: 38.7636 - val_crf_viterbi_accuracy: 0.9683
# Epoch 9/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 39.1660 - crf_viterbi_accuracy: 0.9778 - val_loss: 38.7678 - val_crf_viterbi_accuracy: 0.9668
# Epoch 10/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.1581 - crf_viterbi_accuracy: 0.9806 - val_loss: 38.7609 - val_crf_viterbi_accuracy: 0.9685
# Epoch 11/20
# 9361/9361 [==============================] - 208s 22ms/step - loss: 39.1553 - crf_viterbi_accuracy: 0.9818 - val_loss: 38.7653 - val_crf_viterbi_accuracy: 0.9685
# Epoch 12/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.1516 - crf_viterbi_accuracy: 0.9829 - val_loss: 38.7603 - val_crf_viterbi_accuracy: 0.9710
# Epoch 13/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 39.1482 - crf_viterbi_accuracy: 0.9843 - val_loss: 38.7648 - val_crf_viterbi_accuracy: 0.9714
# Epoch 14/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 39.1440 - crf_viterbi_accuracy: 0.9867 - val_loss: 38.7639 - val_crf_viterbi_accuracy: 0.9715
# FOLD Number: 7/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 214s 23ms/step - loss: 39.2150 - crf_viterbi_accuracy: 0.9071 - val_loss: 39.3127 - val_crf_viterbi_accuracy: 0.9386
# Epoch 2/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 39.0520 - crf_viterbi_accuracy: 0.9471 - val_loss: 39.2709 - val_crf_viterbi_accuracy: 0.9510
# Epoch 3/20
# 9360/9360 [==============================] - 201s 22ms/step - loss: 39.0129 - crf_viterbi_accuracy: 0.9578 - val_loss: 39.2453 - val_crf_viterbi_accuracy: 0.9579
# Epoch 4/20
# 9360/9360 [==============================] - 200s 21ms/step - loss: 38.9908 - crf_viterbi_accuracy: 0.9642 - val_loss: 39.2376 - val_crf_viterbi_accuracy: 0.9592
# Epoch 5/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 38.9751 - crf_viterbi_accuracy: 0.9680 - val_loss: 39.2269 - val_crf_viterbi_accuracy: 0.9626
# Epoch 6/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 38.9625 - crf_viterbi_accuracy: 0.9716 - val_loss: 39.2161 - val_crf_viterbi_accuracy: 0.9660
# Epoch 7/20
# 9360/9360 [==============================] - 203s 22ms/step - loss: 38.9518 - crf_viterbi_accuracy: 0.9746 - val_loss: 39.2186 - val_crf_viterbi_accuracy: 0.9659
# Epoch 8/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 38.9444 - crf_viterbi_accuracy: 0.9763 - val_loss: 39.2118 - val_crf_viterbi_accuracy: 0.9685
# Epoch 9/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 38.9393 - crf_viterbi_accuracy: 0.9785 - val_loss: 39.2110 - val_crf_viterbi_accuracy: 0.9691
# Epoch 10/20
# 9360/9360 [==============================] - 206s 22ms/step - loss: 38.9319 - crf_viterbi_accuracy: 0.9806 - val_loss: 39.2154 - val_crf_viterbi_accuracy: 0.9682
# Epoch 11/20
# 9360/9360 [==============================] - 202s 22ms/step - loss: 38.9277 - crf_viterbi_accuracy: 0.9826 - val_loss: 39.2133 - val_crf_viterbi_accuracy: 0.9699
# FOLD Number: 8/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 210s 22ms/step - loss: 39.2136 - crf_viterbi_accuracy: 0.9090 - val_loss: 39.3211 - val_crf_viterbi_accuracy: 0.9387
# Epoch 2/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.0464 - crf_viterbi_accuracy: 0.9479 - val_loss: 39.2687 - val_crf_viterbi_accuracy: 0.9542
# Epoch 3/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.0115 - crf_viterbi_accuracy: 0.9573 - val_loss: 39.2540 - val_crf_viterbi_accuracy: 0.9578
# Epoch 4/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 38.9888 - crf_viterbi_accuracy: 0.9627 - val_loss: 39.2359 - val_crf_viterbi_accuracy: 0.9616
# Epoch 5/20
# 9361/9361 [==============================] - 202s 22ms/step - loss: 38.9725 - crf_viterbi_accuracy: 0.9673 - val_loss: 39.2277 - val_crf_viterbi_accuracy: 0.9642
# Epoch 6/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 38.9608 - crf_viterbi_accuracy: 0.9696 - val_loss: 39.2259 - val_crf_viterbi_accuracy: 0.9657
# Epoch 7/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 38.9507 - crf_viterbi_accuracy: 0.9738 - val_loss: 39.2194 - val_crf_viterbi_accuracy: 0.9657
# Epoch 8/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 38.9426 - crf_viterbi_accuracy: 0.9762 - val_loss: 39.2143 - val_crf_viterbi_accuracy: 0.9694
# Epoch 9/20
# 9361/9361 [==============================] - 207s 22ms/step - loss: 38.9366 - crf_viterbi_accuracy: 0.9773 - val_loss: 39.2155 - val_crf_viterbi_accuracy: 0.9691
# Epoch 10/20
# 9361/9361 [==============================] - 206s 22ms/step - loss: 38.9306 - crf_viterbi_accuracy: 0.9801 - val_loss: 39.2161 - val_crf_viterbi_accuracy: 0.9702
# FOLD Number: 9/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 212s 23ms/step - loss: 39.4669 - crf_viterbi_accuracy: 0.9027 - val_loss: 38.8751 - val_crf_viterbi_accuracy: 0.9377
# Epoch 2/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.2826 - crf_viterbi_accuracy: 0.9465 - val_loss: 38.8392 - val_crf_viterbi_accuracy: 0.9431
# Epoch 3/20
# 9361/9361 [==============================] - 203s 22ms/step - loss: 39.2433 - crf_viterbi_accuracy: 0.9567 - val_loss: 38.7975 - val_crf_viterbi_accuracy: 0.9591
# Epoch 4/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.2189 - crf_viterbi_accuracy: 0.9631 - val_loss: 38.7910 - val_crf_viterbi_accuracy: 0.9581
# Epoch 5/20
# 9361/9361 [==============================] - 201s 21ms/step - loss: 39.2025 - crf_viterbi_accuracy: 0.9671 - val_loss: 38.7811 - val_crf_viterbi_accuracy: 0.9623
# Epoch 6/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.1912 - crf_viterbi_accuracy: 0.9706 - val_loss: 38.7713 - val_crf_viterbi_accuracy: 0.9650
# Epoch 7/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.1801 - crf_viterbi_accuracy: 0.9734 - val_loss: 38.7700 - val_crf_viterbi_accuracy: 0.9669
# Epoch 8/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.1734 - crf_viterbi_accuracy: 0.9753 - val_loss: 38.7680 - val_crf_viterbi_accuracy: 0.9666
# Epoch 9/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 39.1668 - crf_viterbi_accuracy: 0.9777 - val_loss: 38.7633 - val_crf_viterbi_accuracy: 0.9689
# Epoch 10/20
# 9361/9361 [==============================] - 195s 21ms/step - loss: 39.1612 - crf_viterbi_accuracy: 0.9796 - val_loss: 38.7650 - val_crf_viterbi_accuracy: 0.9677
# Epoch 11/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 39.1551 - crf_viterbi_accuracy: 0.9817 - val_loss: 38.7644 - val_crf_viterbi_accuracy: 0.9690
# FOLD Number: 10/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 208s 22ms/step - loss: 39.2153 - crf_viterbi_accuracy: 0.9083 - val_loss: 39.3154 - val_crf_viterbi_accuracy: 0.9379
# Epoch 2/20
# 9360/9360 [==============================] - 198s 21ms/step - loss: 39.0508 - crf_viterbi_accuracy: 0.9475 - val_loss: 39.2666 - val_crf_viterbi_accuracy: 0.9519
# Epoch 3/20
# 9360/9360 [==============================] - 197s 21ms/step - loss: 39.0107 - crf_viterbi_accuracy: 0.9581 - val_loss: 39.2453 - val_crf_viterbi_accuracy: 0.9573
# Epoch 4/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9899 - crf_viterbi_accuracy: 0.9636 - val_loss: 39.2386 - val_crf_viterbi_accuracy: 0.9582
# Epoch 5/20
# 9360/9360 [==============================] - 196s 21ms/step - loss: 38.9732 - crf_viterbi_accuracy: 0.9686 - val_loss: 39.2222 - val_crf_viterbi_accuracy: 0.9626
# Epoch 6/20
# 9360/9360 [==============================] - 196s 21ms/step - loss: 38.9613 - crf_viterbi_accuracy: 0.9714 - val_loss: 39.2151 - val_crf_viterbi_accuracy: 0.9658
# Epoch 7/20
# 9360/9360 [==============================] - 195s 21ms/step - loss: 38.9512 - crf_viterbi_accuracy: 0.9745 - val_loss: 39.2164 - val_crf_viterbi_accuracy: 0.9641
# Epoch 8/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9424 - crf_viterbi_accuracy: 0.9771 - val_loss: 39.2119 - val_crf_viterbi_accuracy: 0.9679
# Epoch 9/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9357 - crf_viterbi_accuracy: 0.9796 - val_loss: 39.2131 - val_crf_viterbi_accuracy: 0.9658
# Epoch 10/20
# 9360/9360 [==============================] - 198s 21ms/step - loss: 38.9312 - crf_viterbi_accuracy: 0.9811 - val_loss: 39.2122 - val_crf_viterbi_accuracy: 0.9668
# FOLD Number: 11/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 205s 22ms/step - loss: 39.2347 - crf_viterbi_accuracy: 0.9035 - val_loss: 39.3200 - val_crf_viterbi_accuracy: 0.9404
# Epoch 2/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.0512 - crf_viterbi_accuracy: 0.9472 - val_loss: 39.2685 - val_crf_viterbi_accuracy: 0.9544
# Epoch 3/20
# 9361/9361 [==============================] - 199s 21ms/step - loss: 39.0132 - crf_viterbi_accuracy: 0.9574 - val_loss: 39.2579 - val_crf_viterbi_accuracy: 0.9534
# Epoch 4/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 38.9906 - crf_viterbi_accuracy: 0.9626 - val_loss: 39.2389 - val_crf_viterbi_accuracy: 0.9613
# Epoch 5/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 38.9740 - crf_viterbi_accuracy: 0.9668 - val_loss: 39.2267 - val_crf_viterbi_accuracy: 0.9649
# Epoch 6/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 38.9622 - crf_viterbi_accuracy: 0.9706 - val_loss: 39.2245 - val_crf_viterbi_accuracy: 0.9636
# Epoch 7/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 38.9528 - crf_viterbi_accuracy: 0.9731 - val_loss: 39.2197 - val_crf_viterbi_accuracy: 0.9677
# Epoch 8/20
# 9361/9361 [==============================] - 195s 21ms/step - loss: 38.9439 - crf_viterbi_accuracy: 0.9759 - val_loss: 39.2193 - val_crf_viterbi_accuracy: 0.9655
# Epoch 9/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 38.9380 - crf_viterbi_accuracy: 0.9778 - val_loss: 39.2244 - val_crf_viterbi_accuracy: 0.9634
# Epoch 10/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 38.9323 - crf_viterbi_accuracy: 0.9800 - val_loss: 39.2193 - val_crf_viterbi_accuracy: 0.9677
# Epoch 11/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 38.9277 - crf_viterbi_accuracy: 0.9804 - val_loss: 39.2164 - val_crf_viterbi_accuracy: 0.9701
# Epoch 12/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 38.9235 - crf_viterbi_accuracy: 0.9831 - val_loss: 39.2191 - val_crf_viterbi_accuracy: 0.9667
# Epoch 13/20
# 9361/9361 [==============================] - 192s 21ms/step - loss: 38.9193 - crf_viterbi_accuracy: 0.9851 - val_loss: 39.2193 - val_crf_viterbi_accuracy: 0.9710
# FOLD Number: 12/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 204s 22ms/step - loss: 39.4477 - crf_viterbi_accuracy: 0.9084 - val_loss: 38.8675 - val_crf_viterbi_accuracy: 0.9387
# Epoch 2/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.2785 - crf_viterbi_accuracy: 0.9479 - val_loss: 38.8206 - val_crf_viterbi_accuracy: 0.9509
# Epoch 3/20
# 9361/9361 [==============================] - 196s 21ms/step - loss: 39.2406 - crf_viterbi_accuracy: 0.9576 - val_loss: 38.8030 - val_crf_viterbi_accuracy: 0.9568
# Epoch 4/20
# 9361/9361 [==============================] - 195s 21ms/step - loss: 39.2187 - crf_viterbi_accuracy: 0.9632 - val_loss: 38.7858 - val_crf_viterbi_accuracy: 0.9602
# Epoch 5/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.2021 - crf_viterbi_accuracy: 0.9677 - val_loss: 38.7760 - val_crf_viterbi_accuracy: 0.9644
# Epoch 6/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 39.1880 - crf_viterbi_accuracy: 0.9715 - val_loss: 38.7680 - val_crf_viterbi_accuracy: 0.9664
# Epoch 7/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.1800 - crf_viterbi_accuracy: 0.9737 - val_loss: 38.7660 - val_crf_viterbi_accuracy: 0.9654
# Epoch 8/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.1725 - crf_viterbi_accuracy: 0.9750 - val_loss: 38.7646 - val_crf_viterbi_accuracy: 0.9676
# Epoch 9/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 39.1661 - crf_viterbi_accuracy: 0.9776 - val_loss: 38.7634 - val_crf_viterbi_accuracy: 0.9679
# Epoch 10/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 39.1608 - crf_viterbi_accuracy: 0.9796 - val_loss: 38.7660 - val_crf_viterbi_accuracy: 0.9692
# Epoch 11/20
# 9361/9361 [==============================] - 197s 21ms/step - loss: 39.1545 - crf_viterbi_accuracy: 0.9818 - val_loss: 38.7638 - val_crf_viterbi_accuracy: 0.9698
# CPU times: user 11h 33min 6s, sys: 47min 34s, total: 12h 20min 40s
# Wall time: 7h 47min 37s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("Clipping").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#           train_loss  train_acc   val_loss   val_acc     epochs
# Clipping
# 1          38.998089   0.984455  39.066604  0.970249  12.666667
# 2          39.004460   0.981465  39.064592  0.969690  10.666667
# 5          39.001637   0.982672  39.065132  0.969245  11.333333
# 0          39.002823   0.982567  39.075038  0.968866  11.333333

# %%
from google.colab import files
df_results.to_csv('Clipping_grid_Glove.csv')
files.download('Clipping_grid_Glove.csv')
