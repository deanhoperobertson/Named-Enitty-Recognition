# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/GloVe/BiLSTM-CRF%20GLOVE%20(Dropout).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-t2wt5mo4
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-t2wt5mo4
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=d6df5578e1eef90822f71139f4bdd2e9db7d1bffeed9dd15b2f2c31a302a153a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lg3f2h1d/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Requirement already satisfied: sklearn_crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# TensorFlow 1.x selected.

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2
# Using TensorFlow backend.

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_path = "/content/drive/My Drive/glove.6B.50d.txt"
#root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
DROPOUTS = [0, 0.05, 0.10, 0.25, 0.50]
CELLS =200
BATCH_SIZE= 32
EPOCHS=20
fold_count = 1

for DROP in DROPOUTS:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(DROPOUTS)*3))
    
    #split data
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(DROP):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=CELLS, return_sequences=True,
                                recurrent_dropout=DROP, dropout=DROP))(model_2)
      model_2 = TimeDistributed(Dense(20, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer="adam", loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

  #---------Fit Model-----------------
    model = create_model(DROP)
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "Dropout": DROP,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/15
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2974: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 263s 28ms/step - loss: 39.2484 - crf_viterbi_accuracy: 0.9014 - val_loss: 39.3384 - val_crf_viterbi_accuracy: 0.9322
# Epoch 2/20
# 9360/9360 [==============================] - 267s 29ms/step - loss: 39.0597 - crf_viterbi_accuracy: 0.9466 - val_loss: 39.2796 - val_crf_viterbi_accuracy: 0.9496
# Epoch 3/20
# 9360/9360 [==============================] - 266s 28ms/step - loss: 39.0187 - crf_viterbi_accuracy: 0.9577 - val_loss: 39.2545 - val_crf_viterbi_accuracy: 0.9558
# Epoch 4/20
# 9360/9360 [==============================] - 268s 29ms/step - loss: 38.9903 - crf_viterbi_accuracy: 0.9655 - val_loss: 39.2363 - val_crf_viterbi_accuracy: 0.9609
# Epoch 5/20
# 9360/9360 [==============================] - 263s 28ms/step - loss: 38.9716 - crf_viterbi_accuracy: 0.9702 - val_loss: 39.2279 - val_crf_viterbi_accuracy: 0.9627
# Epoch 6/20
# 9360/9360 [==============================] - 260s 28ms/step - loss: 38.9567 - crf_viterbi_accuracy: 0.9750 - val_loss: 39.2211 - val_crf_viterbi_accuracy: 0.9650
# Epoch 7/20
# 9360/9360 [==============================] - 260s 28ms/step - loss: 38.9458 - crf_viterbi_accuracy: 0.9772 - val_loss: 39.2154 - val_crf_viterbi_accuracy: 0.9662
# Epoch 8/20
# 9360/9360 [==============================] - 266s 28ms/step - loss: 38.9361 - crf_viterbi_accuracy: 0.9809 - val_loss: 39.2203 - val_crf_viterbi_accuracy: 0.9635
# Epoch 9/20
# 9360/9360 [==============================] - 264s 28ms/step - loss: 38.9278 - crf_viterbi_accuracy: 0.9844 - val_loss: 39.2208 - val_crf_viterbi_accuracy: 0.9654
# FOLD Number: 2/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 268s 29ms/step - loss: 39.2439 - crf_viterbi_accuracy: 0.9022 - val_loss: 39.3314 - val_crf_viterbi_accuracy: 0.9387
# Epoch 2/20
# 9361/9361 [==============================] - 266s 28ms/step - loss: 39.0527 - crf_viterbi_accuracy: 0.9472 - val_loss: 39.2785 - val_crf_viterbi_accuracy: 0.9538
# Epoch 3/20
# 9361/9361 [==============================] - 265s 28ms/step - loss: 39.0111 - crf_viterbi_accuracy: 0.9589 - val_loss: 39.2553 - val_crf_viterbi_accuracy: 0.9582
# Epoch 4/20
# 9361/9361 [==============================] - 262s 28ms/step - loss: 38.9863 - crf_viterbi_accuracy: 0.9653 - val_loss: 39.2398 - val_crf_viterbi_accuracy: 0.9624
# Epoch 5/20
# 9361/9361 [==============================] - 264s 28ms/step - loss: 38.9679 - crf_viterbi_accuracy: 0.9700 - val_loss: 39.2316 - val_crf_viterbi_accuracy: 0.9649
# Epoch 6/20
# 9361/9361 [==============================] - 269s 29ms/step - loss: 38.9540 - crf_viterbi_accuracy: 0.9743 - val_loss: 39.2264 - val_crf_viterbi_accuracy: 0.9655
# Epoch 7/20
# 9361/9361 [==============================] - 266s 28ms/step - loss: 38.9426 - crf_viterbi_accuracy: 0.9774 - val_loss: 39.2255 - val_crf_viterbi_accuracy: 0.9651
# Epoch 8/20
# 9361/9361 [==============================] - 261s 28ms/step - loss: 38.9326 - crf_viterbi_accuracy: 0.9815 - val_loss: 39.2245 - val_crf_viterbi_accuracy: 0.9659
# Epoch 9/20
# 9361/9361 [==============================] - 264s 28ms/step - loss: 38.9252 - crf_viterbi_accuracy: 0.9847 - val_loss: 39.2227 - val_crf_viterbi_accuracy: 0.9681
# Epoch 10/20
# 9361/9361 [==============================] - 268s 29ms/step - loss: 38.9180 - crf_viterbi_accuracy: 0.9880 - val_loss: 39.2319 - val_crf_viterbi_accuracy: 0.9664
# Epoch 11/20
# 9361/9361 [==============================] - 266s 28ms/step - loss: 38.9123 - crf_viterbi_accuracy: 0.9906 - val_loss: 39.2368 - val_crf_viterbi_accuracy: 0.9630
# FOLD Number: 3/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 268s 29ms/step - loss: 39.5299 - crf_viterbi_accuracy: 0.8910 - val_loss: 38.8848 - val_crf_viterbi_accuracy: 0.9335
# Epoch 2/20
# 9361/9361 [==============================] - 270s 29ms/step - loss: 39.2849 - crf_viterbi_accuracy: 0.9469 - val_loss: 38.8308 - val_crf_viterbi_accuracy: 0.9503
# Epoch 3/20
# 9361/9361 [==============================] - 261s 28ms/step - loss: 39.2430 - crf_viterbi_accuracy: 0.9582 - val_loss: 38.8037 - val_crf_viterbi_accuracy: 0.9580
# Epoch 4/20
# 9361/9361 [==============================] - 257s 27ms/step - loss: 39.2170 - crf_viterbi_accuracy: 0.9647 - val_loss: 38.7895 - val_crf_viterbi_accuracy: 0.9604
# Epoch 5/20
# 9361/9361 [==============================] - 255s 27ms/step - loss: 39.1987 - crf_viterbi_accuracy: 0.9689 - val_loss: 38.7781 - val_crf_viterbi_accuracy: 0.9627
# Epoch 6/20
# 9361/9361 [==============================] - 259s 28ms/step - loss: 39.1846 - crf_viterbi_accuracy: 0.9735 - val_loss: 38.7715 - val_crf_viterbi_accuracy: 0.9657
# Epoch 7/20
# 9361/9361 [==============================] - 261s 28ms/step - loss: 39.1727 - crf_viterbi_accuracy: 0.9767 - val_loss: 38.7736 - val_crf_viterbi_accuracy: 0.9630
# Epoch 8/20
# 9361/9361 [==============================] - 262s 28ms/step - loss: 39.1644 - crf_viterbi_accuracy: 0.9795 - val_loss: 38.7680 - val_crf_viterbi_accuracy: 0.9669
# Epoch 9/20
# 9361/9361 [==============================] - 265s 28ms/step - loss: 39.1555 - crf_viterbi_accuracy: 0.9832 - val_loss: 38.7720 - val_crf_viterbi_accuracy: 0.9661
# Epoch 10/20
# 9361/9361 [==============================] - 266s 28ms/step - loss: 39.1484 - crf_viterbi_accuracy: 0.9864 - val_loss: 38.7690 - val_crf_viterbi_accuracy: 0.9684
# FOLD Number: 4/15
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 284s 30ms/step - loss: 39.2629 - crf_viterbi_accuracy: 0.8983 - val_loss: 39.3308 - val_crf_viterbi_accuracy: 0.9346
# Epoch 2/20
# 9360/9360 [==============================] - 283s 30ms/step - loss: 39.0650 - crf_viterbi_accuracy: 0.9431 - val_loss: 39.2805 - val_crf_viterbi_accuracy: 0.9491
# Epoch 3/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 39.0225 - crf_viterbi_accuracy: 0.9556 - val_loss: 39.2568 - val_crf_viterbi_accuracy: 0.9554
# Epoch 4/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 38.9981 - crf_viterbi_accuracy: 0.9623 - val_loss: 39.2392 - val_crf_viterbi_accuracy: 0.9593
# Epoch 5/20
# 9360/9360 [==============================] - 282s 30ms/step - loss: 38.9793 - crf_viterbi_accuracy: 0.9674 - val_loss: 39.2351 - val_crf_viterbi_accuracy: 0.9613
# Epoch 6/20
# 9360/9360 [==============================] - 276s 30ms/step - loss: 38.9655 - crf_viterbi_accuracy: 0.9712 - val_loss: 39.2269 - val_crf_viterbi_accuracy: 0.9616
# Epoch 7/20
# 9360/9360 [==============================] - 280s 30ms/step - loss: 38.9547 - crf_viterbi_accuracy: 0.9748 - val_loss: 39.2199 - val_crf_viterbi_accuracy: 0.9645
# Epoch 8/20
# 9360/9360 [==============================] - 283s 30ms/step - loss: 38.9448 - crf_viterbi_accuracy: 0.9771 - val_loss: 39.2196 - val_crf_viterbi_accuracy: 0.9651
# Epoch 9/20
# 9360/9360 [==============================] - 284s 30ms/step - loss: 38.9366 - crf_viterbi_accuracy: 0.9804 - val_loss: 39.2195 - val_crf_viterbi_accuracy: 0.9606
# Epoch 10/20
# 9360/9360 [==============================] - 283s 30ms/step - loss: 38.9305 - crf_viterbi_accuracy: 0.9820 - val_loss: 39.2121 - val_crf_viterbi_accuracy: 0.9685
# Epoch 11/20
# 9360/9360 [==============================] - 281s 30ms/step - loss: 38.9251 - crf_viterbi_accuracy: 0.9847 - val_loss: 39.2166 - val_crf_viterbi_accuracy: 0.9667
# Epoch 12/20
# 9360/9360 [==============================] - 280s 30ms/step - loss: 38.9208 - crf_viterbi_accuracy: 0.9860 - val_loss: 39.2155 - val_crf_viterbi_accuracy: 0.9663
# FOLD Number: 5/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 286s 31ms/step - loss: 39.2657 - crf_viterbi_accuracy: 0.8995 - val_loss: 39.3348 - val_crf_viterbi_accuracy: 0.9376
# Epoch 2/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 39.0648 - crf_viterbi_accuracy: 0.9424 - val_loss: 39.2863 - val_crf_viterbi_accuracy: 0.9496
# Epoch 3/20
# 9361/9361 [==============================] - 285s 30ms/step - loss: 39.0230 - crf_viterbi_accuracy: 0.9550 - val_loss: 39.2572 - val_crf_viterbi_accuracy: 0.9575
# Epoch 4/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 38.9977 - crf_viterbi_accuracy: 0.9614 - val_loss: 39.2465 - val_crf_viterbi_accuracy: 0.9605
# Epoch 5/20
# 9361/9361 [==============================] - 285s 30ms/step - loss: 38.9780 - crf_viterbi_accuracy: 0.9666 - val_loss: 39.2322 - val_crf_viterbi_accuracy: 0.9639
# Epoch 6/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 38.9642 - crf_viterbi_accuracy: 0.9708 - val_loss: 39.2255 - val_crf_viterbi_accuracy: 0.9668
# Epoch 7/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 38.9531 - crf_viterbi_accuracy: 0.9732 - val_loss: 39.2215 - val_crf_viterbi_accuracy: 0.9683
# Epoch 8/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 38.9445 - crf_viterbi_accuracy: 0.9764 - val_loss: 39.2234 - val_crf_viterbi_accuracy: 0.9662
# Epoch 9/20
# 9361/9361 [==============================] - 287s 31ms/step - loss: 38.9377 - crf_viterbi_accuracy: 0.9790 - val_loss: 39.2220 - val_crf_viterbi_accuracy: 0.9695
# FOLD Number: 6/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 288s 31ms/step - loss: 39.4885 - crf_viterbi_accuracy: 0.9001 - val_loss: 38.8785 - val_crf_viterbi_accuracy: 0.9374
# Epoch 2/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.2900 - crf_viterbi_accuracy: 0.9445 - val_loss: 38.8293 - val_crf_viterbi_accuracy: 0.9506
# Epoch 3/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 39.2501 - crf_viterbi_accuracy: 0.9551 - val_loss: 38.8046 - val_crf_viterbi_accuracy: 0.9573
# Epoch 4/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 39.2241 - crf_viterbi_accuracy: 0.9617 - val_loss: 38.7920 - val_crf_viterbi_accuracy: 0.9591
# Epoch 5/20
# 9361/9361 [==============================] - 285s 30ms/step - loss: 39.2065 - crf_viterbi_accuracy: 0.9663 - val_loss: 38.7808 - val_crf_viterbi_accuracy: 0.9643
# Epoch 6/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.1930 - crf_viterbi_accuracy: 0.9695 - val_loss: 38.7735 - val_crf_viterbi_accuracy: 0.9663
# Epoch 7/20
# 9361/9361 [==============================] - 283s 30ms/step - loss: 39.1820 - crf_viterbi_accuracy: 0.9733 - val_loss: 38.7686 - val_crf_viterbi_accuracy: 0.9673
# Epoch 8/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 39.1719 - crf_viterbi_accuracy: 0.9764 - val_loss: 38.7692 - val_crf_viterbi_accuracy: 0.9657
# Epoch 9/20
# 9361/9361 [==============================] - 283s 30ms/step - loss: 39.1645 - crf_viterbi_accuracy: 0.9787 - val_loss: 38.7661 - val_crf_viterbi_accuracy: 0.9677
# Epoch 10/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.1585 - crf_viterbi_accuracy: 0.9813 - val_loss: 38.7717 - val_crf_viterbi_accuracy: 0.9662
# Epoch 11/20
# 9361/9361 [==============================] - 291s 31ms/step - loss: 39.1537 - crf_viterbi_accuracy: 0.9827 - val_loss: 38.7689 - val_crf_viterbi_accuracy: 0.9677
# FOLD Number: 7/15
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 292s 31ms/step - loss: 39.2743 - crf_viterbi_accuracy: 0.8998 - val_loss: 39.3226 - val_crf_viterbi_accuracy: 0.9354
# Epoch 2/20
# 9360/9360 [==============================] - 286s 31ms/step - loss: 39.0628 - crf_viterbi_accuracy: 0.9445 - val_loss: 39.2737 - val_crf_viterbi_accuracy: 0.9508
# Epoch 3/20
# 9360/9360 [==============================] - 285s 30ms/step - loss: 39.0219 - crf_viterbi_accuracy: 0.9555 - val_loss: 39.2500 - val_crf_viterbi_accuracy: 0.9576
# Epoch 4/20
# 9360/9360 [==============================] - 281s 30ms/step - loss: 38.9986 - crf_viterbi_accuracy: 0.9615 - val_loss: 39.2378 - val_crf_viterbi_accuracy: 0.9601
# Epoch 5/20
# 9360/9360 [==============================] - 284s 30ms/step - loss: 38.9814 - crf_viterbi_accuracy: 0.9667 - val_loss: 39.2292 - val_crf_viterbi_accuracy: 0.9621
# Epoch 6/20
# 9360/9360 [==============================] - 285s 30ms/step - loss: 38.9665 - crf_viterbi_accuracy: 0.9695 - val_loss: 39.2261 - val_crf_viterbi_accuracy: 0.9596
# Epoch 7/20
# 9360/9360 [==============================] - 284s 30ms/step - loss: 38.9580 - crf_viterbi_accuracy: 0.9725 - val_loss: 39.2188 - val_crf_viterbi_accuracy: 0.9648
# Epoch 8/20
# 9360/9360 [==============================] - 285s 30ms/step - loss: 38.9498 - crf_viterbi_accuracy: 0.9747 - val_loss: 39.2118 - val_crf_viterbi_accuracy: 0.9670
# Epoch 9/20
# 9360/9360 [==============================] - 287s 31ms/step - loss: 38.9433 - crf_viterbi_accuracy: 0.9770 - val_loss: 39.2118 - val_crf_viterbi_accuracy: 0.9681
# Epoch 10/20
# 9360/9360 [==============================] - 281s 30ms/step - loss: 38.9357 - crf_viterbi_accuracy: 0.9795 - val_loss: 39.2124 - val_crf_viterbi_accuracy: 0.9668
# FOLD Number: 8/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 286s 31ms/step - loss: 39.3048 - crf_viterbi_accuracy: 0.8856 - val_loss: 39.3405 - val_crf_viterbi_accuracy: 0.9347
# Epoch 2/20
# 9361/9361 [==============================] - 278s 30ms/step - loss: 39.0762 - crf_viterbi_accuracy: 0.9392 - val_loss: 39.2853 - val_crf_viterbi_accuracy: 0.9504
# Epoch 3/20
# 9361/9361 [==============================] - 283s 30ms/step - loss: 39.0301 - crf_viterbi_accuracy: 0.9515 - val_loss: 39.2608 - val_crf_viterbi_accuracy: 0.9561
# Epoch 4/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.0046 - crf_viterbi_accuracy: 0.9589 - val_loss: 39.2496 - val_crf_viterbi_accuracy: 0.9587
# Epoch 5/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 38.9865 - crf_viterbi_accuracy: 0.9635 - val_loss: 39.2410 - val_crf_viterbi_accuracy: 0.9590
# Epoch 6/20
# 9361/9361 [==============================] - 286s 31ms/step - loss: 38.9725 - crf_viterbi_accuracy: 0.9668 - val_loss: 39.2336 - val_crf_viterbi_accuracy: 0.9626
# Epoch 7/20
# 9361/9361 [==============================] - 288s 31ms/step - loss: 38.9612 - crf_viterbi_accuracy: 0.9706 - val_loss: 39.2226 - val_crf_viterbi_accuracy: 0.9670
# Epoch 8/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 38.9531 - crf_viterbi_accuracy: 0.9728 - val_loss: 39.2260 - val_crf_viterbi_accuracy: 0.9648
# Epoch 9/20
# 9361/9361 [==============================] - 285s 30ms/step - loss: 38.9448 - crf_viterbi_accuracy: 0.9753 - val_loss: 39.2193 - val_crf_viterbi_accuracy: 0.9683
# Epoch 10/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 38.9384 - crf_viterbi_accuracy: 0.9778 - val_loss: 39.2163 - val_crf_viterbi_accuracy: 0.9701
# Epoch 11/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 38.9336 - crf_viterbi_accuracy: 0.9797 - val_loss: 39.2179 - val_crf_viterbi_accuracy: 0.9692
# Epoch 12/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 38.9290 - crf_viterbi_accuracy: 0.9813 - val_loss: 39.2182 - val_crf_viterbi_accuracy: 0.9705
# FOLD Number: 9/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 290s 31ms/step - loss: 39.5404 - crf_viterbi_accuracy: 0.8915 - val_loss: 38.8910 - val_crf_viterbi_accuracy: 0.9301
# Epoch 2/20
# 9361/9361 [==============================] - 287s 31ms/step - loss: 39.2944 - crf_viterbi_accuracy: 0.9412 - val_loss: 38.8305 - val_crf_viterbi_accuracy: 0.9474
# Epoch 3/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.2532 - crf_viterbi_accuracy: 0.9538 - val_loss: 38.8066 - val_crf_viterbi_accuracy: 0.9552
# Epoch 4/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 39.2293 - crf_viterbi_accuracy: 0.9600 - val_loss: 38.7928 - val_crf_viterbi_accuracy: 0.9592
# Epoch 5/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.2122 - crf_viterbi_accuracy: 0.9642 - val_loss: 38.7812 - val_crf_viterbi_accuracy: 0.9626
# Epoch 6/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.2000 - crf_viterbi_accuracy: 0.9675 - val_loss: 38.7791 - val_crf_viterbi_accuracy: 0.9623
# Epoch 7/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 39.1902 - crf_viterbi_accuracy: 0.9707 - val_loss: 38.7678 - val_crf_viterbi_accuracy: 0.9669
# Epoch 8/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.1803 - crf_viterbi_accuracy: 0.9730 - val_loss: 38.7722 - val_crf_viterbi_accuracy: 0.9651
# Epoch 9/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 39.1744 - crf_viterbi_accuracy: 0.9749 - val_loss: 38.7632 - val_crf_viterbi_accuracy: 0.9667
# Epoch 10/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 39.1680 - crf_viterbi_accuracy: 0.9769 - val_loss: 38.7630 - val_crf_viterbi_accuracy: 0.9695
# Epoch 11/20
# 9361/9361 [==============================] - 270s 29ms/step - loss: 39.1614 - crf_viterbi_accuracy: 0.9791 - val_loss: 38.7640 - val_crf_viterbi_accuracy: 0.9689
# Epoch 12/20
# 9361/9361 [==============================] - 264s 28ms/step - loss: 39.1580 - crf_viterbi_accuracy: 0.9812 - val_loss: 38.7619 - val_crf_viterbi_accuracy: 0.9703
# Epoch 13/20
# 9361/9361 [==============================] - 263s 28ms/step - loss: 39.1529 - crf_viterbi_accuracy: 0.9827 - val_loss: 38.7639 - val_crf_viterbi_accuracy: 0.9685
# Epoch 14/20
# 9361/9361 [==============================] - 261s 28ms/step - loss: 39.1506 - crf_viterbi_accuracy: 0.9835 - val_loss: 38.7613 - val_crf_viterbi_accuracy: 0.9706
# Epoch 15/20
# 9361/9361 [==============================] - 262s 28ms/step - loss: 39.1463 - crf_viterbi_accuracy: 0.9855 - val_loss: 38.7647 - val_crf_viterbi_accuracy: 0.9709
# Epoch 16/20
# 9361/9361 [==============================] - 263s 28ms/step - loss: 39.1428 - crf_viterbi_accuracy: 0.9876 - val_loss: 38.7676 - val_crf_viterbi_accuracy: 0.9704
# FOLD Number: 10/15
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 264s 28ms/step - loss: 39.3012 - crf_viterbi_accuracy: 0.8900 - val_loss: 39.3440 - val_crf_viterbi_accuracy: 0.9312
# Epoch 2/20
# 9360/9360 [==============================] - 261s 28ms/step - loss: 39.0914 - crf_viterbi_accuracy: 0.9362 - val_loss: 39.2883 - val_crf_viterbi_accuracy: 0.9477
# Epoch 3/20
# 9360/9360 [==============================] - 258s 28ms/step - loss: 39.0454 - crf_viterbi_accuracy: 0.9496 - val_loss: 39.2626 - val_crf_viterbi_accuracy: 0.9535
# Epoch 4/20
# 9360/9360 [==============================] - 259s 28ms/step - loss: 39.0214 - crf_viterbi_accuracy: 0.9548 - val_loss: 39.2457 - val_crf_viterbi_accuracy: 0.9580
# Epoch 5/20
# 9360/9360 [==============================] - 252s 27ms/step - loss: 39.0027 - crf_viterbi_accuracy: 0.9595 - val_loss: 39.2378 - val_crf_viterbi_accuracy: 0.9601
# Epoch 6/20
# 9360/9360 [==============================] - 254s 27ms/step - loss: 38.9897 - crf_viterbi_accuracy: 0.9633 - val_loss: 39.2262 - val_crf_viterbi_accuracy: 0.9625
# Epoch 7/20
# 9360/9360 [==============================] - 252s 27ms/step - loss: 38.9813 - crf_viterbi_accuracy: 0.9650 - val_loss: 39.2213 - val_crf_viterbi_accuracy: 0.9642
# Epoch 8/20
# 9360/9360 [==============================] - 251s 27ms/step - loss: 38.9700 - crf_viterbi_accuracy: 0.9677 - val_loss: 39.2197 - val_crf_viterbi_accuracy: 0.9625
# Epoch 9/20
# 9360/9360 [==============================] - 254s 27ms/step - loss: 38.9656 - crf_viterbi_accuracy: 0.9692 - val_loss: 39.2174 - val_crf_viterbi_accuracy: 0.9659
# Epoch 10/20
# 9360/9360 [==============================] - 251s 27ms/step - loss: 38.9585 - crf_viterbi_accuracy: 0.9715 - val_loss: 39.2112 - val_crf_viterbi_accuracy: 0.9678
# Epoch 11/20
# 9360/9360 [==============================] - 251s 27ms/step - loss: 38.9535 - crf_viterbi_accuracy: 0.9736 - val_loss: 39.2115 - val_crf_viterbi_accuracy: 0.9684
# Epoch 12/20
# 9360/9360 [==============================] - 250s 27ms/step - loss: 38.9488 - crf_viterbi_accuracy: 0.9742 - val_loss: 39.2069 - val_crf_viterbi_accuracy: 0.9686
# Epoch 13/20
# 9360/9360 [==============================] - 251s 27ms/step - loss: 38.9448 - crf_viterbi_accuracy: 0.9753 - val_loss: 39.2066 - val_crf_viterbi_accuracy: 0.9692
# Epoch 14/20
# 9360/9360 [==============================] - 253s 27ms/step - loss: 38.9418 - crf_viterbi_accuracy: 0.9763 - val_loss: 39.2083 - val_crf_viterbi_accuracy: 0.9703
# Epoch 15/20
# 9360/9360 [==============================] - 254s 27ms/step - loss: 38.9376 - crf_viterbi_accuracy: 0.9779 - val_loss: 39.2099 - val_crf_viterbi_accuracy: 0.9682
# FOLD Number: 11/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 260s 28ms/step - loss: 39.3242 - crf_viterbi_accuracy: 0.8849 - val_loss: 39.3465 - val_crf_viterbi_accuracy: 0.9328
# Epoch 2/20
# 9361/9361 [==============================] - 250s 27ms/step - loss: 39.0932 - crf_viterbi_accuracy: 0.9345 - val_loss: 39.2963 - val_crf_viterbi_accuracy: 0.9469
# Epoch 3/20
# 9361/9361 [==============================] - 250s 27ms/step - loss: 39.0473 - crf_viterbi_accuracy: 0.9465 - val_loss: 39.2683 - val_crf_viterbi_accuracy: 0.9554
# Epoch 4/20
# 9361/9361 [==============================] - 248s 27ms/step - loss: 39.0216 - crf_viterbi_accuracy: 0.9543 - val_loss: 39.2566 - val_crf_viterbi_accuracy: 0.9566
# Epoch 5/20
# 9361/9361 [==============================] - 249s 27ms/step - loss: 39.0032 - crf_viterbi_accuracy: 0.9585 - val_loss: 39.2387 - val_crf_viterbi_accuracy: 0.9619
# Epoch 6/20
# 9361/9361 [==============================] - 246s 26ms/step - loss: 38.9913 - crf_viterbi_accuracy: 0.9623 - val_loss: 39.2313 - val_crf_viterbi_accuracy: 0.9637
# Epoch 7/20
# 9361/9361 [==============================] - 244s 26ms/step - loss: 38.9792 - crf_viterbi_accuracy: 0.9645 - val_loss: 39.2278 - val_crf_viterbi_accuracy: 0.9645
# Epoch 8/20
# 9361/9361 [==============================] - 245s 26ms/step - loss: 38.9710 - crf_viterbi_accuracy: 0.9668 - val_loss: 39.2199 - val_crf_viterbi_accuracy: 0.9669
# Epoch 9/20
# 9361/9361 [==============================] - 246s 26ms/step - loss: 38.9643 - crf_viterbi_accuracy: 0.9686 - val_loss: 39.2145 - val_crf_viterbi_accuracy: 0.9692
# Epoch 10/20
# 9361/9361 [==============================] - 248s 26ms/step - loss: 38.9585 - crf_viterbi_accuracy: 0.9704 - val_loss: 39.2226 - val_crf_viterbi_accuracy: 0.9643
# Epoch 11/20
# 9361/9361 [==============================] - 250s 27ms/step - loss: 38.9521 - crf_viterbi_accuracy: 0.9717 - val_loss: 39.2242 - val_crf_viterbi_accuracy: 0.9613
# FOLD Number: 12/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 257s 27ms/step - loss: 39.6259 - crf_viterbi_accuracy: 0.8510 - val_loss: 38.9093 - val_crf_viterbi_accuracy: 0.9277
# Epoch 2/20
# 9361/9361 [==============================] - 250s 27ms/step - loss: 39.3356 - crf_viterbi_accuracy: 0.9285 - val_loss: 38.8617 - val_crf_viterbi_accuracy: 0.9379
# Epoch 3/20
# 9361/9361 [==============================] - 254s 27ms/step - loss: 39.2893 - crf_viterbi_accuracy: 0.9417 - val_loss: 38.8275 - val_crf_viterbi_accuracy: 0.9491
# Epoch 4/20
# 9361/9361 [==============================] - 249s 27ms/step - loss: 39.2632 - crf_viterbi_accuracy: 0.9481 - val_loss: 38.8061 - val_crf_viterbi_accuracy: 0.9560
# Epoch 5/20
# 9361/9361 [==============================] - 251s 27ms/step - loss: 39.2437 - crf_viterbi_accuracy: 0.9537 - val_loss: 38.7984 - val_crf_viterbi_accuracy: 0.9564
# Epoch 6/20
# 9361/9361 [==============================] - 250s 27ms/step - loss: 39.2299 - crf_viterbi_accuracy: 0.9579 - val_loss: 38.7835 - val_crf_viterbi_accuracy: 0.9611
# Epoch 7/20
# 9361/9361 [==============================] - 250s 27ms/step - loss: 39.2187 - crf_viterbi_accuracy: 0.9602 - val_loss: 38.7765 - val_crf_viterbi_accuracy: 0.9628
# Epoch 8/20
# 9361/9361 [==============================] - 250s 27ms/step - loss: 39.2082 - crf_viterbi_accuracy: 0.9632 - val_loss: 38.7705 - val_crf_viterbi_accuracy: 0.9643
# Epoch 9/20
# 9361/9361 [==============================] - 252s 27ms/step - loss: 39.2039 - crf_viterbi_accuracy: 0.9646 - val_loss: 38.7685 - val_crf_viterbi_accuracy: 0.9651
# Epoch 10/20
# 9361/9361 [==============================] - 268s 29ms/step - loss: 39.1951 - crf_viterbi_accuracy: 0.9669 - val_loss: 38.7657 - val_crf_viterbi_accuracy: 0.9655
# Epoch 11/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 39.1905 - crf_viterbi_accuracy: 0.9684 - val_loss: 38.7663 - val_crf_viterbi_accuracy: 0.9653
# Epoch 12/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 39.1868 - crf_viterbi_accuracy: 0.9689 - val_loss: 38.7636 - val_crf_viterbi_accuracy: 0.9657
# Epoch 13/20
# 9361/9361 [==============================] - 278s 30ms/step - loss: 39.1819 - crf_viterbi_accuracy: 0.9708 - val_loss: 38.7627 - val_crf_viterbi_accuracy: 0.9660
# Epoch 14/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.1785 - crf_viterbi_accuracy: 0.9719 - val_loss: 38.7599 - val_crf_viterbi_accuracy: 0.9666
# Epoch 15/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 39.1750 - crf_viterbi_accuracy: 0.9731 - val_loss: 38.7642 - val_crf_viterbi_accuracy: 0.9633
# Epoch 16/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.1716 - crf_viterbi_accuracy: 0.9743 - val_loss: 38.7563 - val_crf_viterbi_accuracy: 0.9676
# Epoch 17/20
# 9361/9361 [==============================] - 281s 30ms/step - loss: 39.1682 - crf_viterbi_accuracy: 0.9749 - val_loss: 38.7611 - val_crf_viterbi_accuracy: 0.9651
# Epoch 18/20
# 9361/9361 [==============================] - 278s 30ms/step - loss: 39.1656 - crf_viterbi_accuracy: 0.9760 - val_loss: 38.7530 - val_crf_viterbi_accuracy: 0.9708
# Epoch 19/20
# 9361/9361 [==============================] - 276s 29ms/step - loss: 39.1634 - crf_viterbi_accuracy: 0.9768 - val_loss: 38.7574 - val_crf_viterbi_accuracy: 0.9686
# Epoch 20/20
# 9361/9361 [==============================] - 274s 29ms/step - loss: 39.1614 - crf_viterbi_accuracy: 0.9774 - val_loss: 38.7609 - val_crf_viterbi_accuracy: 0.9661
# FOLD Number: 13/15
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 281s 30ms/step - loss: 39.3498 - crf_viterbi_accuracy: 0.8793 - val_loss: 39.3671 - val_crf_viterbi_accuracy: 0.9234
# Epoch 2/20
# 9360/9360 [==============================] - 277s 30ms/step - loss: 39.1297 - crf_viterbi_accuracy: 0.9221 - val_loss: 39.3138 - val_crf_viterbi_accuracy: 0.9399
# Epoch 3/20
# 9360/9360 [==============================] - 275s 29ms/step - loss: 39.0833 - crf_viterbi_accuracy: 0.9353 - val_loss: 39.2877 - val_crf_viterbi_accuracy: 0.9451
# Epoch 4/20
# 9360/9360 [==============================] - 274s 29ms/step - loss: 39.0561 - crf_viterbi_accuracy: 0.9424 - val_loss: 39.2650 - val_crf_viterbi_accuracy: 0.9520
# Epoch 5/20
# 9360/9360 [==============================] - 280s 30ms/step - loss: 39.0401 - crf_viterbi_accuracy: 0.9465 - val_loss: 39.2531 - val_crf_viterbi_accuracy: 0.9539
# Epoch 6/20
# 9360/9360 [==============================] - 280s 30ms/step - loss: 39.0274 - crf_viterbi_accuracy: 0.9491 - val_loss: 39.2435 - val_crf_viterbi_accuracy: 0.9575
# Epoch 7/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 39.0165 - crf_viterbi_accuracy: 0.9535 - val_loss: 39.2379 - val_crf_viterbi_accuracy: 0.9579
# Epoch 8/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 39.0079 - crf_viterbi_accuracy: 0.9549 - val_loss: 39.2304 - val_crf_viterbi_accuracy: 0.9597
# Epoch 9/20
# 9360/9360 [==============================] - 281s 30ms/step - loss: 38.9995 - crf_viterbi_accuracy: 0.9566 - val_loss: 39.2278 - val_crf_viterbi_accuracy: 0.9602
# Epoch 10/20
# 9360/9360 [==============================] - 282s 30ms/step - loss: 38.9945 - crf_viterbi_accuracy: 0.9579 - val_loss: 39.2233 - val_crf_viterbi_accuracy: 0.9607
# Epoch 11/20
# 9360/9360 [==============================] - 278s 30ms/step - loss: 38.9900 - crf_viterbi_accuracy: 0.9592 - val_loss: 39.2212 - val_crf_viterbi_accuracy: 0.9623
# Epoch 12/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 38.9865 - crf_viterbi_accuracy: 0.9594 - val_loss: 39.2225 - val_crf_viterbi_accuracy: 0.9617
# Epoch 13/20
# 9360/9360 [==============================] - 280s 30ms/step - loss: 38.9827 - crf_viterbi_accuracy: 0.9614 - val_loss: 39.2194 - val_crf_viterbi_accuracy: 0.9622
# Epoch 14/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 38.9779 - crf_viterbi_accuracy: 0.9613 - val_loss: 39.2193 - val_crf_viterbi_accuracy: 0.9595
# Epoch 15/20
# 9360/9360 [==============================] - 277s 30ms/step - loss: 38.9741 - crf_viterbi_accuracy: 0.9642 - val_loss: 39.2131 - val_crf_viterbi_accuracy: 0.9636
# Epoch 16/20
# 9360/9360 [==============================] - 280s 30ms/step - loss: 38.9715 - crf_viterbi_accuracy: 0.9642 - val_loss: 39.2133 - val_crf_viterbi_accuracy: 0.9632
# Epoch 17/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 38.9700 - crf_viterbi_accuracy: 0.9650 - val_loss: 39.2078 - val_crf_viterbi_accuracy: 0.9672
# Epoch 18/20
# 9360/9360 [==============================] - 282s 30ms/step - loss: 38.9663 - crf_viterbi_accuracy: 0.9658 - val_loss: 39.2075 - val_crf_viterbi_accuracy: 0.9676
# Epoch 19/20
# 9360/9360 [==============================] - 279s 30ms/step - loss: 38.9644 - crf_viterbi_accuracy: 0.9656 - val_loss: 39.2068 - val_crf_viterbi_accuracy: 0.9674
# Epoch 20/20
# 9360/9360 [==============================] - 276s 29ms/step - loss: 38.9620 - crf_viterbi_accuracy: 0.9672 - val_loss: 39.2099 - val_crf_viterbi_accuracy: 0.9625
# FOLD Number: 14/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.3945 - crf_viterbi_accuracy: 0.8682 - val_loss: 39.3782 - val_crf_viterbi_accuracy: 0.9275
# Epoch 2/20
# 9361/9361 [==============================] - 269s 29ms/step - loss: 39.1466 - crf_viterbi_accuracy: 0.9202 - val_loss: 39.3193 - val_crf_viterbi_accuracy: 0.9417
# Epoch 3/20
# 9361/9361 [==============================] - 269s 29ms/step - loss: 39.0942 - crf_viterbi_accuracy: 0.9339 - val_loss: 39.2928 - val_crf_viterbi_accuracy: 0.9493
# Epoch 4/20
# 9361/9361 [==============================] - 267s 29ms/step - loss: 39.0668 - crf_viterbi_accuracy: 0.9410 - val_loss: 39.2740 - val_crf_viterbi_accuracy: 0.9529
# Epoch 5/20
# 9361/9361 [==============================] - 256s 27ms/step - loss: 39.0454 - crf_viterbi_accuracy: 0.9456 - val_loss: 39.2647 - val_crf_viterbi_accuracy: 0.9546
# Epoch 6/20
# 9361/9361 [==============================] - 255s 27ms/step - loss: 39.0309 - crf_viterbi_accuracy: 0.9495 - val_loss: 39.2531 - val_crf_viterbi_accuracy: 0.9573
# Epoch 7/20
# 9361/9361 [==============================] - 261s 28ms/step - loss: 39.0207 - crf_viterbi_accuracy: 0.9510 - val_loss: 39.2435 - val_crf_viterbi_accuracy: 0.9600
# Epoch 8/20
# 9361/9361 [==============================] - 262s 28ms/step - loss: 39.0107 - crf_viterbi_accuracy: 0.9542 - val_loss: 39.2386 - val_crf_viterbi_accuracy: 0.9619
# Epoch 9/20
# 9361/9361 [==============================] - 259s 28ms/step - loss: 39.0050 - crf_viterbi_accuracy: 0.9552 - val_loss: 39.2330 - val_crf_viterbi_accuracy: 0.9624
# Epoch 10/20
# 9361/9361 [==============================] - 257s 27ms/step - loss: 38.9980 - crf_viterbi_accuracy: 0.9568 - val_loss: 39.2326 - val_crf_viterbi_accuracy: 0.9612
# Epoch 11/20
# 9361/9361 [==============================] - 260s 28ms/step - loss: 38.9907 - crf_viterbi_accuracy: 0.9587 - val_loss: 39.2266 - val_crf_viterbi_accuracy: 0.9641
# Epoch 12/20
# 9361/9361 [==============================] - 255s 27ms/step - loss: 38.9891 - crf_viterbi_accuracy: 0.9601 - val_loss: 39.2235 - val_crf_viterbi_accuracy: 0.9649
# Epoch 13/20
# 9361/9361 [==============================] - 258s 28ms/step - loss: 38.9842 - crf_viterbi_accuracy: 0.9606 - val_loss: 39.2185 - val_crf_viterbi_accuracy: 0.9651
# Epoch 14/20
# 9361/9361 [==============================] - 263s 28ms/step - loss: 38.9809 - crf_viterbi_accuracy: 0.9610 - val_loss: 39.2155 - val_crf_viterbi_accuracy: 0.9665
# Epoch 15/20
# 9361/9361 [==============================] - 261s 28ms/step - loss: 38.9762 - crf_viterbi_accuracy: 0.9627 - val_loss: 39.2176 - val_crf_viterbi_accuracy: 0.9658
# Epoch 16/20
# 9361/9361 [==============================] - 258s 28ms/step - loss: 38.9737 - crf_viterbi_accuracy: 0.9634 - val_loss: 39.2149 - val_crf_viterbi_accuracy: 0.9671
# Epoch 17/20
# 9361/9361 [==============================] - 255s 27ms/step - loss: 38.9708 - crf_viterbi_accuracy: 0.9635 - val_loss: 39.2143 - val_crf_viterbi_accuracy: 0.9659
# Epoch 18/20
# 9361/9361 [==============================] - 253s 27ms/step - loss: 38.9677 - crf_viterbi_accuracy: 0.9642 - val_loss: 39.2148 - val_crf_viterbi_accuracy: 0.9652
# Epoch 19/20
# 9361/9361 [==============================] - 253s 27ms/step - loss: 38.9663 - crf_viterbi_accuracy: 0.9649 - val_loss: 39.2110 - val_crf_viterbi_accuracy: 0.9678
# Epoch 20/20
# 9361/9361 [==============================] - 253s 27ms/step - loss: 38.9636 - crf_viterbi_accuracy: 0.9653 - val_loss: 39.2129 - val_crf_viterbi_accuracy: 0.9681
# FOLD Number: 15/15
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 270s 29ms/step - loss: 39.5863 - crf_viterbi_accuracy: 0.8758 - val_loss: 38.9353 - val_crf_viterbi_accuracy: 0.9177
# Epoch 2/20
# 9361/9361 [==============================] - 254s 27ms/step - loss: 39.3621 - crf_viterbi_accuracy: 0.9218 - val_loss: 38.8645 - val_crf_viterbi_accuracy: 0.9411
# Epoch 3/20
# 9361/9361 [==============================] - 252s 27ms/step - loss: 39.3154 - crf_viterbi_accuracy: 0.9345 - val_loss: 38.8376 - val_crf_viterbi_accuracy: 0.9470
# Epoch 4/20
# 9361/9361 [==============================] - 251s 27ms/step - loss: 39.2870 - crf_viterbi_accuracy: 0.9416 - val_loss: 38.8166 - val_crf_viterbi_accuracy: 0.9517
# Epoch 5/20
# 9361/9361 [==============================] - 253s 27ms/step - loss: 39.2681 - crf_viterbi_accuracy: 0.9464 - val_loss: 38.8072 - val_crf_viterbi_accuracy: 0.9531
# Epoch 6/20
# 9361/9361 [==============================] - 259s 28ms/step - loss: 39.2556 - crf_viterbi_accuracy: 0.9498 - val_loss: 38.7968 - val_crf_viterbi_accuracy: 0.9576
# Epoch 7/20
# 9361/9361 [==============================] - 275s 29ms/step - loss: 39.2443 - crf_viterbi_accuracy: 0.9526 - val_loss: 38.7881 - val_crf_viterbi_accuracy: 0.9578
# Epoch 8/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 39.2360 - crf_viterbi_accuracy: 0.9531 - val_loss: 38.7858 - val_crf_viterbi_accuracy: 0.9593
# Epoch 9/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.2317 - crf_viterbi_accuracy: 0.9551 - val_loss: 38.7818 - val_crf_viterbi_accuracy: 0.9597
# Epoch 10/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.2234 - crf_viterbi_accuracy: 0.9575 - val_loss: 38.7725 - val_crf_viterbi_accuracy: 0.9636
# Epoch 11/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 39.2182 - crf_viterbi_accuracy: 0.9583 - val_loss: 38.7697 - val_crf_viterbi_accuracy: 0.9634
# Epoch 12/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.2137 - crf_viterbi_accuracy: 0.9591 - val_loss: 38.7690 - val_crf_viterbi_accuracy: 0.9650
# Epoch 13/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.2095 - crf_viterbi_accuracy: 0.9608 - val_loss: 38.7642 - val_crf_viterbi_accuracy: 0.9659
# Epoch 14/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 39.2066 - crf_viterbi_accuracy: 0.9608 - val_loss: 38.7641 - val_crf_viterbi_accuracy: 0.9648
# Epoch 15/20
# 9361/9361 [==============================] - 282s 30ms/step - loss: 39.2030 - crf_viterbi_accuracy: 0.9633 - val_loss: 38.7613 - val_crf_viterbi_accuracy: 0.9662
# Epoch 16/20
# 9361/9361 [==============================] - 280s 30ms/step - loss: 39.1986 - crf_viterbi_accuracy: 0.9639 - val_loss: 38.7603 - val_crf_viterbi_accuracy: 0.9664
# Epoch 17/20
# 9361/9361 [==============================] - 277s 30ms/step - loss: 39.1988 - crf_viterbi_accuracy: 0.9632 - val_loss: 38.7608 - val_crf_viterbi_accuracy: 0.9663
# Epoch 18/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.1949 - crf_viterbi_accuracy: 0.9643 - val_loss: 38.7598 - val_crf_viterbi_accuracy: 0.9666
# Epoch 19/20
# 9361/9361 [==============================] - 284s 30ms/step - loss: 39.1917 - crf_viterbi_accuracy: 0.9657 - val_loss: 38.7576 - val_crf_viterbi_accuracy: 0.9676
# Epoch 20/20
# 9361/9361 [==============================] - 279s 30ms/step - loss: 39.1921 - crf_viterbi_accuracy: 0.9655 - val_loss: 38.7587 - val_crf_viterbi_accuracy: 0.9665
# CPU times: user 22h 9min 53s, sys: 1h 54min 16s, total: 1d 4min 9s
# Wall time: 15h 31min 14s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("Dropout").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#          train_loss  train_acc   val_loss   val_acc     epochs
# Dropout
# 0.10      39.002488   0.982797  39.066033  0.969201  12.666667
# 0.05      39.004093   0.982572  39.068751  0.967847  10.666667
# 0.50      39.039220   0.965964  39.060526  0.965696  20.000000
# 0.00      38.996188   0.987107  39.075542  0.965624  10.000000
# 0.25      39.017048   0.975705  39.064999  0.965206  15.333333

# %%
from google.colab import files
df_results.to_csv('Dropout_grid_Glove.csv')
files.download('Dropout_grid_Glove.csv')
