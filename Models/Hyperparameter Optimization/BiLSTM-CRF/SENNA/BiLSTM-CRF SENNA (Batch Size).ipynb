# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/SENNA/BiLSTM-CRF%20SENNA%20(Batch%20Size).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-ivmimyok
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-ivmimyok
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=4ca994029b2aa5cf172ed618a0e53ce36c11faa02b114f93a2af41ffbdb8776f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cjgpyayn/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Requirement already satisfied: sklearn_crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#root_path = "/content/drive/My Drive/glove.6B.50d.txt"
root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 130000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
BATCHES= [256,128,64,32]
EPOCHS=20
fold_count = 1

for BATCH_SIZE in BATCHES:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(BATCHES)*3))
    
    #split data
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(opt='adam'):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=100, return_sequences=True,
                                recurrent_dropout=0.1, dropout=0.1))(model_2)
      model_2 = TimeDistributed(Dense(20, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer=opt, loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

  #---------Fit Model-----------------
    model = create_model()
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "batch size": BATCH_SIZE,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 28s 3ms/step - loss: 39.9396 - crf_viterbi_accuracy: 0.7627 - val_loss: 39.6795 - val_crf_viterbi_accuracy: 0.8675
# 9360/9360 [==============================] - 25s 3ms/step - loss: 38.9646 - crf_viterbi_accuracy: 0.9722 - val_loss: 39.2255 - val_crf_viterbi_accuracy: 0.9631
# Epoch 19/20
# 9360/9360 [==============================] - 25s 3ms/step - loss: 38.9610 - crf_viterbi_accuracy: 0.9727 - val_loss: 39.2254 - val_crf_viterbi_accuracy: 0.9633
# Epoch 20/20
# 9360/9360 [==============================] - 25s 3ms/step - loss: 38.9580 - crf_viterbi_accuracy: 0.9735 - val_loss: 39.2241 - val_crf_viterbi_accuracy: 0.9644
# FOLD Number: 2/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 28s 3ms/step - loss: 39.9713 - crf_viterbi_accuracy: 0.7381 - val_loss: 39.7078 - val_crf_viterbi_accuracy: 0.8581
# Epoch 2/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.3524 - crf_viterbi_accuracy: 0.8876 - val_loss: 39.4712 - val_crf_viterbi_accuracy: 0.9126
# Epoch 3/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.1766 - crf_viterbi_accuracy: 0.9259 - val_loss: 39.3799 - val_crf_viterbi_accuracy: 0.9288
# Epoch 4/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.1174 - crf_viterbi_accuracy: 0.9358 - val_loss: 39.3419 - val_crf_viterbi_accuracy: 0.9383
# Epoch 5/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0890 - crf_viterbi_accuracy: 0.9409 - val_loss: 39.3211 - val_crf_viterbi_accuracy: 0.9424
# Epoch 6/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0683 - crf_viterbi_accuracy: 0.9452 - val_loss: 39.3048 - val_crf_viterbi_accuracy: 0.9452
# Epoch 7/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.0520 - crf_viterbi_accuracy: 0.9484 - val_loss: 39.2925 - val_crf_viterbi_accuracy: 0.9483
# Epoch 8/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0398 - crf_viterbi_accuracy: 0.9507 - val_loss: 39.2826 - val_crf_viterbi_accuracy: 0.9506
# Epoch 9/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0281 - crf_viterbi_accuracy: 0.9535 - val_loss: 39.2734 - val_crf_viterbi_accuracy: 0.9535
# Epoch 10/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0175 - crf_viterbi_accuracy: 0.9559 - val_loss: 39.2673 - val_crf_viterbi_accuracy: 0.9550
# Epoch 11/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.0091 - crf_viterbi_accuracy: 0.9582 - val_loss: 39.2622 - val_crf_viterbi_accuracy: 0.9569
# Epoch 12/20
# 9361/9361 [==============================] - 26s 3ms/step - loss: 39.0032 - crf_viterbi_accuracy: 0.9597 - val_loss: 39.2561 - val_crf_viterbi_accuracy: 0.9587
# Epoch 13/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9961 - crf_viterbi_accuracy: 0.9617 - val_loss: 39.2516 - val_crf_viterbi_accuracy: 0.9594
# Epoch 14/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9900 - crf_viterbi_accuracy: 0.9632 - val_loss: 39.2476 - val_crf_viterbi_accuracy: 0.9604
# Epoch 15/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9845 - crf_viterbi_accuracy: 0.9654 - val_loss: 39.2437 - val_crf_viterbi_accuracy: 0.9619
# Epoch 16/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9798 - crf_viterbi_accuracy: 0.9665 - val_loss: 39.2423 - val_crf_viterbi_accuracy: 0.9611
# Epoch 17/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9745 - crf_viterbi_accuracy: 0.9675 - val_loss: 39.2381 - val_crf_viterbi_accuracy: 0.9633
# Epoch 18/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9705 - crf_viterbi_accuracy: 0.9688 - val_loss: 39.2362 - val_crf_viterbi_accuracy: 0.9627
# Epoch 19/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9664 - crf_viterbi_accuracy: 0.9697 - val_loss: 39.2341 - val_crf_viterbi_accuracy: 0.9639
# Epoch 20/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 38.9635 - crf_viterbi_accuracy: 0.9709 - val_loss: 39.2318 - val_crf_viterbi_accuracy: 0.9656
# FOLD Number: 3/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 28s 3ms/step - loss: 40.2501 - crf_viterbi_accuracy: 0.7287 - val_loss: 39.2875 - val_crf_viterbi_accuracy: 0.8444
# Epoch 2/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.5701 - crf_viterbi_accuracy: 0.8898 - val_loss: 39.0101 - val_crf_viterbi_accuracy: 0.9082
# Epoch 3/20
# 9361/9361 [==============================] - 24s 3ms/step - loss: 39.3976 - crf_viterbi_accuracy: 0.9276 - val_loss: 38.9303 - val_crf_viterbi_accuracy: 0.9276
# Epoch 4/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.3430 - crf_viterbi_accuracy: 0.9387 - val_loss: 38.8938 - val_crf_viterbi_accuracy: 0.9344
# Epoch 5/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.3147 - crf_viterbi_accuracy: 0.9438 - val_loss: 38.8704 - val_crf_viterbi_accuracy: 0.9382
# Epoch 6/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2950 - crf_viterbi_accuracy: 0.9463 - val_loss: 38.8523 - val_crf_viterbi_accuracy: 0.9424
# Epoch 7/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2769 - crf_viterbi_accuracy: 0.9501 - val_loss: 38.8400 - val_crf_viterbi_accuracy: 0.9452
# Epoch 8/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2661 - crf_viterbi_accuracy: 0.9526 - val_loss: 38.8277 - val_crf_viterbi_accuracy: 0.9480
# Epoch 9/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2538 - crf_viterbi_accuracy: 0.9552 - val_loss: 38.8215 - val_crf_viterbi_accuracy: 0.9486
# Epoch 10/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2449 - crf_viterbi_accuracy: 0.9572 - val_loss: 38.8157 - val_crf_viterbi_accuracy: 0.9506
# Epoch 11/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2365 - crf_viterbi_accuracy: 0.9594 - val_loss: 38.8076 - val_crf_viterbi_accuracy: 0.9527
# Epoch 12/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2297 - crf_viterbi_accuracy: 0.9616 - val_loss: 38.8012 - val_crf_viterbi_accuracy: 0.9560
# Epoch 13/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2222 - crf_viterbi_accuracy: 0.9635 - val_loss: 38.7979 - val_crf_viterbi_accuracy: 0.9565
# Epoch 14/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2162 - crf_viterbi_accuracy: 0.9650 - val_loss: 38.7951 - val_crf_viterbi_accuracy: 0.9574
# Epoch 15/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2122 - crf_viterbi_accuracy: 0.9662 - val_loss: 38.7883 - val_crf_viterbi_accuracy: 0.9596
# Epoch 16/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2060 - crf_viterbi_accuracy: 0.9675 - val_loss: 38.7869 - val_crf_viterbi_accuracy: 0.9597
# Epoch 17/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.2015 - crf_viterbi_accuracy: 0.9679 - val_loss: 38.7837 - val_crf_viterbi_accuracy: 0.9609
# Epoch 18/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.1976 - crf_viterbi_accuracy: 0.9698 - val_loss: 38.7803 - val_crf_viterbi_accuracy: 0.9621
# Epoch 19/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.1942 - crf_viterbi_accuracy: 0.9709 - val_loss: 38.7792 - val_crf_viterbi_accuracy: 0.9625
# Epoch 20/20
# 9361/9361 [==============================] - 25s 3ms/step - loss: 39.1902 - crf_viterbi_accuracy: 0.9723 - val_loss: 38.7777 - val_crf_viterbi_accuracy: 0.9625
# FOLD Number: 4/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 55s 6ms/step - loss: 39.8447 - crf_viterbi_accuracy: 0.7663 - val_loss: 39.4945 - val_crf_viterbi_accuracy: 0.9091
# Epoch 2/20
# 9360/9360 [==============================] - 50s 5ms/step - loss: 39.1658 - crf_viterbi_accuracy: 0.9304 - val_loss: 39.3780 - val_crf_viterbi_accuracy: 0.9310
# Epoch 3/20
# 9360/9360 [==============================] - 50s 5ms/step - loss: 39.0962 - crf_viterbi_accuracy: 0.9429 - val_loss: 39.3324 - val_crf_viterbi_accuracy: 0.9398
# Epoch 4/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0659 - crf_viterbi_accuracy: 0.9479 - val_loss: 39.3045 - val_crf_viterbi_accuracy: 0.9442
# Epoch 5/20
# 9360/9360 [==============================] - 49s 5ms/step - loss: 39.0433 - crf_viterbi_accuracy: 0.9522 - val_loss: 39.2863 - val_crf_viterbi_accuracy: 0.9499
# Epoch 18/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 38.9424 - crf_viterbi_accuracy: 0.9781 - val_loss: 39.2211 - val_crf_viterbi_accuracy: 0.9693
# Epoch 19/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 38.9385 - crf_viterbi_accuracy: 0.9789 - val_loss: 39.2195 - val_crf_viterbi_accuracy: 0.9702
# Epoch 20/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 38.9364 - crf_viterbi_accuracy: 0.9799 - val_loss: 39.2220 - val_crf_viterbi_accuracy: 0.9680
# FOLD Number: 6/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 55s 6ms/step - loss: 39.8349 - crf_viterbi_accuracy: 0.8279 - val_loss: 38.9863 - val_crf_viterbi_accuracy: 0.9155
# Epoch 2/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.3690 - crf_viterbi_accuracy: 0.9335 - val_loss: 38.8999 - val_crf_viterbi_accuracy: 0.9343
# Epoch 3/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.3118 - crf_viterbi_accuracy: 0.9440 - val_loss: 38.8597 - val_crf_viterbi_accuracy: 0.9425
# Epoch 4/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.2818 - crf_viterbi_accuracy: 0.9496 - val_loss: 38.8374 - val_crf_viterbi_accuracy: 0.9475
# Epoch 5/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.2617 - crf_viterbi_accuracy: 0.9532 - val_loss: 38.8223 - val_crf_viterbi_accuracy: 0.9515
# Epoch 6/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2458 - crf_viterbi_accuracy: 0.9573 - val_loss: 38.8124 - val_crf_viterbi_accuracy: 0.9533
# Epoch 7/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2326 - crf_viterbi_accuracy: 0.9604 - val_loss: 38.8084 - val_crf_viterbi_accuracy: 0.9547
# Epoch 8/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2236 - crf_viterbi_accuracy: 0.9622 - val_loss: 38.7935 - val_crf_viterbi_accuracy: 0.9600
# Epoch 9/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.2134 - crf_viterbi_accuracy: 0.9657 - val_loss: 38.7911 - val_crf_viterbi_accuracy: 0.9599
# Epoch 10/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.2077 - crf_viterbi_accuracy: 0.9667 - val_loss: 38.7832 - val_crf_viterbi_accuracy: 0.9628
# Epoch 11/20
# 9361/9361 [==============================] - 49s 5ms/step - loss: 39.2004 - crf_viterbi_accuracy: 0.9690 - val_loss: 38.7815 - val_crf_viterbi_accuracy: 0.9630
# Epoch 12/20
# 9361/9361 [==============================] - 50s 5ms/step - loss: 39.1939 - crf_viterbi_accuracy: 0.9709 - val_loss: 38.7783 - val_crf_viterbi_accuracy: 0.9628
# Epoch 13/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 38.9670 - crf_viterbi_accuracy: 0.9701 - val_loss: 39.2333 - val_crf_viterbi_accuracy: 0.9638
# Epoch 9/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 38.9584 - crf_viterbi_accuracy: 0.9721 - val_loss: 39.2266 - val_crf_viterbi_accuracy: 0.9664
# Epoch 10/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 38.9522 - crf_viterbi_accuracy: 0.9743 - val_loss: 39.2261 - val_crf_viterbi_accuracy: 0.9655
# Epoch 11/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 38.9460 - crf_viterbi_accuracy: 0.9761 - val_loss: 39.2208 - val_crf_viterbi_accuracy: 0.9685
# Epoch 12/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 38.9410 - crf_viterbi_accuracy: 0.9772 - val_loss: 39.2191 - val_crf_viterbi_accuracy: 0.9692
# Epoch 13/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 38.9373 - crf_viterbi_accuracy: 0.9785 - val_loss: 39.2180 - val_crf_viterbi_accuracy: 0.9686
# Epoch 14/20
# 9361/9361 [==============================] - 98s 11ms/step - loss: 38.9327 - crf_viterbi_accuracy: 0.9806 - val_loss: 39.2174 - val_crf_viterbi_accuracy: 0.9707
# Epoch 15/20
# 9361/9361 [==============================] - 98s 10ms/step - loss: 38.9305 - crf_viterbi_accuracy: 0.9812 - val_loss: 39.2181 - val_crf_viterbi_accuracy: 0.9705
# Epoch 16/20
# 9361/9361 [==============================] - 100s 11ms/step - loss: 38.9269 - crf_viterbi_accuracy: 0.9823 - val_loss: 39.2188 - val_crf_viterbi_accuracy: 0.9689
# FOLD Number: 9/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 109s 12ms/step - loss: 39.6077 - crf_viterbi_accuracy: 0.8681 - val_loss: 38.9028 - val_crf_viterbi_accuracy: 0.9317
# Epoch 2/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 39.3039 - crf_viterbi_accuracy: 0.9440 - val_loss: 38.8464 - val_crf_viterbi_accuracy: 0.9434
# Epoch 3/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 39.2644 - crf_viterbi_accuracy: 0.9520 - val_loss: 38.8205 - val_crf_viterbi_accuracy: 0.9492
# Epoch 4/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2401 - crf_viterbi_accuracy: 0.9578 - val_loss: 38.8014 - val_crf_viterbi_accuracy: 0.9550
# Epoch 5/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2233 - crf_viterbi_accuracy: 0.9623 - val_loss: 38.7948 - val_crf_viterbi_accuracy: 0.9559
# Epoch 6/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 39.2104 - crf_viterbi_accuracy: 0.9658 - val_loss: 38.7810 - val_crf_viterbi_accuracy: 0.9628
# Epoch 7/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 39.1988 - crf_viterbi_accuracy: 0.9691 - val_loss: 38.7754 - val_crf_viterbi_accuracy: 0.9645
# Epoch 9/20
# 9360/9360 [==============================] - 196s 21ms/step - loss: 38.9366 - crf_viterbi_accuracy: 0.9795 - val_loss: 39.2109 - val_crf_viterbi_accuracy: 0.9677
# Epoch 10/20
# 9360/9360 [==============================] - 199s 21ms/step - loss: 38.9319 - crf_viterbi_accuracy: 0.9813 - val_loss: 39.2133 - val_crf_viterbi_accuracy: 0.9677
# Epoch 11/20
# 9360/9360 [==============================] - 196s 21ms/step - loss: 38.9277 - crf_viterbi_accuracy: 0.9824 - val_loss: 39.2109 - val_crf_viterbi_accuracy: 0.9687
# Epoch 12/20
# 9360/9360 [==============================] - 194s 21ms/step - loss: 38.9239 - crf_viterbi_accuracy: 0.9845 - val_loss: 39.2070 - val_crf_viterbi_accuracy: 0.9703
# Epoch 13/20
# 9360/9360 [==============================] - 201s 21ms/step - loss: 38.9212 - crf_viterbi_accuracy: 0.9851 - val_loss: 39.2109 - val_crf_viterbi_accuracy: 0.9694
# Epoch 14/20
# 9360/9360 [==============================] - 197s 21ms/step - loss: 38.9183 - crf_viterbi_accuracy: 0.9863 - val_loss: 39.2158 - val_crf_viterbi_accuracy: 0.9712
# FOLD Number: 11/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 200s 21ms/step - loss: 39.2768 - crf_viterbi_accuracy: 0.8981 - val_loss: 39.3162 - val_crf_viterbi_accuracy: 0.9421
# Epoch 2/20
# 9361/9361 [==============================] - 193s 21ms/step - loss: 39.0451 - crf_viterbi_accuracy: 0.9490 - val_loss: 39.2792 - val_crf_viterbi_accuracy: 0.9504
# Epoch 3/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 39.0114 - crf_viterbi_accuracy: 0.9572 - val_loss: 39.2550 - val_crf_viterbi_accuracy: 0.9592
# Epoch 4/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 38.9889 - crf_viterbi_accuracy: 0.9624 - val_loss: 39.2379 - val_crf_viterbi_accuracy: 0.9636
# Epoch 5/20
# 9361/9361 [==============================] - 193s 21ms/step - loss: 38.9724 - crf_viterbi_accuracy: 0.9671 - val_loss: 39.2287 - val_crf_viterbi_accuracy: 0.9662
# Epoch 6/20
# 9361/9361 [==============================] - 194s 21ms/step - loss: 38.9627 - crf_viterbi_accuracy: 0.9703 - val_loss: 39.2247 - val_crf_viterbi_accuracy: 0.9665
# Epoch 7/20
# 9361/9361 [==============================] - 195s 21ms/step - loss: 38.9537 - crf_viterbi_accuracy: 0.9725 - val_loss: 39.2228 - val_crf_viterbi_accuracy: 0.9646
# Epoch 8/20
# 9361/9361 [==============================] - 192s 21ms/step - loss: 38.9455 - crf_viterbi_accuracy: 0.9756 - val_loss: 39.2163 - val_crf_viterbi_accuracy: 0.9697
# Epoch 9/20
# 9361/9361 [==============================] - 198s 21ms/step - loss: 38.9398 - crf_viterbi_accuracy: 0.9772 - val_loss: 39.2228 - val_crf_viterbi_accuracy: 0.9639
# Epoch 10/20
# 9361/9361 [==============================] - 195s 21ms/step - loss: 38.9341 - crf_viterbi_accuracy: 0.9786 - val_loss: 39.2185 - val_crf_viterbi_accuracy: 0.9659
# FOLD Number: 12/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 209s 22ms/step - loss: 39.4843 - crf_viterbi_accuracy: 0.9141 - val_loss: 38.8585 - val_crf_viterbi_accuracy: 0.9446
# Epoch 2/20
# 9361/9361 [==============================] - 195s 21ms/step - loss: 39.2725 - crf_viterbi_accuracy: 0.9509 - val_loss: 38.8131 - val_crf_viterbi_accuracy: 0.9537
# Epoch 3/20
# 9361/9361 [==============================] - 195s 21ms/step - loss: 39.2379 - crf_viterbi_accuracy: 0.9587 - val_loss: 38.7935 - val_crf_viterbi_accuracy: 0.9582
# Epoch 4/20
# 9361/9361 [==============================] - 192s 21ms/step - loss: 39.2149 - crf_viterbi_accuracy: 0.9639 - val_loss: 38.7849 - val_crf_viterbi_accuracy: 0.9602
# Epoch 5/20
# 9361/9361 [==============================] - 193s 21ms/step - loss: 39.2011 - crf_viterbi_accuracy: 0.9678 - val_loss: 38.7717 - val_crf_viterbi_accuracy: 0.9647
# Epoch 6/20
# 9361/9361 [==============================] - 193s 21ms/step - loss: 39.1887 - crf_viterbi_accuracy: 0.9715 - val_loss: 38.7714 - val_crf_viterbi_accuracy: 0.9641
# Epoch 7/20
# 9361/9361 [==============================] - 192s 20ms/step - loss: 39.1812 - crf_viterbi_accuracy: 0.9732 - val_loss: 38.7637 - val_crf_viterbi_accuracy: 0.9670
# Epoch 8/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.1723 - crf_viterbi_accuracy: 0.9763 - val_loss: 38.7589 - val_crf_viterbi_accuracy: 0.9685
# Epoch 9/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.1665 - crf_viterbi_accuracy: 0.9779 - val_loss: 38.7600 - val_crf_viterbi_accuracy: 0.9682
# Epoch 10/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.1624 - crf_viterbi_accuracy: 0.9788 - val_loss: 38.7582 - val_crf_viterbi_accuracy: 0.9683
# Epoch 11/20
# 9361/9361 [==============================] - 190s 20ms/step - loss: 39.1573 - crf_viterbi_accuracy: 0.9811 - val_loss: 38.7587 - val_crf_viterbi_accuracy: 0.9674
# Epoch 12/20
# 9361/9361 [==============================] - 191s 20ms/step - loss: 39.1538 - crf_viterbi_accuracy: 0.9821 - val_loss: 38.7630 - val_crf_viterbi_accuracy: 0.9668
# CPU times: user 6h 43min 28s, sys: 27min 3s, total: 7h 10min 31s
# Wall time: 4h 33min 14s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("batch size").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#             train_loss  train_acc   val_loss   val_acc  epochs
# batch size
# 64           39.002579   0.982585  39.064226  0.968281      16
# 32           39.002073   0.982354  39.065738  0.967940      12
# 128          39.014099   0.979257  39.069446  0.967118      20
# 256          39.037238   0.972245  39.077888  0.964137      20

# %%
from google.colab import files
df_results.to_csv('batch size_grid_senna.csv')
files.download('batch size_grid_senna.csv')
