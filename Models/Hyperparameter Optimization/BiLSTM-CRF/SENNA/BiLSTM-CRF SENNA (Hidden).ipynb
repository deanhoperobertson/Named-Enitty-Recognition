# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/SENNA/BiLSTM-CRF%20SENNA%20(Hidden).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-vriiolqp
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-vriiolqp
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=4d5ce0eb5864cc7df4e113f8240657101af175565ae107d641955751aea19f84
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tdz4qy_s/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Requirement already satisfied: sklearn_crfsuite in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# TensorFlow 1.x selected.

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2
# Using TensorFlow backend.

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#root_path = "/content/drive/My Drive/glove.6B.50d.txt"
root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 130000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
HIDDEN =[10,20,50,100]
DROPOUT =0.25
CELLS =100
BATCH_SIZE= 64
EPOCHS=20
fold_count = 1


for HID in HIDDEN:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(HIDDEN)*3))
    
    #split data
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(HID):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=CELLS, return_sequences=True,
                                recurrent_dropout=DROPOUT, dropout=DROPOUT))(model_2)
      model_2 = TimeDistributed(Dense(HID, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer="adam", loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

  #---------Fit Model-----------------
    model = create_model(HID)
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "Hidden": HID ,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/12
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9496 - crf_viterbi_accuracy: 0.9736 - val_loss: 39.2114 - val_crf_viterbi_accuracy: 0.9667
# Epoch 17/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 38.9450 - crf_viterbi_accuracy: 0.9754 - val_loss: 39.2085 - val_crf_viterbi_accuracy: 0.9668
# Epoch 18/20
# 9360/9360 [==============================] - 95s 10ms/step - loss: 38.9427 - crf_viterbi_accuracy: 0.9763 - val_loss: 39.2092 - val_crf_viterbi_accuracy: 0.9670
# Epoch 19/20
# 9360/9360 [==============================] - 95s 10ms/step - loss: 38.9412 - crf_viterbi_accuracy: 0.9764 - val_loss: 39.2090 - val_crf_viterbi_accuracy: 0.9662
# FOLD Number: 2/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 98s 11ms/step - loss: 39.5594 - crf_viterbi_accuracy: 0.8345 - val_loss: 39.4065 - val_crf_viterbi_accuracy: 0.9270
# Epoch 2/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.1295 - crf_viterbi_accuracy: 0.9342 - val_loss: 39.3295 - val_crf_viterbi_accuracy: 0.9419
# Epoch 3/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.0745 - crf_viterbi_accuracy: 0.9436 - val_loss: 39.2953 - val_crf_viterbi_accuracy: 0.9489
# Epoch 4/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.0453 - crf_viterbi_accuracy: 0.9494 - val_loss: 39.2757 - val_crf_viterbi_accuracy: 0.9528
# Epoch 5/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.0269 - crf_viterbi_accuracy: 0.9535 - val_loss: 39.2625 - val_crf_viterbi_accuracy: 0.9571
# Epoch 6/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.0129 - crf_viterbi_accuracy: 0.9568 - val_loss: 39.2494 - val_crf_viterbi_accuracy: 0.9598
# Epoch 7/20
# 9361/9361 [==============================] - 98s 10ms/step - loss: 39.0013 - crf_viterbi_accuracy: 0.9591 - val_loss: 39.2422 - val_crf_viterbi_accuracy: 0.9621
# Epoch 8/20
# 9361/9361 [==============================] - 98s 10ms/step - loss: 38.9918 - crf_viterbi_accuracy: 0.9617 - val_loss: 39.2367 - val_crf_viterbi_accuracy: 0.9620
# Epoch 9/20
# 9361/9361 [==============================] - 98s 10ms/step - loss: 38.9821 - crf_viterbi_accuracy: 0.9644 - val_loss: 39.2355 - val_crf_viterbi_accuracy: 0.9625
# Epoch 10/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 38.9771 - crf_viterbi_accuracy: 0.9662 - val_loss: 39.2258 - val_crf_viterbi_accuracy: 0.9656
# Epoch 11/20
# 9361/9361 [==============================] - 98s 11ms/step - loss: 38.9717 - crf_viterbi_accuracy: 0.9676 - val_loss: 39.2229 - val_crf_viterbi_accuracy: 0.9671
# Epoch 12/20
# 9361/9361 [==============================] - 100s 11ms/step - loss: 38.9522 - crf_viterbi_accuracy: 0.9721 - val_loss: 39.2221 - val_crf_viterbi_accuracy: 0.9646
# Epoch 15/20
# 9361/9361 [==============================] - 100s 11ms/step - loss: 38.9502 - crf_viterbi_accuracy: 0.9729 - val_loss: 39.2136 - val_crf_viterbi_accuracy: 0.9687
# Epoch 16/20
# 9361/9361 [==============================] - 102s 11ms/step - loss: 38.9471 - crf_viterbi_accuracy: 0.9741 - val_loss: 39.2172 - val_crf_viterbi_accuracy: 0.9663
# Epoch 17/20
# 9361/9361 [==============================] - 101s 11ms/step - loss: 38.9438 - crf_viterbi_accuracy: 0.9745 - val_loss: 39.2102 - val_crf_viterbi_accuracy: 0.9708
# Epoch 18/20
# 9361/9361 [==============================] - 101s 11ms/step - loss: 38.9417 - crf_viterbi_accuracy: 0.9755 - val_loss: 39.2089 - val_crf_viterbi_accuracy: 0.9708
# Epoch 19/20
# 9361/9361 [==============================] - 102s 11ms/step - loss: 38.9392 - crf_viterbi_accuracy: 0.9762 - val_loss: 39.2103 - val_crf_viterbi_accuracy: 0.9694
# Epoch 20/20
# 9361/9361 [==============================] - 101s 11ms/step - loss: 38.9379 - crf_viterbi_accuracy: 0.9763 - val_loss: 39.2080 - val_crf_viterbi_accuracy: 0.9709
# FOLD Number: 6/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 106s 11ms/step - loss: 39.7997 - crf_viterbi_accuracy: 0.8209 - val_loss: 38.9453 - val_crf_viterbi_accuracy: 0.9234
# Epoch 2/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 39.3470 - crf_viterbi_accuracy: 0.9362 - val_loss: 38.8747 - val_crf_viterbi_accuracy: 0.9368
# Epoch 3/20
# 9361/9361 [==============================] - 99s 11ms/step - loss: 39.2993 - crf_viterbi_accuracy: 0.9447 - val_loss: 38.8382 - val_crf_viterbi_accuracy: 0.9457
# Epoch 4/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2733 - crf_viterbi_accuracy: 0.9488 - val_loss: 38.8210 - val_crf_viterbi_accuracy: 0.9496
# Epoch 5/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.2543 - crf_viterbi_accuracy: 0.9529 - val_loss: 38.8071 - val_crf_viterbi_accuracy: 0.9536
# Epoch 6/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.2389 - crf_viterbi_accuracy: 0.9566 - val_loss: 38.8006 - val_crf_viterbi_accuracy: 0.9531
# Epoch 7/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2285 - crf_viterbi_accuracy: 0.9587 - val_loss: 38.7975 - val_crf_viterbi_accuracy: 0.9539
# Epoch 8/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.2204 - crf_viterbi_accuracy: 0.9609 - val_loss: 38.7822 - val_crf_viterbi_accuracy: 0.9605
# Epoch 9/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.2116 - crf_viterbi_accuracy: 0.9632 - val_loss: 38.7775 - val_crf_viterbi_accuracy: 0.9615
# Epoch 10/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2049 - crf_viterbi_accuracy: 0.9652 - val_loss: 38.7811 - val_crf_viterbi_accuracy: 0.9585
# Epoch 11/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.2000 - crf_viterbi_accuracy: 0.9665 - val_loss: 38.7708 - val_crf_viterbi_accuracy: 0.9629
# Epoch 12/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1946 - crf_viterbi_accuracy: 0.9681 - val_loss: 38.7703 - val_crf_viterbi_accuracy: 0.9624
# Epoch 13/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1906 - crf_viterbi_accuracy: 0.9691 - val_loss: 38.7689 - val_crf_viterbi_accuracy: 0.9625
# Epoch 14/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1869 - crf_viterbi_accuracy: 0.9698 - val_loss: 38.7643 - val_crf_viterbi_accuracy: 0.9653
# Epoch 15/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1852 - crf_viterbi_accuracy: 0.9698 - val_loss: 38.7689 - val_crf_viterbi_accuracy: 0.9609
# Epoch 16/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1807 - crf_viterbi_accuracy: 0.9727 - val_loss: 38.7640 - val_crf_viterbi_accuracy: 0.9641
# Epoch 17/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1786 - crf_viterbi_accuracy: 0.9720 - val_loss: 38.7642 - val_crf_viterbi_accuracy: 0.9638
# Epoch 18/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.1752 - crf_viterbi_accuracy: 0.9738 - val_loss: 38.7667 - val_crf_viterbi_accuracy: 0.9616
# FOLD Number: 7/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 102s 11ms/step - loss: 39.3577 - crf_viterbi_accuracy: 0.8850 - val_loss: 39.3496 - val_crf_viterbi_accuracy: 0.9331
# Epoch 2/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 39.0799 - crf_viterbi_accuracy: 0.9427 - val_loss: 39.3008 - val_crf_viterbi_accuracy: 0.9425
# Epoch 3/20
# 9360/9360 [==============================] - 97s 10ms/step - loss: 39.0458 - crf_viterbi_accuracy: 0.9498 - val_loss: 39.2710 - val_crf_viterbi_accuracy: 0.9503
# Epoch 4/20
# 9360/9360 [==============================] - 95s 10ms/step - loss: 39.0205 - crf_viterbi_accuracy: 0.9551 - val_loss: 39.2532 - val_crf_viterbi_accuracy: 0.9553
# Epoch 5/20
# 9360/9360 [==============================] - 96s 10ms/step - loss: 39.0052 - crf_viterbi_accuracy: 0.9591 - val_loss: 39.2424 - val_crf_viterbi_accuracy: 0.9583
# Epoch 6/20
# 9360/9360 [==============================] - 95s 10ms/step - loss: 38.9934 - crf_viterbi_accuracy: 0.9621 - val_loss: 39.2339 - val_crf_viterbi_accuracy: 0.9601
# Epoch 7/20
20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.0023 - crf_viterbi_accuracy: 0.9600 - val_loss: 39.2475 - val_crf_viterbi_accuracy: 0.9616
# Epoch 7/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9913 - crf_viterbi_accuracy: 0.9624 - val_loss: 39.2389 - val_crf_viterbi_accuracy: 0.9639
# Epoch 8/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9823 - crf_viterbi_accuracy: 0.9648 - val_loss: 39.2313 - val_crf_viterbi_accuracy: 0.9658
# Epoch 9/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9744 - crf_viterbi_accuracy: 0.9671 - val_loss: 39.2280 - val_crf_viterbi_accuracy: 0.9672
# Epoch 10/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9675 - crf_viterbi_accuracy: 0.9689 - val_loss: 39.2282 - val_crf_viterbi_accuracy: 0.9661
# Epoch 11/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9641 - crf_viterbi_accuracy: 0.9701 - val_loss: 39.2266 - val_crf_viterbi_accuracy: 0.9671
# Epoch 12/20
# 9361/9361 [==============================] - 93s 10ms/step - loss: 38.9584 - crf_viterbi_accuracy: 0.9715 - val_loss: 39.2230 - val_crf_viterbi_accuracy: 0.9666
# Epoch 13/20
# 9361/9361 [==============================] - 93s 10ms/step - loss: 38.9548 - crf_viterbi_accuracy: 0.9715 - val_loss: 39.2220 - val_crf_viterbi_accuracy: 0.9663
# Epoch 14/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9515 - crf_viterbi_accuracy: 0.9733 - val_loss: 39.2167 - val_crf_viterbi_accuracy: 0.9677
# Epoch 15/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9470 - crf_viterbi_accuracy: 0.9743 - val_loss: 39.2141 - val_crf_viterbi_accuracy: 0.9695
# Epoch 16/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9439 - crf_viterbi_accuracy: 0.9754 - val_loss: 39.2153 - val_crf_viterbi_accuracy: 0.9696
# Epoch 17/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 38.9423 - crf_viterbi_accuracy: 0.9761 - val_loss: 39.2124 - val_crf_viterbi_accuracy: 0.9708
# Epoch 18/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 38.9396 - crf_viterbi_accuracy: 0.9768 - val_loss: 39.2151 - val_crf_viterbi_accuracy: 0.9684
# Epoch 19/20
# 9361/9361 [==============================] - 93s 10ms/step - loss: 38.9382 - crf_viterbi_accuracy: 0.9773 - val_loss: 39.2121 - val_crf_viterbi_accuracy: 0.9717
# Epoch 20/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 38.9353 - crf_viterbi_accuracy: 0.9775 - val_loss: 39.2119 - val_crf_viterbi_accuracy: 0.9711
# FOLD Number: 9/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 102s 11ms/step - loss: 39.6230 - crf_viterbi_accuracy: 0.8604 - val_loss: 38.8976 - val_crf_viterbi_accuracy: 0.9308
# Epoch 2/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.3110 - crf_viterbi_accuracy: 0.9407 - val_loss: 38.8432 - val_crf_viterbi_accuracy: 0.9428
# Epoch 3/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2733 - crf_viterbi_accuracy: 0.9485 - val_loss: 38.8171 - val_crf_viterbi_accuracy: 0.9488
# Epoch 4/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2496 - crf_viterbi_accuracy: 0.9541 - val_loss: 38.8014 - val_crf_viterbi_accuracy: 0.9533
# Epoch 5/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2339 - crf_viterbi_accuracy: 0.9575 - val_loss: 38.7884 - val_crf_viterbi_accuracy: 0.9580
# Epoch 6/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 39.2214 - crf_viterbi_accuracy: 0.9605 - val_loss: 38.7837 - val_crf_viterbi_accuracy: 0.9601
# Epoch 7/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.2130 - crf_viterbi_accuracy: 0.9641 - val_loss: 38.7748 - val_crf_viterbi_accuracy: 0.9631
# Epoch 8/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2034 - crf_viterbi_accuracy: 0.9665 - val_loss: 38.7724 - val_crf_viterbi_accuracy: 0.9632
# Epoch 9/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1975 - crf_viterbi_accuracy: 0.9679 - val_loss: 38.7664 - val_crf_viterbi_accuracy: 0.9650
# Epoch 10/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1917 - crf_viterbi_accuracy: 0.9696 - val_loss: 38.7672 - val_crf_viterbi_accuracy: 0.9642
# Epoch 11/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1867 - crf_viterbi_accuracy: 0.9705 - val_loss: 38.7646 - val_crf_viterbi_accuracy: 0.9654
# Epoch 12/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1842 - crf_viterbi_accuracy: 0.9715 - val_loss: 38.7605 - val_crf_viterbi_accuracy: 0.9668
# Epoch 13/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1800 - crf_viterbi_accuracy: 0.9724 - val_loss: 38.7593 - val_crf_viterbi_accuracy: 0.9671
# Epoch 14/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1769 - crf_viterbi_accuracy: 0.9732 - val_loss: 38.7572 - val_crf_viterbi_accuracy: 0.9672
# Epoch 15/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1735 - crf_viterbi_accuracy: 0.9746 - val_loss: 38.7581 - val_crf_viterbi_accuracy: 0.9669
# Epoch 16/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1714 - crf_viterbi_accuracy: 0.9754 - val_loss: 38.7577 - val_crf_viterbi_accuracy: 0.9660
# FOLD Number: 10/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 104s 11ms/step - loss: 39.3837 - crf_viterbi_accuracy: 0.8678 - val_loss: 39.3505 - val_crf_viterbi_accuracy: 0.9328
# Epoch 2/20
# 9360/9360 [==============================] - 94s 10ms/step - loss: 39.0840 - crf_viterbi_accuracy: 0.9419 - val_loss: 39.3033 - val_crf_viterbi_accuracy: 0.9420
# Epoch 3/20
# 9360/9360 [==============================] - 95s 10ms/step - loss: 39.0454 - crf_viterbi_accuracy: 0.9503 - val_loss: 39.2712 - val_crf_viterbi_accuracy: 0.9513
# Epoch 4/20
# 9360/9360 [==============================] - 95s 10ms/step - loss: 39.0236 - crf_viterbi_accuracy: 0.9546 - val_loss: 39.2537 - val_crf_viterbi_accuracy: 0.9554
# 9361/9361 [==============================] - 102s 11ms/step - loss: 39.3905 - crf_viterbi_accuracy: 0.8621 - val_loss: 39.3386 - val_crf_viterbi_accuracy: 0.9387
# Epoch 2/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.0796 - crf_viterbi_accuracy: 0.9414 - val_loss: 39.2937 - val_crf_viterbi_accuracy: 0.9491
# Epoch 3/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.0447 - crf_viterbi_accuracy: 0.9482 - val_loss: 39.2692 - val_crf_viterbi_accuracy: 0.9540
# Epoch 4/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.0190 - crf_viterbi_accuracy: 0.9534 - val_loss: 39.2529 - val_crf_viterbi_accuracy: 0.9590
# Epoch 5/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.0054 - crf_viterbi_accuracy: 0.9576 - val_loss: 39.2452 - val_crf_viterbi_accuracy: 0.9604
# Epoch 6/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 38.9926 - crf_viterbi_accuracy: 0.9610 - val_loss: 39.2373 - val_crf_viterbi_accuracy: 0.9626
# Epoch 7/20
# 9361/9361 [==============================] - 98s 11ms/step - loss: 38.9819 - crf_viterbi_accuracy: 0.9635 - val_loss: 39.2268 - val_crf_viterbi_accuracy: 0.9666
# Epoch 8/20
# 9361/9361 [==============================] - 97s 10ms/step - loss: 38.9736 - crf_viterbi_accuracy: 0.9658 - val_loss: 39.2246 - val_crf_viterbi_accuracy: 0.9669
# Epoch 9/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9679 - crf_viterbi_accuracy: 0.9675 - val_loss: 39.2200 - val_crf_viterbi_accuracy: 0.9679
# Epoch 10/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 38.9635 - crf_viterbi_accuracy: 0.9688 - val_loss: 39.2163 - val_crf_viterbi_accuracy: 0.9695
# Epoch 11/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9578 - crf_viterbi_accuracy: 0.9704 - val_loss: 39.2169 - val_crf_viterbi_accuracy: 0.9676
# Epoch 12/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 38.9546 - crf_viterbi_accuracy: 0.9716 - val_loss: 39.2181 - val_crf_viterbi_accuracy: 0.9670
# FOLD Number: 12/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 103s 11ms/step - loss: 39.6327 - crf_viterbi_accuracy: 0.8661 - val_loss: 38.9009 - val_crf_viterbi_accuracy: 0.9306
# Epoch 2/20
# 9361/9361 [==============================] - 96s 10ms/step - loss: 39.3138 - crf_viterbi_accuracy: 0.9409 - val_loss: 38.8436 - val_crf_viterbi_accuracy: 0.9455
# Epoch 3/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2739 - crf_viterbi_accuracy: 0.9489 - val_loss: 38.8167 - val_crf_viterbi_accuracy: 0.9501
# Epoch 4/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.2509 - crf_viterbi_accuracy: 0.9538 - val_loss: 38.8034 - val_crf_viterbi_accuracy: 0.9540
# Epoch 5/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.2351 - crf_viterbi_accuracy: 0.9586 - val_loss: 38.7908 - val_crf_viterbi_accuracy: 0.9581
# Epoch 6/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.2209 - crf_viterbi_accuracy: 0.9618 - val_loss: 38.7895 - val_crf_viterbi_accuracy: 0.9572
# Epoch 7/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.2112 - crf_viterbi_accuracy: 0.9644 - val_loss: 38.7796 - val_crf_viterbi_accuracy: 0.9624
# Epoch 8/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.2027 - crf_viterbi_accuracy: 0.9660 - val_loss: 38.7728 - val_crf_viterbi_accuracy: 0.9643
# Epoch 9/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1979 - crf_viterbi_accuracy: 0.9682 - val_loss: 38.7685 - val_crf_viterbi_accuracy: 0.9654
# Epoch 10/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1908 - crf_viterbi_accuracy: 0.9702 - val_loss: 38.7644 - val_crf_viterbi_accuracy: 0.9673
# Epoch 11/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1864 - crf_viterbi_accuracy: 0.9713 - val_loss: 38.7635 - val_crf_viterbi_accuracy: 0.9664
# Epoch 12/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1822 - crf_viterbi_accuracy: 0.9721 - val_loss: 38.7629 - val_crf_viterbi_accuracy: 0.9667
# Epoch 13/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1779 - crf_viterbi_accuracy: 0.9741 - val_loss: 38.7649 - val_crf_viterbi_accuracy: 0.9657
# Epoch 14/20
# 9361/9361 [==============================] - 93s 10ms/step - loss: 39.1743 - crf_viterbi_accuracy: 0.9745 - val_loss: 38.7555 - val_crf_viterbi_accuracy: 0.9702
# Epoch 15/20
# 9361/9361 [==============================] - 93s 10ms/step - loss: 39.1711 - crf_viterbi_accuracy: 0.9757 - val_loss: 38.7548 - val_crf_viterbi_accuracy: 0.9701
# Epoch 16/20
# 9361/9361 [==============================] - 95s 10ms/step - loss: 39.1703 - crf_viterbi_accuracy: 0.9758 - val_loss: 38.7591 - val_crf_viterbi_accuracy: 0.9660
# Epoch 17/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1668 - crf_viterbi_accuracy: 0.9772 - val_loss: 38.7541 - val_crf_viterbi_accuracy: 0.9690
# Epoch 18/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1638 - crf_viterbi_accuracy: 0.9777 - val_loss: 38.7567 - val_crf_viterbi_accuracy: 0.9675
# Epoch 19/20
# 9361/9361 [==============================] - 94s 10ms/step - loss: 39.1626 - crf_viterbi_accuracy: 0.9781 - val_loss: 38.7550 - val_crf_viterbi_accuracy: 0.9693
# CPU times: user 8h 42min 59s, sys: 37min 38s, total: 9h 20min 38s
# Wall time: 5h 58min 7s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("Hidden").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#         train_loss  train_acc   val_loss   val_acc     epochs
# Hidden
# 50       39.014644   0.976905  39.058118  0.969077  18.000000
# 100      39.017830   0.976082  39.060215  0.968410  16.666667
# 10       39.019106   0.975334  39.059157  0.968273  19.666667
# 20       39.016906   0.975790  39.061093  0.967173  19.333333

# %%
from google.colab import files
df_results.to_csv('Hidden_grid_senna.csv')
files.download('Hidden_grid_senna.csv')
