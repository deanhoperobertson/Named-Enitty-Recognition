# %% [markdown]
# <a href="https://colab.research.google.com/github/deanhoperobertson/Named-Enitty-Recognition/blob/master/Models/Hyperparameter%20Optimization/BiLSTM-CRF/SENNA/BiLSTM-CRF%20SENNA%20(Gradient%20Clipping).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn_crfsuite
# !pip install keras==2.2.4
# %tensorflow_version 1.x
#!pip install tensorflow-gpu==1.15.0
# !pip install keras==2.2.4
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-sl2d9t43
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-sl2d9t43
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.4.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras->keras-contrib==2.0.8) (1.15.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=518377508bd1cebfc50aea9ddd639d572aae64d68063641e8ede3756f230a102
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_wuylcik/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8
# Collecting sklearn_crfsuite
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Collecting python-crfsuite>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/95/99/869dde6dbf3e0d07a013c8eebfb0a3d30776334e0097f8432b631a9a3a19/python_crfsuite-0.9.7-cp36-cp36m-manylinux1_x86_64.whl (743kB)
#      |████████████████████████████████| 747kB 4.8MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (4.41.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn_crfsuite) (0.8.7)
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.7 sklearn-crfsuite-0.3.6
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 3.2MB/s
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 4.6MB/s
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Installing collected packages: keras-applications, keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.4 keras-applications-1.0.8
# TensorFlow 1.x selected.
# Collecting keras==2.2.4
#   Using cached https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.2.4

# %%
import pandas as pd
import re
import numpy as np
import urllib.request
from sklearn.model_selection import train_test_split

#keras and tensorflow packages
import tensorflow as tf
from keras.layers.merge import add
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.metrics import crf_accuracy

#evaluation
from sklearn_crfsuite.metrics import flat_classification_report,flat_f1_score,flat_precision_score
print(tf.__version__)
# Out:
# 1.15.2
# Using TensorFlow backend.

# %%
#Ensure Reproducibility
import numpy as np
import random as rn
import os

random_seed=3

# 1) set numpy random seed
np.random.seed(random_seed)
# 2) set build-in random seed
rn.seed(random_seed)
# 3) set PYTHONHASHSEED
os.environ['PYTHONHASHSEED']=str(random_seed)
# 4) set tensorflow random seed
tf.random.set_random_seed(random_seed)

# 5) Force TensorFlow to use single thread.
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
from keras import backend as K
tf.set_random_seed(1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import data from my github repo
train_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/train.txt"
test_url = "https://raw.githubusercontent.com/deanhoperobertson/Named-Enitty-Recognition/master/Data/test.txt"
train = urllib.request.urlopen(train_url).read()
test = urllib.request.urlopen(test_url).read()
train = train.decode('utf-8')
test = test.decode('utf-8')

def readstring(filename, meth):
    f = filename.split('\n')
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        if meth.lower()=="numbers1":
            sentence.append([hasNumbers1(splits[0]), splits[-1].strip()])
        elif meth.lower()=="numbers2":
            sentence.append([hasNumbers2(splits[0]), splits[-1].strip()])
        else:
            sentence.append([splits[0], splits[-1].strip()])
    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

def hasNumbers1(inputString):
    if re.search(r'\d', inputString):
        return "0"
    else:return(inputString)

def hasNumbers2(text):
  if text.isdigit():
      return "1"
  elif re.search(r'\d',text) and re.search(r'\,|\.',text):
      return "1" 
  else:
      if re.search(r'\d', text):
          return(re.sub('\d','D', text))
      else:
          return text

#preproces the txt file
train_data = readstring(train,"Numbers1")
test_data = readstring(test,"Numbers1")

#create corpus
corpus = train_data.copy()
corpus.extend(test_data)

# %%
def reformat_data(data,meth):
  if meth.lower() == "data":
    i=0
  else: i=1
  train = []
  output= []
  for sentence in data:
    words=[]
    for x in sentence:
      words.append(x[i])
    train.append(words)

  for i in train:
    string = ' '.join(i)
    output.append(string)
  return output

def get_max_length(corpus):
  length = []
  for sentence in corpus:
    length.append(len(sentence))
  return int(max(length))

def number_of_tags(corpus):
  tags=[]
  for sentence in corpus:
    for tag in sentence:
      tags.append(tag[1])
  return int(len(list(set(tags))))


MAX_LEN = get_max_length(corpus)
N_tags = number_of_tags(corpus)

train = reformat_data(train_data,"data")
test = reformat_data(test_data,"data")

train_y = reformat_data(train_data,"tags")
test_y = reformat_data(test_data,"tags")

# %% [markdown]
# ## Load Embeddings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#root_path = "/content/drive/My Drive/glove.6B.50d.txt"
root_path = "/content/drive/My Drive/SENNA.txt"

embeddings_index={}
f = open(root_path, encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 130000 word vectors.

# %% [markdown]
# ## Data Processing

# %%
def prep_data(xx_train,yy_train,xx_test,yy_test):
  
  token_word = text.Tokenizer(char_level=False, lower=True, filters="}", oov_token='UNK')
  token_word.fit_on_texts(xx_train)

  X_train = sequence.pad_sequences(token_word.texts_to_sequences(xx_train), maxlen=MAX_LEN,padding="post")
  X_test = sequence.pad_sequences(token_word.texts_to_sequences(xx_test), maxlen=MAX_LEN,padding="post")

  # create a tokenizer
  token_tag = text.Tokenizer(char_level=False, lower=False, filters="}")
  token_tag.fit_on_texts(train_y)

  # convert training labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_train), maxlen=MAX_LEN,padding="post")
  Y_train = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  # convert test labels
  Y = sequence.pad_sequences(token_tag.texts_to_sequences(yy_test), maxlen=MAX_LEN,padding="post")
  Y_test = [to_categorical(i, num_classes=N_tags+1) for i in Y]

  return X_train, X_test, Y_train, Y_test, token_word

# %% [markdown]
# ## Grid Search

# %%
# %%time
from sklearn.model_selection import KFold
from keras import optimizers
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


kf = KFold(n_splits=3,random_state=3, shuffle=True)

grid_results = []
CLIPS = [0,1,2,5]
HIDDEN = 50
DROPOUT =0.25
CELLS =100
BATCH_SIZE= 64
EPOCHS=20
fold_count = 1

for CLIP in CLIPS:
  for train_index, test_index in kf.split(train):
    print("FOLD Number: %d/%d" %(fold_count,len(CLIPS)*3))
    
    #split data
    xx_train,yy_train = np.array(train)[train_index], np.array(train_y)[train_index]
    xx_test,yy_test = np.array(train)[test_index], np.array(train_y)[test_index]

    X_train, X_test, Y_train, Y_test, token_word = prep_data(xx_train, yy_train,xx_test, yy_test)

    #---------create emedding matrix------------
    EMBEDDING=len(coefs)
    word_index = token_word.word_index
    embedding_matrix = np.zeros((len(token_word.word_index) + 1, EMBEDDING))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector

    #---------Define Model Build-------------
    def create_model(OPT):
      input =  Input(shape=(MAX_LEN,))
      model_2 = Embedding(len(token_word.word_index) + 1,output_dim=EMBEDDING,
                      weights=[embedding_matrix],input_length=MAX_LEN,
                      trainable=False,mask_zero=True)(input)
      model_2 = Bidirectional(LSTM(units=CELLS, return_sequences=True,
                                recurrent_dropout=DROPOUT, dropout=DROPOUT))(model_2)
      model_2 = TimeDistributed(Dense(HIDDEN, activation="relu"))(model_2)
      crf = CRF(N_tags+1)  # CRF layer
      out = crf(model_2)  # output
      model_2 = Model(input, out)
      
      model_2.compile(optimizer=OPT, loss=crf_loss,metrics=[crf_viterbi_accuracy])
      return model_2

  #---------Fit Model-----------------
    opt=optimizers.Adam(clipvalue=CLIP)

    model = create_model(opt)
    history = model.fit(X_train, np.array(Y_train), batch_size=BATCH_SIZE, epochs=EPOCHS,verbose=1, callbacks=[early_stopping], validation_data=(X_test,np.array(Y_test)))

    grid_results.append({"train_loss":history.history["loss"][-1],
                      "train_acc": history.history["crf_viterbi_accuracy"][-1],
                      "val_loss": history.history["val_loss"][-1],
                      "val_acc": history.history["val_crf_viterbi_accuracy"][-1],
                      "epochs": len(history.history["loss"]),
                      "Clipping": CLIP ,
                      })

    fold_count +=1
# Out:
# FOLD Number: 1/12
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2974: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9360/9360 [==============================] - 134s 14ms/step - loss: 39.3940 - crf_viterbi_accuracy: 0.8719 - val_loss: 39.3500 - val_crf_viterbi_accuracy: 0.9328
# Epoch 2/20
# 9360/9360 [==============================] - 131s 14ms/step - loss: 39.0832 - crf_viterbi_accuracy: 0.9405 - val_loss: 39.3024 - val_crf_viterbi_accuracy: 0.9421
# Epoch 3/20
# 9360/9360 [==============================] - 130s 14ms/step - loss: 39.0463 - crf_viterbi_accuracy: 0.9487 - val_loss: 39.2740 - val_crf_viterbi_accuracy: 0.9478
# Epoch 4/20
# 9360/9360 [==============================] - 131s 14ms/step - loss: 39.0243 - crf_viterbi_accuracy: 0.9539 - val_loss: 39.2571 - val_crf_viterbi_accuracy: 0.9531
# Epoch 5/20
# 9360/9360 [==============================] - 130s 14ms/step - loss: 39.0069 - crf_viterbi_accuracy: 0.9585 - val_loss: 39.2411 - val_crf_viterbi_accuracy: 0.9582
# Epoch 6/20
# 9360/9360 [==============================] - 130s 14ms/step - loss: 38.9944 - crf_viterbi_accuracy: 0.9616 - val_loss: 39.2348 - val_crf_viterbi_accuracy: 0.9596
# Epoch 7/20
# 9360/9360 [==============================] - 131s 14ms/step - loss: 38.9862 - crf_viterbi_accuracy: 0.9638 - val_loss: 39.2282 - val_crf_viterbi_accuracy: 0.9607
# Epoch 8/20
# 9360/9360 [==============================] - 130s 14ms/step - loss: 38.9777 - crf_viterbi_accuracy: 0.9662 - val_loss: 39.2234 - val_crf_viterbi_accuracy: 0.9633
# Epoch 9/20
# 9360/9360 [==============================] - 130s 14ms/step - loss: 38.9693 - crf_viterbi_accuracy: 0.9685 - val_loss: 39.2204 - val_crf_viterbi_accuracy: 0.9642
# Epoch 10/20
# 9360/9360 [==============================] - 129s 14ms/step - loss: 38.9630 - crf_viterbi_accuracy: 0.9699 - val_loss: 39.2143 - val_crf_viterbi_accuracy: 0.9659
# Epoch 15/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9451 - crf_viterbi_accuracy: 0.9750 - val_loss: 39.2143 - val_crf_viterbi_accuracy: 0.9687
# Epoch 16/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9443 - crf_viterbi_accuracy: 0.9750 - val_loss: 39.2139 - val_crf_viterbi_accuracy: 0.9693
# Epoch 17/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9397 - crf_viterbi_accuracy: 0.9761 - val_loss: 39.2149 - val_crf_viterbi_accuracy: 0.9681
# Epoch 18/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9386 - crf_viterbi_accuracy: 0.9768 - val_loss: 39.2099 - val_crf_viterbi_accuracy: 0.9727
# Epoch 19/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 38.9346 - crf_viterbi_accuracy: 0.9780 - val_loss: 39.2105 - val_crf_viterbi_accuracy: 0.9711
# Epoch 20/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 38.9338 - crf_viterbi_accuracy: 0.9782 - val_loss: 39.2123 - val_crf_viterbi_accuracy: 0.9690
# FOLD Number: 6/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 134s 14ms/step - loss: 39.6454 - crf_viterbi_accuracy: 0.8716 - val_loss: 38.9083 - val_crf_viterbi_accuracy: 0.9333
# Epoch 2/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.3232 - crf_viterbi_accuracy: 0.9405 - val_loss: 38.8535 - val_crf_viterbi_accuracy: 0.9432
# Epoch 3/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.2832 - crf_viterbi_accuracy: 0.9480 - val_loss: 38.8308 - val_crf_viterbi_accuracy: 0.9480
# Epoch 4/20
# 9361/9361 [==============================] - 131s 14ms/step - loss: 39.2587 - crf_viterbi_accuracy: 0.9529 - val_loss: 38.8080 - val_crf_viterbi_accuracy: 0.9541
# Epoch 5/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.2406 - crf_viterbi_accuracy: 0.9570 - val_loss: 38.7990 - val_crf_viterbi_accuracy: 0.9572
# Epoch 6/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.2272 - crf_viterbi_accuracy: 0.9604 - val_loss: 38.7892 - val_crf_viterbi_accuracy: 0.9598
# Epoch 7/20
# 9361/9361 [==============================] - 130s 14ms/step - loss: 39.2162 - crf_viterbi_accuracy: 0.9632 - val_loss: 38.7836 - val_crf_viterbi_accuracy: 0.9606
# Epoch 8/20
# 9361/9361 [==============================] - 130s 14ms/step - loss: 39.2089 - crf_viterbi_accuracy: 0.9650 - val_loss: 38.7766 - val_crf_viterbi_accuracy: 0.9631
# Epoch 9/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.2014 - crf_viterbi_accuracy: 0.9671 - val_loss: 38.7758 - val_crf_viterbi_accuracy: 0.9625
# Epoch 10/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.1941 - crf_viterbi_accuracy: 0.9689 - val_loss: 38.7680 - val_crf_viterbi_accuracy: 0.9662
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.0601 - crf_viterbi_accuracy: 0.9456 - val_loss: 39.2842 - val_crf_viterbi_accuracy: 0.9506
# Epoch 4/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.0337 - crf_viterbi_accuracy: 0.9513 - val_loss: 39.2652 - val_crf_viterbi_accuracy: 0.9564
# Epoch 5/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.0170 - crf_viterbi_accuracy: 0.9548 - val_loss: 39.2542 - val_crf_viterbi_accuracy: 0.9589
# Epoch 6/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.0017 - crf_viterbi_accuracy: 0.9594 - val_loss: 39.2458 - val_crf_viterbi_accuracy: 0.9614
# Epoch 7/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9915 - crf_viterbi_accuracy: 0.9621 - val_loss: 39.2354 - val_crf_viterbi_accuracy: 0.9639
# Epoch 8/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9819 - crf_viterbi_accuracy: 0.9639 - val_loss: 39.2306 - val_crf_viterbi_accuracy: 0.9653
# Epoch 9/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9772 - crf_viterbi_accuracy: 0.9655 - val_loss: 39.2293 - val_crf_viterbi_accuracy: 0.9647
# Epoch 10/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9686 - crf_viterbi_accuracy: 0.9677 - val_loss: 39.2292 - val_crf_viterbi_accuracy: 0.9635
# Epoch 11/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9636 - crf_viterbi_accuracy: 0.9692 - val_loss: 39.2224 - val_crf_viterbi_accuracy: 0.9672
# Epoch 12/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9583 - crf_viterbi_accuracy: 0.9705 - val_loss: 39.2215 - val_crf_viterbi_accuracy: 0.9671
# Epoch 13/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9553 - crf_viterbi_accuracy: 0.9715 - val_loss: 39.2184 - val_crf_viterbi_accuracy: 0.9690
# Epoch 14/20
# 9361/9361 [==============================] - 126s 13ms/step - loss: 38.9509 - crf_viterbi_accuracy: 0.9730 - val_loss: 39.2265 - val_crf_viterbi_accuracy: 0.9628
# Epoch 15/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9483 - crf_viterbi_accuracy: 0.9737 - val_loss: 39.2152 - val_crf_viterbi_accuracy: 0.9690
# Epoch 16/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9453 - crf_viterbi_accuracy: 0.9743 - val_loss: 39.2157 - val_crf_viterbi_accuracy: 0.9693
# Epoch 17/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9423 - crf_viterbi_accuracy: 0.9757 - val_loss: 39.2155 - val_crf_viterbi_accuracy: 0.9675
# FOLD Number: 9/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 136s 15ms/step - loss: 39.5847 - crf_viterbi_accuracy: 0.8884 - val_loss: 38.8866 - val_crf_viterbi_accuracy: 0.9323
# Epoch 2/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.3070 - crf_viterbi_accuracy: 0.9411 - val_loss: 38.8382 - val_crf_viterbi_accuracy: 0.9451
# Epoch 3/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.2697 - crf_viterbi_accuracy: 0.9490 - val_loss: 38.8115 - val_crf_viterbi_accuracy: 0.9501
# Epoch 4/20
# 9361/9361 [==============================] - 126s 13ms/step - loss: 39.2474 - crf_viterbi_accuracy: 0.9544 - val_loss: 38.8010 - val_crf_viterbi_accuracy: 0.9517
# Epoch 5/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.2320 - crf_viterbi_accuracy: 0.9583 - val_loss: 38.7882 - val_crf_viterbi_accuracy: 0.9583
# Epoch 6/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.2202 - crf_viterbi_accuracy: 0.9609 - val_loss: 38.7793 - val_crf_viterbi_accuracy: 0.9613
# Epoch 7/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.2098 - crf_viterbi_accuracy: 0.9638 - val_loss: 38.7751 - val_crf_viterbi_accuracy: 0.9619
# Epoch 8/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.2025 - crf_viterbi_accuracy: 0.9664 - val_loss: 38.7687 - val_crf_viterbi_accuracy: 0.9642
# Epoch 9/20
# 9361/9361 [==============================] - 126s 13ms/step - loss: 39.1955 - crf_viterbi_accuracy: 0.9685 - val_loss: 38.7655 - val_crf_viterbi_accuracy: 0.9653
# Epoch 10/20
# 9361/9361 [==============================] - 126s 13ms/step - loss: 39.1917 - crf_viterbi_accuracy: 0.9688 - val_loss: 38.7661 - val_crf_viterbi_accuracy: 0.9640
# Epoch 11/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.1865 - crf_viterbi_accuracy: 0.9703 - val_loss: 38.7624 - val_crf_viterbi_accuracy: 0.9652
# Epoch 12/20
# 9361/9361 [==============================] - 126s 13ms/step - loss: 39.1824 - crf_viterbi_accuracy: 0.9715 - val_loss: 38.7585 - val_crf_viterbi_accuracy: 0.9677
# Epoch 13/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.1793 - crf_viterbi_accuracy: 0.9727 - val_loss: 38.7646 - val_crf_viterbi_accuracy: 0.9642
# Epoch 14/20
# 9361/9361 [==============================] - 125s 13ms/step - loss: 39.1742 - crf_viterbi_accuracy: 0.9739 - val_loss: 38.7570 - val_crf_viterbi_accuracy: 0.9680
# Epoch 15/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.1715 - crf_viterbi_accuracy: 0.9746 - val_loss: 38.7544 - val_crf_viterbi_accuracy: 0.9683
# Epoch 16/20
# 9361/9361 [==============================] - 125s 13ms/step - loss: 39.1699 - crf_viterbi_accuracy: 0.9757 - val_loss: 38.7561 - val_crf_viterbi_accuracy: 0.9673
# Epoch 17/20
# 9361/9361 [==============================] - 125s 13ms/step - loss: 39.1675 - crf_viterbi_accuracy: 0.9767 - val_loss: 38.7545 - val_crf_viterbi_accuracy: 0.9683
# FOLD Number: 10/12
# Train on 9360 samples, validate on 4681 samples
# Epoch 1/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.0894 - crf_viterbi_accuracy: 0.9397 - val_loss: 39.3014 - val_crf_viterbi_accuracy: 0.9476
# Epoch 3/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.0507 - crf_viterbi_accuracy: 0.9476 - val_loss: 39.2756 - val_crf_viterbi_accuracy: 0.9541
# Epoch 4/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.0261 - crf_viterbi_accuracy: 0.9524 - val_loss: 39.2595 - val_crf_viterbi_accuracy: 0.9574
# Epoch 5/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.0089 - crf_viterbi_accuracy: 0.9568 - val_loss: 39.2502 - val_crf_viterbi_accuracy: 0.9604
# Epoch 6/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9964 - crf_viterbi_accuracy: 0.9600 - val_loss: 39.2397 - val_crf_viterbi_accuracy: 0.9636
# Epoch 7/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9863 - crf_viterbi_accuracy: 0.9633 - val_loss: 39.2357 - val_crf_viterbi_accuracy: 0.9631
# Epoch 8/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9783 - crf_viterbi_accuracy: 0.9651 - val_loss: 39.2332 - val_crf_viterbi_accuracy: 0.9637
# Epoch 9/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9737 - crf_viterbi_accuracy: 0.9661 - val_loss: 39.2285 - val_crf_viterbi_accuracy: 0.9650
# Epoch 10/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 38.9661 - crf_viterbi_accuracy: 0.9684 - val_loss: 39.2217 - val_crf_viterbi_accuracy: 0.9682
# Epoch 11/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9598 - crf_viterbi_accuracy: 0.9704 - val_loss: 39.2188 - val_crf_viterbi_accuracy: 0.9687
# Epoch 12/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9565 - crf_viterbi_accuracy: 0.9710 - val_loss: 39.2175 - val_crf_viterbi_accuracy: 0.9681
# Epoch 13/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9540 - crf_viterbi_accuracy: 0.9725 - val_loss: 39.2170 - val_crf_viterbi_accuracy: 0.9689
# Epoch 14/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9488 - crf_viterbi_accuracy: 0.9728 - val_loss: 39.2152 - val_crf_viterbi_accuracy: 0.9700
# Epoch 15/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 38.9472 - crf_viterbi_accuracy: 0.9739 - val_loss: 39.2170 - val_crf_viterbi_accuracy: 0.9677
# Epoch 16/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 38.9446 - crf_viterbi_accuracy: 0.9746 - val_loss: 39.2193 - val_crf_viterbi_accuracy: 0.9685
# FOLD Number: 12/12
# Train on 9361 samples, validate on 4680 samples
# Epoch 1/20
# 9361/9361 [==============================] - 140s 15ms/step - loss: 39.6089 - crf_viterbi_accuracy: 0.8711 - val_loss: 38.9059 - val_crf_viterbi_accuracy: 0.9321
# Epoch 2/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.3216 - crf_viterbi_accuracy: 0.9396 - val_loss: 38.8530 - val_crf_viterbi_accuracy: 0.9422
# Epoch 3/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.2817 - crf_viterbi_accuracy: 0.9479 - val_loss: 38.8236 - val_crf_viterbi_accuracy: 0.9495
# Epoch 4/20
# 9361/9361 [==============================] - 129s 14ms/step - loss: 39.2553 - crf_viterbi_accuracy: 0.9533 - val_loss: 38.8047 - val_crf_viterbi_accuracy: 0.9549
# Epoch 5/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.2374 - crf_viterbi_accuracy: 0.9574 - val_loss: 38.7973 - val_crf_viterbi_accuracy: 0.9568
# Epoch 6/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.2248 - crf_viterbi_accuracy: 0.9614 - val_loss: 38.7875 - val_crf_viterbi_accuracy: 0.9603
# Epoch 7/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.2146 - crf_viterbi_accuracy: 0.9638 - val_loss: 38.7762 - val_crf_viterbi_accuracy: 0.9639
# Epoch 8/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.2058 - crf_viterbi_accuracy: 0.9665 - val_loss: 38.7728 - val_crf_viterbi_accuracy: 0.9649
# Epoch 9/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.1979 - crf_viterbi_accuracy: 0.9683 - val_loss: 38.7689 - val_crf_viterbi_accuracy: 0.9650
# Epoch 10/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.1944 - crf_viterbi_accuracy: 0.9685 - val_loss: 38.7696 - val_crf_viterbi_accuracy: 0.9646
# Epoch 11/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.1886 - crf_viterbi_accuracy: 0.9705 - val_loss: 38.7652 - val_crf_viterbi_accuracy: 0.9660
# Epoch 12/20
# 9361/9361 [==============================] - 126s 13ms/step - loss: 39.1846 - crf_viterbi_accuracy: 0.9717 - val_loss: 38.7601 - val_crf_viterbi_accuracy: 0.9688
# Epoch 13/20
# 9361/9361 [==============================] - 128s 14ms/step - loss: 39.1795 - crf_viterbi_accuracy: 0.9728 - val_loss: 38.7610 - val_crf_viterbi_accuracy: 0.9666
# Epoch 14/20
# 9361/9361 [==============================] - 127s 14ms/step - loss: 39.1763 - crf_viterbi_accuracy: 0.9742 - val_loss: 38.7614 - val_crf_viterbi_accuracy: 0.9656
# CPU times: user 11h 4min 50s, sys: 56min 58s, total: 12h 1min 49s
# Wall time: 7h 40min 52s

# %% [markdown]
# ## TEST

# %%
df_results = pd.DataFrame(grid_results)
df_results.groupby("Clipping").mean().sort_values(by=["val_acc"], ascending=False)
# Out:
#           train_loss  train_acc   val_loss   val_acc     epochs
# Clipping
# 2          39.015437   0.976777  39.059281  0.968801  17.666667
# 1          39.010728   0.978391  39.058339  0.968499  20.000000
# 0          39.013084   0.977376  39.058236  0.968194  18.666667
# 5          39.022419   0.974590  39.063052  0.967495  15.000000

# %%
from google.colab import files
df_results.to_csv('Clipping_grid_Senna.csv')
files.download('Clipping_grid_Senna.csv')
